# %%
import json
import torch
from sentence_transformers import util

# %%
big = "memoryalpha"
small = "stexpanded"

embeddings = "dogtag_bgelarge"
communities = "leiden"

# %%
mappings_file_big = "./_input/mappings/" + big + ".json"
mappings_file_small = "./_input/mappings/" + small + ".json"

communities_small_file = "./_input/communities/" + communities + "/" + small + ".txt"
communities_big_file = "./_input/communities/" + communities + "/" + big + ".txt"

node_embeddings_small_file = "./_input/node_embeddings/" + embeddings + "/" + small + ".json"
node_embeddings_big_file = "./_input/node_embeddings/" + embeddings + "/" + big + ".json"

neighborhood_embeddings_small_file = "./_input/neighborhood_embeddings/" + embeddings + "/" + small + ".json"
neighborhood_embeddings_big_file = "./_input/neighborhood_embeddings/" + embeddings + "/" + big + ".json"

community_embeddings_small_file = "./_input/community_embeddings/" + communities + "_" + embeddings + "/" + small + ".json"
community_embeddings_big_file = "./_input/community_embeddings/" + communities + "_" + embeddings + "/" + big + ".json"

exact_match_file = "./_input/exact_match/" + big + "-" + small + ".json"
gold_pairs_file = "./_input/gold_pairs/" + big + "-" + small + ".txt"

# %%
with open(gold_pairs_file) as gpf:
    gold_pairs = []
    for line in gpf:
        numbers_list = [int(num) for num in line.strip().split(";")]
        gold_pairs.append(numbers_list)

with open(exact_match_file) as file:
    exact_match = json.load(file)

with open(mappings_file_small) as file:
    mappings_small = json.load(file)
    mappings_small = {v: k for k, v in mappings_small.items()}

with open(mappings_file_big) as file:
    mappings_big = json.load(file)
    mappings_big = {v: k for k, v in mappings_big.items()}

with open(communities_small_file) as csf:
    small_communities = []
    for line in csf:
        numbers_set = {int(num) for num in line.strip().split(" ")}
        small_communities.append(numbers_set)

with open(communities_big_file) as cbf:
    big_communities = []
    for line in cbf:
        numbers_set = {int(num) for num in line.strip().split(" ")}
        big_communities.append(numbers_set)

with open(node_embeddings_small_file) as nesf:
    node_embeddings_small = json.load(nesf)

with open(node_embeddings_big_file) as nebf:
    node_embeddings_big = json.load(nebf)

with open(neighborhood_embeddings_small_file) as nesf:
    neig_embeddings_small = json.load(nesf)

with open(neighborhood_embeddings_big_file) as nebf:
    neig_embeddings_big = json.load(nebf)

with open(community_embeddings_small_file) as cesf:
    comm_embeddings_small = json.load(cesf)

with open(community_embeddings_big_file) as cebf:
    comm_embeddings_big = json.load(cebf)

# %%
gold_exact = list()
gold_not_exact = list()

for p in gold_pairs:
    if [p[0], p[1]] in exact_match:
        gold_exact.append([p[0], p[1]])
    else:
        gold_not_exact.append([p[0], p[1]])

# %%
node_to_comm_embeddings_small = dict()
index = 0
for community in small_communities:
    for node in community:
        node_to_comm_embeddings_small[str(node)] = comm_embeddings_small[str(index)]
    index += 1

node_to_comm_embeddings_big = dict()
index = 0
for community in big_communities:
    for node in community:
        node_to_comm_embeddings_big[str(node)] = comm_embeddings_big[str(index)]
    index += 1

# %%
small_torch_embeds = torch.Tensor(list(node_embeddings_small.values()))
big_torch_embeds = torch.Tensor(list(node_embeddings_big.values()))
order_node = util.semantic_search(small_torch_embeds, big_torch_embeds)

# %%
top1dict_node = dict()
for index, value in enumerate(order_node):
    add_key = int(list(node_embeddings_small.keys())[index])
    add_value = int(list(node_embeddings_big.keys())[order_node[index][0]["corpus_id"]])
    top1dict_node[add_key] = add_value

# %%
node_neig_embeddings_small = {
    key: node_embeddings_small[key] + neig_embeddings_small[key]
    for key in node_embeddings_small
    if key in neig_embeddings_small
}
node_neig_embeddings_big = {
    key: node_embeddings_big[key] + neig_embeddings_big[key]
    for key in node_embeddings_big
    if key in neig_embeddings_big
}

# %%
small_torch_embeds = torch.Tensor(list(node_neig_embeddings_small.values()))
big_torch_embeds = torch.Tensor(list(node_neig_embeddings_big.values()))
order_node_neig = util.semantic_search(small_torch_embeds, big_torch_embeds)

# %%
top1dict_node_neig = dict()
for index, value in enumerate(order_node_neig):
    add_key = int(list(node_neig_embeddings_small.keys())[index])
    add_value = int(list(node_neig_embeddings_big.keys())[order_node_neig[index][0]["corpus_id"]])
    top1dict_node_neig[add_key] = add_value

# %%
node_neig_comm_embeddings_small = {
    key: node_embeddings_small[key] + neig_embeddings_small[key] + node_to_comm_embeddings_small[key]
    for key in node_embeddings_small
    if (key in neig_embeddings_small and key in node_to_comm_embeddings_small)
}
node_neig_comm_embeddings_big = {
    key: node_embeddings_big[key] + neig_embeddings_big[key]  + node_to_comm_embeddings_big[key]
    for key in node_embeddings_big
    if (key in neig_embeddings_big and key in node_to_comm_embeddings_big)
}

# %%
small_torch_embeds = torch.Tensor(list(node_neig_comm_embeddings_small.values()))
big_torch_embeds = torch.Tensor(list(node_neig_comm_embeddings_big.values()))
order_node_neig_comm = util.semantic_search(small_torch_embeds, big_torch_embeds)

# %%
top1dict_node_neig_comm = dict()
for index, value in enumerate(order_node_neig):
    add_key = int(list(node_neig_comm_embeddings_small.keys())[index])
    add_value = int(list(node_neig_comm_embeddings_big.keys())[order_node_neig_comm[index][0]["corpus_id"]])
    top1dict_node_neig_comm[add_key] = add_value

# %%
print("############### SETTINGS ################")
print("From:            " + small)
print("To:              " + big)
print("Embeddings:      " + embeddings)
print("Communities:     " + communities)

print("############ ALL GOLD PAIRS #############")
print("Count:            " + str(len(gold_pairs)))

found = 0
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node:             " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node_neig.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig:        " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node_neig_comm.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig-Comm:   " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

print("############## EXACT MATCH ##############")
print("Count:            " + str(len(gold_exact)))

found = 0
all_pairs = len(gold_exact)
# for gold_pair in tqdm(gold_exact):
for gold_pair in gold_exact:
    if top1dict_node.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node:             " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_exact)
# for gold_pair in tqdm(gold_exact):
for gold_pair in gold_exact:
    if top1dict_node_neig.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig:        " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_exact)
# for gold_pair in tqdm(gold_exact):
for gold_pair in gold_exact:
    if top1dict_node_neig_comm.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig-Comm:   " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

print("############ NOT EXACT MATCH ############")
print("Count:            " + str(len(gold_not_exact)))

found = 0
all_pairs = len(gold_not_exact)
# for gold_pair in tqdm(gold_not_exact):
for gold_pair in gold_not_exact:
    if top1dict_node.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node:             " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_not_exact)
# for gold_pair in tqdm(gold_not_exact):
for gold_pair in gold_not_exact:
    if top1dict_node_neig.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig:        " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")

found = 0
all_pairs = len(gold_not_exact)
# for gold_pair in tqdm(gold_not_exact):
for gold_pair in gold_not_exact:
    if top1dict_node_neig_comm.get(gold_pair[1]) == gold_pair[0]:
        found += 1
print("Node-Neig-Comm:   " + str(found) + " (" + f"{found / all_pairs * 100:.5f}" + "%)")
# Out:
# ############### SETTINGS ################
# From:            stexpanded
# To:              memoryalpha
# Embeddings:      dogtag_bgelarge
# Communities:     leiden
# ############ ALL GOLD PAIRS #############
# Count:            1779
# Node:             1432 (80.49466%)
# Node-Neig:        1455 (81.78752%)
# Node-Neig-Comm:   1439 (80.88814%)
# ############## EXACT MATCH ##############
# Count:            1617
# Node:             1332 (82.37477%)
# Node-Neig:        1356 (83.85900%)
# Node-Neig-Comm:   1339 (82.80767%)
# ############ NOT EXACT MATCH ############
# Count:            162
# Node:             100 (61.72840%)
# Node-Neig:        99 (61.11111%)
# Node-Neig-Comm:   100 (61.72840%)

# %%
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node.get(gold_pair[1]) == gold_pair[0]:
        print("found:", "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
    else:
        print("not found:", "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""),
              "\nfound instead:", "\n",
              mappings_big[top1dict_node.get(gold_pair[1])]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
# Out:
# found:
#  http://memory-alpha.wikia.com/18th_century
#  http://stexpanded.wikia.com/18th_century
#
# found:
#  http://memory-alpha.wikia.com/1991
#  http://stexpanded.wikia.com/1991
#
# found:
#  http://memory-alpha.wikia.com/1992
#  http://stexpanded.wikia.com/1992
#
# not found:
#  http://stexpanded.wikia.com/1996
#  http://memory-alpha.wikia.com/1996
# found instead:
#  http://memory-alpha.wikia.com/Joachim
#
# found:
#  http://memory-alpha.wikia.com/19th_century
#  http://stexpanded.wikia.com/19th_century
#
# found:
#  http://memory-alpha.wikia.com/20th_century
#  http://stexpanded.wikia.com/20th_century
#
# found:
#  http://memory-alpha.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#  http://stexpanded.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#
# not found:
#  http://stexpanded.wikia.com/47
#  http://memory-alpha.wikia.com/47
# found instead:
#  http://memory-alpha.wikia.com/12_February
#
# found:
#  http://memory-alpha.wikia.com/602_Club
#  http://stexpanded.wikia.com/602_Club
#
# not found:
#  http://stexpanded.wikia.com/Magna_Roma
#  http://memory-alpha.wikia.com/892-IV
# found instead:
#  http://memory-alpha.wikia.com/Roman_Empire_(892-IV)
#
# not found:
#  http://stexpanded.wikia.com/Alyson_Foxton
#  http://memory-alpha.wikia.com/A.F.
# found instead:
#  http://memory-alpha.wikia.com/Alden
#
# found:
#  http://memory-alpha.wikia.com/Aaamazzarite
#  http://stexpanded.wikia.com/Aaamazzarite
#
# found:
#  http://memory-alpha.wikia.com/Aberdeen
#  http://stexpanded.wikia.com/Aberdeen
#
# found:
#  http://memory-alpha.wikia.com/Ablative_armor
#  http://stexpanded.wikia.com/Ablative_armor
#
# found:
#  http://memory-alpha.wikia.com/Acamarian
#  http://stexpanded.wikia.com/Acamarian
#
# found:
#  http://memory-alpha.wikia.com/Acting_captain
#  http://stexpanded.wikia.com/Acting_captain
#
# found:
#  http://memory-alpha.wikia.com/Actor
#  http://stexpanded.wikia.com/Actor
#
# found:
#  http://memory-alpha.wikia.com/Adarak_Prime
#  http://stexpanded.wikia.com/Adarak_Prime
#
# not found:
#  http://stexpanded.wikia.com/Admiral
#  http://memory-alpha.wikia.com/Admiral
# found instead:
#  http://memory-alpha.wikia.com/Fleet_admiral
#
# found:
#  http://memory-alpha.wikia.com/Advanced_Tactical_Training
#  http://stexpanded.wikia.com/Advanced_Tactical_Training_Program
#
# found:
#  http://memory-alpha.wikia.com/Aenar
#  http://stexpanded.wikia.com/Aenar
#
# found:
#  http://memory-alpha.wikia.com/Aeroshuttle
#  http://stexpanded.wikia.com/Aeroshuttle
#
# not found:
#  http://stexpanded.wikia.com/Africa
#  http://memory-alpha.wikia.com/Africa
# found instead:
#  http://memory-alpha.wikia.com/South_Africa
#
# found:
#  http://memory-alpha.wikia.com/Afterlife
#  http://stexpanded.wikia.com/Afterlife
#
# found:
#  http://memory-alpha.wikia.com/Aircraft_carrier
#  http://stexpanded.wikia.com/Aircraft_carrier
#
# found:
#  http://memory-alpha.wikia.com/Alaska
#  http://stexpanded.wikia.com/Alaska
#
# found:
#  http://memory-alpha.wikia.com/Alcohol
#  http://stexpanded.wikia.com/Alcohol
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran
#  http://stexpanded.wikia.com/Aldebaran_system
#
# not found:
#  http://stexpanded.wikia.com/Aldebaran_Prime
#  http://memory-alpha.wikia.com/Aldebaran_III
# found instead:
#  http://memory-alpha.wikia.com/Aldebaran
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran_whiskey
#  http://stexpanded.wikia.com/Aldebaran_whiskey
#
# found:
#  http://memory-alpha.wikia.com/Alden
#  http://stexpanded.wikia.com/Alden
#
# found:
#  http://memory-alpha.wikia.com/Alexander_Rozhenko
#  http://stexpanded.wikia.com/Alexander_Rozhenko
#
# found:
#  http://memory-alpha.wikia.com/Alien
#  http://stexpanded.wikia.com/Alien
#
# not found:
#  http://stexpanded.wikia.com/Alliance
#  http://memory-alpha.wikia.com/Alliance
# found instead:
#  http://memory-alpha.wikia.com/Alliance_(nation)
#
# found:
#  http://memory-alpha.wikia.com/Almatha_sector
#  http://stexpanded.wikia.com/Almatha_sector
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Centauri
#  http://stexpanded.wikia.com/Alpha_Centauri_system
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Quadrant
#  http://stexpanded.wikia.com/Alpha_Quadrant
#
# found:
#  http://memory-alpha.wikia.com/Alsuran_Empire
#  http://stexpanded.wikia.com/Alsuran
#
# found:
#  http://memory-alpha.wikia.com/Altair_water
#  http://stexpanded.wikia.com/Altair_water
#
# not found:
#  http://stexpanded.wikia.com/Alternate_reality
#  http://memory-alpha.wikia.com/Alternate_reality
# found instead:
#  http://memory-alpha.wikia.com/Quantum_reality
#
# not found:
#  http://stexpanded.wikia.com/Alternate_timeline
#  http://memory-alpha.wikia.com/Alternate_timeline
# found instead:
#  http://memory-alpha.wikia.com/Time_warp
#
# found:
#  http://memory-alpha.wikia.com/Altonian_brain_teaser
#  http://stexpanded.wikia.com/Altonian_brain_teaser
#
# found:
#  http://memory-alpha.wikia.com/Alynna_Nechayev
#  http://stexpanded.wikia.com/Alynna_Nechayev
#
# found:
#  http://memory-alpha.wikia.com/Amanda_Grayson
#  http://stexpanded.wikia.com/Amanda_Grayson
#
# not found:
#  http://stexpanded.wikia.com/Ambassador
#  http://memory-alpha.wikia.com/Ambassador
# found instead:
#  http://memory-alpha.wikia.com/Ambassadors
#
# found:
#  http://memory-alpha.wikia.com/Ambassador_class
#  http://stexpanded.wikia.com/Ambassador_class
#
# found:
#  http://memory-alpha.wikia.com/American_Civil_War
#  http://stexpanded.wikia.com/American_Civil_War
#
# found:
#  http://memory-alpha.wikia.com/American_Revolution
#  http://stexpanded.wikia.com/American_Revolutionary_War
#
# not found:
#  http://stexpanded.wikia.com/Amnesia
#  http://memory-alpha.wikia.com/Amnesia
# found instead:
#  http://memory-alpha.wikia.com/Anterograde_amnesia
#
# found:
#  http://memory-alpha.wikia.com/Amusement_park
#  http://stexpanded.wikia.com/Amusement_park
#
# found:
#  http://memory-alpha.wikia.com/Ancient_humanoid
#  http://stexpanded.wikia.com/Ancient_humanoid
#
# found:
#  http://memory-alpha.wikia.com/Andoria
#  http://stexpanded.wikia.com/Andoria
#
# found:
#  http://memory-alpha.wikia.com/Andorian
#  http://stexpanded.wikia.com/Andorian
#
# found:
#  http://memory-alpha.wikia.com/Andorian_Imperial_Guard
#  http://stexpanded.wikia.com/Andorian_Imperial_Guard
#
# found:
#  http://memory-alpha.wikia.com/Andorian_battle_cruiser
#  http://stexpanded.wikia.com/Kumari_class
#
# found:
#  http://memory-alpha.wikia.com/Android
#  http://stexpanded.wikia.com/Android
#
# found:
#  http://memory-alpha.wikia.com/Andromeda_Galaxy
#  http://stexpanded.wikia.com/Andromeda_Galaxy
#
# not found:
#  http://stexpanded.wikia.com/Anesthizine
#  http://memory-alpha.wikia.com/Anesthizine
# found instead:
#  http://memory-alpha.wikia.com/Anetrizine
#
# found:
#  http://memory-alpha.wikia.com/Antares_Ship_Yards
#  http://stexpanded.wikia.com/Antares_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Antares_class_(Starfleet)
#  http://memory-alpha.wikia.com/Antares_type
# found instead:
#  http://memory-alpha.wikia.com/USS_Antares
#
# found:
#  http://memory-alpha.wikia.com/Anthropology
#  http://stexpanded.wikia.com/Anthropology
#
# found:
#  http://memory-alpha.wikia.com/Antideuterium
#  http://stexpanded.wikia.com/Anti-deuterium
#
# not found:
#  http://stexpanded.wikia.com/Antimatter
#  http://memory-alpha.wikia.com/Antimatter
# found instead:
#  http://memory-alpha.wikia.com/Antithoron
#
# found:
#  http://memory-alpha.wikia.com/Antwerp
#  http://stexpanded.wikia.com/Antwerp
#
# found:
#  http://memory-alpha.wikia.com/Apollo_class
#  http://stexpanded.wikia.com/Apollo_class
#
# found:
#  http://memory-alpha.wikia.com/Aquiel_Uhnari
#  http://stexpanded.wikia.com/Aquiel_Uhnari
#
# found:
#  http://memory-alpha.wikia.com/Arboretum
#  http://stexpanded.wikia.com/Arboretum
#
# not found:
#  http://stexpanded.wikia.com/Archaeology
#  http://memory-alpha.wikia.com/Archaeology
# found instead:
#  http://memory-alpha.wikia.com/Archaeologist
#
# found:
#  http://memory-alpha.wikia.com/Archaeology_and_anthropology_officer
#  http://stexpanded.wikia.com/Archaeology_and_anthropology_officer
#
# found:
#  http://memory-alpha.wikia.com/Archanis_sector
#  http://stexpanded.wikia.com/Archanis_sector
#
# found:
#  http://memory-alpha.wikia.com/Architecture
#  http://stexpanded.wikia.com/Architecture
#
# found:
#  http://memory-alpha.wikia.com/Archon_(starship)
#  http://stexpanded.wikia.com/USS_Archon_(NCC-189)
#
# found:
#  http://memory-alpha.wikia.com/Arex
#  http://stexpanded.wikia.com/Arex
#
# not found:
#  http://stexpanded.wikia.com/Argo_type
#  http://memory-alpha.wikia.com/Argo_(shuttlecraft)
# found instead:
#  http://memory-alpha.wikia.com/Type_8_shuttlecraft
#
# found:
#  http://memory-alpha.wikia.com/Argolis_Cluster
#  http://stexpanded.wikia.com/Argolis_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Argus_X
#  http://stexpanded.wikia.com/Argus_X
#
# found:
#  http://memory-alpha.wikia.com/Ariannus
#  http://stexpanded.wikia.com/Ariannus
#
# found:
#  http://memory-alpha.wikia.com/Arkonian
#  http://stexpanded.wikia.com/Arkonian
#
# found:
#  http://memory-alpha.wikia.com/Armory
#  http://stexpanded.wikia.com/Armory
#
# found:
#  http://memory-alpha.wikia.com/Armory_officer
#  http://stexpanded.wikia.com/Armory_officer
#
# not found:
#  http://stexpanded.wikia.com/USS_Armstrong_(NCC-57537)
#  http://memory-alpha.wikia.com/Armstrong_(disambiguation)
# found instead:
#  http://memory-alpha.wikia.com/USS_Neil_Armstrong
#
# found:
#  http://memory-alpha.wikia.com/Armus
#  http://stexpanded.wikia.com/Armus
#
# found:
#  http://memory-alpha.wikia.com/Artificial_intelligence
#  http://stexpanded.wikia.com/Artificial_intelligence
#
# not found:
#  http://stexpanded.wikia.com/Asia
#  http://memory-alpha.wikia.com/Asia
# found instead:
#  http://memory-alpha.wikia.com/Malaysia
#
# found:
#  http://memory-alpha.wikia.com/Assault_team
#  http://stexpanded.wikia.com/Assault_team
#
# found:
#  http://memory-alpha.wikia.com/Assignment_patch
#  http://stexpanded.wikia.com/Assignment_patch
#
# found:
#  http://memory-alpha.wikia.com/Assimilation
#  http://stexpanded.wikia.com/Assimilation
#
# found:
#  http://memory-alpha.wikia.com/Assistant_chief_engineer
#  http://stexpanded.wikia.com/Assistant_chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Asteroid
#  http://stexpanded.wikia.com/Asteroid
#
# found:
#  http://memory-alpha.wikia.com/Astrometrics
#  http://stexpanded.wikia.com/Astrometrics
#
# found:
#  http://memory-alpha.wikia.com/Atlanta
#  http://stexpanded.wikia.com/Atlanta
#
# found:
#  http://memory-alpha.wikia.com/Atlantic_Ocean
#  http://stexpanded.wikia.com/Atlantic_Ocean
#
# found:
#  http://memory-alpha.wikia.com/Attack_cruiser
#  http://stexpanded.wikia.com/Attack_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Attack_fighter
#  http://stexpanded.wikia.com/Attack_fighter
#
# found:
#  http://memory-alpha.wikia.com/Auction
#  http://stexpanded.wikia.com/Auction
#
# not found:
#  http://stexpanded.wikia.com/Audrid_Dax
#  http://memory-alpha.wikia.com/Audrid_Dax
# found instead:
#  http://memory-alpha.wikia.com/Lela_Dax
#
# found:
#  http://memory-alpha.wikia.com/Augment
#  http://stexpanded.wikia.com/Augment
#
# found:
#  http://memory-alpha.wikia.com/Aurelian
#  http://stexpanded.wikia.com/Aurelian
#
# found:
#  http://memory-alpha.wikia.com/Australia
#  http://stexpanded.wikia.com/Australia
#
# found:
#  http://memory-alpha.wikia.com/Autarch
#  http://stexpanded.wikia.com/Autarch
#
# found:
#  http://memory-alpha.wikia.com/Auto-destruct
#  http://stexpanded.wikia.com/Auto-destruct
#
# found:
#  http://memory-alpha.wikia.com/Auxiliary_space_vessel
#  http://stexpanded.wikia.com/Auxiliary_craft
#
# found:
#  http://memory-alpha.wikia.com/Avenal_VII
#  http://stexpanded.wikia.com/Avenal_VII
#
# found:
#  http://memory-alpha.wikia.com/Away_mission
#  http://stexpanded.wikia.com/Away_mission
#
# found:
#  http://memory-alpha.wikia.com/Away_team
#  http://stexpanded.wikia.com/Away_team
#
# not found:
#  http://stexpanded.wikia.com/Axanar
#  http://memory-alpha.wikia.com/Axanar
# found instead:
#  http://memory-alpha.wikia.com/Axanar_Starbase_Terminal
#
# found:
#  http://memory-alpha.wikia.com/Azetbur
#  http://stexpanded.wikia.com/Azetbur
#
# found:
#  http://memory-alpha.wikia.com/B%27Elanna_Torres
#  http://stexpanded.wikia.com/B%27Elanna_Torres
#
# found:
#  http://memory-alpha.wikia.com/B.G._Robinson
#  http://stexpanded.wikia.com/B.G._Robinson
#
# not found:
#  http://stexpanded.wikia.com/Ba%27ku
#  http://memory-alpha.wikia.com/Ba%27ku
# found instead:
#  http://memory-alpha.wikia.com/Ba%27ku_(star)
#
# not found:
#  http://stexpanded.wikia.com/Badlands
#  http://memory-alpha.wikia.com/Badlands
# found instead:
#  http://memory-alpha.wikia.com/Etymology
#
# found:
#  http://memory-alpha.wikia.com/Baikonur_Cosmodrome
#  http://stexpanded.wikia.com/Baikonur_Cosmodrome
#
# found:
#  http://memory-alpha.wikia.com/Bajor
#  http://stexpanded.wikia.com/Bajor
#
# found:
#  http://memory-alpha.wikia.com/Bajor_sector
#  http://stexpanded.wikia.com/Bajor_sector
#
# found:
#  http://memory-alpha.wikia.com/Bajoran
#  http://stexpanded.wikia.com/Bajoran
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_Militia
#  http://memory-alpha.wikia.com/Bajoran_Militia
# found instead:
#  http://memory-alpha.wikia.com/Category:Bajoran_Militia_personnel
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Republic
#  http://stexpanded.wikia.com/Bajoran_Provisional_Government
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Resistance
#  http://stexpanded.wikia.com/Bajoran_Resistance
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_language
#  http://stexpanded.wikia.com/Bajoran_language
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_ranks
#  http://memory-alpha.wikia.com/Bajoran_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_religion
#  http://stexpanded.wikia.com/Bajoran_religion
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_system
#  http://memory-alpha.wikia.com/Bajoran_system
# found instead:
#  http://memory-alpha.wikia.com/Bajoran
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_wormhole
#  http://stexpanded.wikia.com/Bajoran_wormhole
#
# not found:
#  http://stexpanded.wikia.com/Bar
#  http://memory-alpha.wikia.com/Bar
# found instead:
#  http://memory-alpha.wikia.com/Tavern
#
# found:
#  http://memory-alpha.wikia.com/Barkonian
#  http://stexpanded.wikia.com/Barkonian
#
# found:
#  http://memory-alpha.wikia.com/Barnard%27s_Star
#  http://stexpanded.wikia.com/Barnard%27s_Star
#
# found:
#  http://memory-alpha.wikia.com/Barstow_(Commodore)
#  http://stexpanded.wikia.com/Barstow
#
# not found:
#  http://stexpanded.wikia.com/Bartender
#  http://memory-alpha.wikia.com/Bartender
# found instead:
#  http://memory-alpha.wikia.com/Waiter
#
# not found:
#  http://stexpanded.wikia.com/Baseball
#  http://memory-alpha.wikia.com/Baseball
# found instead:
#  http://memory-alpha.wikia.com/Soccer
#
# found:
#  http://memory-alpha.wikia.com/Basketball
#  http://stexpanded.wikia.com/Basketball
#
# found:
#  http://memory-alpha.wikia.com/Bat%27leth
#  http://stexpanded.wikia.com/Bat%27leth
#
# found:
#  http://memory-alpha.wikia.com/Battle_cruiser
#  http://stexpanded.wikia.com/Battle_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Axanar
#  http://stexpanded.wikia.com/Battle_of_Axanar
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Betazed
#  http://stexpanded.wikia.com/Battle_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cardassia
#  http://stexpanded.wikia.com/Battle_of_Cardassia
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cheron
#  http://stexpanded.wikia.com/Battle_of_Cheron
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Klach_D%27kel_Brakt
#  http://stexpanded.wikia.com/Battle_of_Klach_D%27kel_Brakt
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Procyon_V
#  http://stexpanded.wikia.com/Battle_of_Procyon_V
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Ricktor_Prime
#  http://stexpanded.wikia.com/Battle_of_Ricktor_Prime
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Sector_001
#  http://stexpanded.wikia.com/Battle_of_Sector_001
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_the_Omarion_Nebula
#  http://stexpanded.wikia.com/Battle_of_the_Omarion_Nebula
#
# found:
#  http://memory-alpha.wikia.com/Battleship
#  http://stexpanded.wikia.com/Battleship
#
# found:
#  http://memory-alpha.wikia.com/Beer
#  http://stexpanded.wikia.com/Beer
#
# found:
#  http://memory-alpha.wikia.com/Bekk
#  http://stexpanded.wikia.com/Bekk
#
# found:
#  http://memory-alpha.wikia.com/Belgium
#  http://stexpanded.wikia.com/Belgium
#
# found:
#  http://memory-alpha.wikia.com/Bendii_Syndrome
#  http://stexpanded.wikia.com/Bendii_Syndrome
#
# found:
#  http://memory-alpha.wikia.com/Benecia_Colony
#  http://stexpanded.wikia.com/Benecia_Colony
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Finney
#  http://stexpanded.wikia.com/Ben_Finney
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Maxwell
#  http://stexpanded.wikia.com/Benjamin_Maxwell
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Sisko
#  http://stexpanded.wikia.com/Benjamin_Sisko
#
# found:
#  http://memory-alpha.wikia.com/Benny_Russell
#  http://stexpanded.wikia.com/Benny_Russell
#
# found:
#  http://memory-alpha.wikia.com/Benzar
#  http://stexpanded.wikia.com/Benzar
#
# not found:
#  http://stexpanded.wikia.com/Benzenite
#  http://memory-alpha.wikia.com/Benzenite
# found instead:
#  http://memory-alpha.wikia.com/Magnesite
#
# found:
#  http://memory-alpha.wikia.com/Benzite_system
#  http://stexpanded.wikia.com/Benzite_system
#
# found:
#  http://memory-alpha.wikia.com/Berengaria_VII
#  http://stexpanded.wikia.com/Berengaria_VII
#
# not found:
#  http://stexpanded.wikia.com/Berlin
#  http://memory-alpha.wikia.com/Berlin
# found instead:
#  http://memory-alpha.wikia.com/Berlin_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Berlinghoff_Rasmussen
#  http://stexpanded.wikia.com/Berlinghoff_Rasmussen
#
# found:
#  http://memory-alpha.wikia.com/Berthold_ray
#  http://stexpanded.wikia.com/Berthold_ray
#
# found:
#  http://memory-alpha.wikia.com/Beta_Antares_Ship_Yards
#  http://stexpanded.wikia.com/Beta_Antares_Ship_Yards
#
# found:
#  http://memory-alpha.wikia.com/Beta_Quadrant
#  http://stexpanded.wikia.com/Beta_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Beverly_Crusher
#  http://memory-alpha.wikia.com/Beverly_Crusher
# found instead:
#  http://memory-alpha.wikia.com/Gates_McFadden
#
# found:
#  http://memory-alpha.wikia.com/Bible
#  http://stexpanded.wikia.com/Bible
#
# found:
#  http://memory-alpha.wikia.com/Bilitrium
#  http://stexpanded.wikia.com/Bilitrium
#
# found:
#  http://memory-alpha.wikia.com/Bio-dampener
#  http://stexpanded.wikia.com/Bio-dampener
#
# found:
#  http://memory-alpha.wikia.com/Bio-neural_circuitry
#  http://stexpanded.wikia.com/Bio-neural_circuitry
#
# found:
#  http://memory-alpha.wikia.com/Biosynthetic_limb
#  http://stexpanded.wikia.com/Biosynthetic_limb
#
# found:
#  http://memory-alpha.wikia.com/Bird-of-Prey
#  http://stexpanded.wikia.com/Bird-of-Prey
#
# not found:
#  http://stexpanded.wikia.com/Birthday
#  http://memory-alpha.wikia.com/Birthday
# found instead:
#  http://memory-alpha.wikia.com/Birthday_party
#
# not found:
#  http://stexpanded.wikia.com/Black_hole
#  http://memory-alpha.wikia.com/Black_hole
# found instead:
#  http://memory-alpha.wikia.com/Black_star
#
# found:
#  http://memory-alpha.wikia.com/Bloodwine
#  http://stexpanded.wikia.com/Bloodwine
#
# found:
#  http://memory-alpha.wikia.com/Blue_alert
#  http://stexpanded.wikia.com/Blue_alert
#
# found:
#  http://memory-alpha.wikia.com/Bolarus_IX
#  http://stexpanded.wikia.com/Bolarus_IX
#
# found:
#  http://memory-alpha.wikia.com/Bolian
#  http://stexpanded.wikia.com/Bolian
#
# not found:
#  http://stexpanded.wikia.com/SS_Bonaventure
#  http://memory-alpha.wikia.com/Bonaventure
# found instead:
#  http://memory-alpha.wikia.com/Bonaventure_(C1-21)
#
# not found:
#  http://stexpanded.wikia.com/Boothby
#  http://memory-alpha.wikia.com/Boothby
# found instead:
#  http://memory-alpha.wikia.com/Boothby_(Species_8472)
#
# not found:
#  http://stexpanded.wikia.com/Borath
#  http://memory-alpha.wikia.com/Borath
# found instead:
#  http://memory-alpha.wikia.com/Vorta
#
# found:
#  http://memory-alpha.wikia.com/Border
#  http://stexpanded.wikia.com/Border
#
# not found:
#  http://stexpanded.wikia.com/Borg
#  http://memory-alpha.wikia.com/Borg
# found instead:
#  http://memory-alpha.wikia.com/Best_of_the_Borg
#
# not found:
#  http://stexpanded.wikia.com/Borg_Collective
#  http://memory-alpha.wikia.com/Borg_Collective
# found instead:
#  http://memory-alpha.wikia.com/Borg_drone
#
# found:
#  http://memory-alpha.wikia.com/Borg_Queen
#  http://stexpanded.wikia.com/Borg_Queen
#
# found:
#  http://memory-alpha.wikia.com/Borg_cube
#  http://stexpanded.wikia.com/Borg_cube
#
# found:
#  http://memory-alpha.wikia.com/Borg_drone
#  http://stexpanded.wikia.com/Borg_drone
#
# found:
#  http://memory-alpha.wikia.com/Borg_probe
#  http://stexpanded.wikia.com/Borg_probe
#
# found:
#  http://memory-alpha.wikia.com/Borg_sphere
#  http://stexpanded.wikia.com/Borg_sphere
#
# found:
#  http://memory-alpha.wikia.com/Borg_tactical_cube
#  http://stexpanded.wikia.com/Borg_tactical_cube
#
# found:
#  http://memory-alpha.wikia.com/Borias_Cluster
#  http://stexpanded.wikia.com/Borias_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Bowsers
#  http://stexpanded.wikia.com/Bowser
#
# found:
#  http://memory-alpha.wikia.com/Boy_Scout
#  http://stexpanded.wikia.com/Boy_Scouts
#
# found:
#  http://memory-alpha.wikia.com/Bradbury_class
#  http://stexpanded.wikia.com/Bradbury_class
#
# found:
#  http://memory-alpha.wikia.com/Braxton
#  http://stexpanded.wikia.com/Braxton
#
# found:
#  http://memory-alpha.wikia.com/Bread
#  http://stexpanded.wikia.com/Bread
#
# found:
#  http://memory-alpha.wikia.com/Breen
#  http://stexpanded.wikia.com/Breen
#
# found:
#  http://memory-alpha.wikia.com/Breen_(planet)
#  http://stexpanded.wikia.com/Breen_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Breen_Confederacy
#  http://stexpanded.wikia.com/Breen_Confederacy
#
# found:
#  http://memory-alpha.wikia.com/Breen_attack_on_Earth
#  http://stexpanded.wikia.com/Breen_attack_on_Earth
#
# found:
#  http://memory-alpha.wikia.com/Breen_warship
#  http://stexpanded.wikia.com/Gor_Taan_class
#
# found:
#  http://memory-alpha.wikia.com/Briar_Patch
#  http://stexpanded.wikia.com/Briar_Patch
#
# not found:
#  http://stexpanded.wikia.com/Bridge
#  http://memory-alpha.wikia.com/Bridge
# found instead:
#  http://memory-alpha.wikia.com/Bridge_officer
#
# found:
#  http://memory-alpha.wikia.com/Bridge_Officer%27s_Test
#  http://stexpanded.wikia.com/Bridge_Officer%27s_Test
#
# found:
#  http://memory-alpha.wikia.com/Bridge_officer
#  http://stexpanded.wikia.com/Bridge_officer
#
# not found:
#  http://stexpanded.wikia.com/Brig
#  http://memory-alpha.wikia.com/Brig
# found instead:
#  http://memory-alpha.wikia.com/Security_holding_area
#
# not found:
#  http://stexpanded.wikia.com/Brigadier_general
#  http://memory-alpha.wikia.com/Brigadier
# found instead:
#  http://memory-alpha.wikia.com/General
#
# not found:
#  http://stexpanded.wikia.com/Briori
#  http://memory-alpha.wikia.com/Briori
# found instead:
#  http://memory-alpha.wikia.com/1937
#
# found:
#  http://memory-alpha.wikia.com/Brisbane
#  http://stexpanded.wikia.com/Brisbane
#
# found:
#  http://memory-alpha.wikia.com/Bruce_Maddox
#  http://stexpanded.wikia.com/Bruce_Maddox
#
# found:
#  http://memory-alpha.wikia.com/Brussels
#  http://stexpanded.wikia.com/Brussels
#
# found:
#  http://memory-alpha.wikia.com/Bryma
#  http://stexpanded.wikia.com/Bryma
#
# not found:
#  http://stexpanded.wikia.com/Cadet
#  http://memory-alpha.wikia.com/Cadet
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_cadets
#
# found:
#  http://memory-alpha.wikia.com/Cait
#  http://stexpanded.wikia.com/Cait
#
# not found:
#  http://stexpanded.wikia.com/Caitian
#  http://memory-alpha.wikia.com/Caitian
# found instead:
#  http://memory-alpha.wikia.com/Cait
#
# found:
#  http://memory-alpha.wikia.com/California
#  http://stexpanded.wikia.com/California
#
# not found:
#  http://stexpanded.wikia.com/Calvin_Hudson
#  http://memory-alpha.wikia.com/Calvin_Hudson
# found instead:
#  http://memory-alpha.wikia.com/Tyler_(male)
#
# found:
#  http://memory-alpha.wikia.com/Canberra
#  http://stexpanded.wikia.com/Canberra
#
# not found:
#  http://stexpanded.wikia.com/Canon
#  http://memory-alpha.wikia.com/Canon
# found instead:
#  http://memory-alpha.wikia.com/Fan_fiction
#
# found:
#  http://memory-alpha.wikia.com/Canopus_III
#  http://stexpanded.wikia.com/Canopus_III
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_dining_room
#  http://stexpanded.wikia.com/Captain%27s_dining_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_ready_room
#  http://stexpanded.wikia.com/Captain%27s_ready_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_yacht
#  http://stexpanded.wikia.com/Captain%27s_yacht
#
# found:
#  http://memory-alpha.wikia.com/Captain_of_engineering
#  http://stexpanded.wikia.com/Captain_of_Engineering
#
# not found:
#  http://stexpanded.wikia.com/Cardassia_Prime
#  http://memory-alpha.wikia.com/Cardassia_Prime
# found instead:
#  http://memory-alpha.wikia.com/Sorna_Prime
#
# not found:
#  http://stexpanded.wikia.com/Cardassian
#  http://memory-alpha.wikia.com/Cardassian
# found instead:
#  http://memory-alpha.wikia.com/Cardassians
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Central_Command
#  http://stexpanded.wikia.com/Cardassian_Central_Command
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Liberation_Front
#  http://stexpanded.wikia.com/Cardassian_Rebellion
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Union
#  http://stexpanded.wikia.com/Cardassian_Union
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_dissident_movement
#  http://stexpanded.wikia.com/Cardassian_dissident_movement
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_neck_trick
#  http://stexpanded.wikia.com/Cardassian_neck_trick
#
# not found:
#  http://stexpanded.wikia.com/Cardassian_ranks
#  http://memory-alpha.wikia.com/Cardassian_ranks
# found instead:
#  http://memory-alpha.wikia.com/Legate
#
# not found:
#  http://stexpanded.wikia.com/Caretaker_(MCNL)
#  http://memory-alpha.wikia.com/Caretaker_(episode)
# found instead:
#  http://memory-alpha.wikia.com/Phage_(episode)
#
# found:
#  http://memory-alpha.wikia.com/Cargo_bay
#  http://stexpanded.wikia.com/Cargo_bay
#
# not found:
#  http://stexpanded.wikia.com/Work_bee
#  http://memory-alpha.wikia.com/Cargo_management_unit
# found instead:
#  http://memory-alpha.wikia.com/Workbee_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Regnancy_of_the_Carnelian_Throne
#  http://memory-alpha.wikia.com/Carnelian_minefield
# found instead:
#  http://memory-alpha.wikia.com/Spartacus
#
# found:
#  http://memory-alpha.wikia.com/Carol_Marcus
#  http://stexpanded.wikia.com/Carol_Marcus
#
# found:
#  http://memory-alpha.wikia.com/Carrington_Award
#  http://stexpanded.wikia.com/Carrington_Award
#
# found:
#  http://memory-alpha.wikia.com/Carson_(Ensign)
#  http://stexpanded.wikia.com/Sara_Carson
#
# found:
#  http://memory-alpha.wikia.com/Cartwright
#  http://stexpanded.wikia.com/Cartwright
#
# found:
#  http://memory-alpha.wikia.com/Casino
#  http://stexpanded.wikia.com/Casino
#
# found:
#  http://memory-alpha.wikia.com/Casperia_Prime
#  http://stexpanded.wikia.com/Casperia_Prime
#
# found:
#  http://memory-alpha.wikia.com/Cat
#  http://stexpanded.wikia.com/Cat
#
# not found:
#  http://stexpanded.wikia.com/Cell_(group)
#  http://memory-alpha.wikia.com/Cell
# found instead:
#  http://memory-alpha.wikia.com/Cell_(organization)
#
# found:
#  http://memory-alpha.wikia.com/Centaur_type
#  http://stexpanded.wikia.com/Centaur_class
#
# found:
#  http://memory-alpha.wikia.com/Central_University
#  http://stexpanded.wikia.com/Central_University
#
# not found:
#  http://stexpanded.wikia.com/Centurion
#  http://memory-alpha.wikia.com/Centurion
# found instead:
#  http://memory-alpha.wikia.com/Lieutenant_commander
#
# found:
#  http://memory-alpha.wikia.com/Cestus_III
#  http://stexpanded.wikia.com/Cestus_III
#
# found:
#  http://memory-alpha.wikia.com/Ceti_Alpha_V
#  http://stexpanded.wikia.com/Ceti_Alpha_V
#
# not found:
#  http://stexpanded.wikia.com/Chakotay
#  http://memory-alpha.wikia.com/Chakotay
# found instead:
#  http://memory-alpha.wikia.com/Patrick_Stewart_(Starfleet)
#
# found:
#  http://memory-alpha.wikia.com/Challenger_class
#  http://stexpanded.wikia.com/Challenger_class
#
# found:
#  http://memory-alpha.wikia.com/Champagne
#  http://stexpanded.wikia.com/Champagne
#
# found:
#  http://memory-alpha.wikia.com/Chancellor_of_the_Klingon_High_Council
#  http://stexpanded.wikia.com/Chancellor_of_the_Klingon_High_Council
#
# not found:
#  http://stexpanded.wikia.com/IKS_Che%27gra
#  http://memory-alpha.wikia.com/Chang%27s_Bird-of-Prey
# found instead:
#  http://memory-alpha.wikia.com/IKS_Hor%27Cha
#
# found:
#  http://memory-alpha.wikia.com/Change_of_Command
#  http://stexpanded.wikia.com/Change_of_Command
#
# not found:
#  http://stexpanded.wikia.com/Changeling
#  http://memory-alpha.wikia.com/Changeling
# found instead:
#  http://memory-alpha.wikia.com/Solids
#
# found:
#  http://memory-alpha.wikia.com/Charlene_Masters
#  http://stexpanded.wikia.com/Charlene_Masters
#
# found:
#  http://memory-alpha.wikia.com/Charles_Tucker_III
#  http://stexpanded.wikia.com/Charles_Tucker_III
#
# not found:
#  http://stexpanded.wikia.com/Chef
#  http://memory-alpha.wikia.com/Chef
# found instead:
#  http://memory-alpha.wikia.com/Cook_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Chell
#  http://stexpanded.wikia.com/Chell
#
# found:
#  http://memory-alpha.wikia.com/Cheyenne_class
#  http://stexpanded.wikia.com/Cheyenne_class
#
# found:
#  http://memory-alpha.wikia.com/Chicago
#  http://stexpanded.wikia.com/Chicago
#
# not found:
#  http://stexpanded.wikia.com/Chief
#  http://memory-alpha.wikia.com/Chief
# found instead:
#  http://memory-alpha.wikia.com/Chief_engineering_officer
#
# found:
#  http://memory-alpha.wikia.com/Chief_engineering_officer
#  http://stexpanded.wikia.com/Chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Chief_medical_officer
#  http://stexpanded.wikia.com/Chief_medical_officer
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Operations
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Security
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Security
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_operations
#  http://stexpanded.wikia.com/Chief_of_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_security
#  http://stexpanded.wikia.com/Security_chief
#
# found:
#  http://memory-alpha.wikia.com/Chin%27toka_system
#  http://stexpanded.wikia.com/Chin%27toka_system
#
# not found:
#  http://stexpanded.wikia.com/China
#  http://memory-alpha.wikia.com/China
# found instead:
#  http://memory-alpha.wikia.com/Russia
#
# found:
#  http://memory-alpha.wikia.com/Christchurch
#  http://stexpanded.wikia.com/Christchurch
#
# found:
#  http://memory-alpha.wikia.com/Christianity
#  http://stexpanded.wikia.com/Christianity
#
# found:
#  http://memory-alpha.wikia.com/Christine_Chapel
#  http://stexpanded.wikia.com/Christine_Chapel
#
# found:
#  http://memory-alpha.wikia.com/Christmas
#  http://stexpanded.wikia.com/Christmas
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike
#  http://memory-alpha.wikia.com/Christopher_Pike
# found instead:
#  http://memory-alpha.wikia.com/Christopher_Pike_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_(alternate_reality)
#  http://stexpanded.wikia.com/Christopher_Pike_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike_(mirror)
#  http://memory-alpha.wikia.com/Christopher_Pike_(mirror)
# found instead:
#  http://memory-alpha.wikia.com/Mirror_universe
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_Medal_of_Valor
#  http://stexpanded.wikia.com/Christopher_Pike_Medal_of_Valor
#
# found:
#  http://memory-alpha.wikia.com/Chroniton
#  http://stexpanded.wikia.com/Chroniton
#
# found:
#  http://memory-alpha.wikia.com/Chroniton_radiation
#  http://stexpanded.wikia.com/Chroniton_radiation
#
# found:
#  http://memory-alpha.wikia.com/Chronometric_particle
#  http://stexpanded.wikia.com/Chronometric_particle
#
# found:
#  http://memory-alpha.wikia.com/City
#  http://stexpanded.wikia.com/City
#
# found:
#  http://memory-alpha.wikia.com/Clark_Terrell
#  http://stexpanded.wikia.com/Clark_Terrell
#
# found:
#  http://memory-alpha.wikia.com/Clarke%27s_Disease
#  http://stexpanded.wikia.com/Clarke%27s_Disease
#
# found:
#  http://memory-alpha.wikia.com/Class_4_probe
#  http://stexpanded.wikia.com/Class_4_probe
#
# found:
#  http://memory-alpha.wikia.com/Class_D
#  http://stexpanded.wikia.com/Class_D_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_H
#  http://stexpanded.wikia.com/Class_H_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_J_planet
#  http://stexpanded.wikia.com/Class_J_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_L
#  http://stexpanded.wikia.com/Class_L_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_M
#  http://stexpanded.wikia.com/Class_M_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_N
#  http://stexpanded.wikia.com/Class_N_planet
#
# not found:
#  http://stexpanded.wikia.com/Cloaking_device
#  http://memory-alpha.wikia.com/Cloaking_device
# found instead:
#  http://memory-alpha.wikia.com/Cloak_(clothing)
#
# found:
#  http://memory-alpha.wikia.com/Clone
#  http://stexpanded.wikia.com/Clone
#
# found:
#  http://memory-alpha.wikia.com/Coalition_of_Planets
#  http://stexpanded.wikia.com/Coalition_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/Coaxial_warp_drive
#  http://stexpanded.wikia.com/Coaxial_warp_drive
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_Medal_of_Excellence
#  http://memory-alpha.wikia.com/Cochrane_Medal_of_Excellence
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_Medal_of_Commendation
#
# found:
#  http://memory-alpha.wikia.com/Code_47
#  http://stexpanded.wikia.com/Code_47
#
# found:
#  http://memory-alpha.wikia.com/Coffee
#  http://stexpanded.wikia.com/Coffee
#
# not found:
#  http://stexpanded.wikia.com/Coffin
#  http://memory-alpha.wikia.com/Coffin
# found instead:
#  http://memory-alpha.wikia.com/Graveyard
#
# found:
#  http://memory-alpha.wikia.com/Cold_Station_12
#  http://stexpanded.wikia.com/Cold_Station_12
#
# found:
#  http://memory-alpha.wikia.com/Cold_start
#  http://stexpanded.wikia.com/Cold_start
#
# found:
#  http://memory-alpha.wikia.com/Colonel
#  http://stexpanded.wikia.com/Colonel
#
# not found:
#  http://stexpanded.wikia.com/Colony
#  http://memory-alpha.wikia.com/Colony
# found instead:
#  http://memory-alpha.wikia.com/Colony_(ant)
#
# found:
#  http://memory-alpha.wikia.com/Colorado
#  http://stexpanded.wikia.com/Colorado
#
# found:
#  http://memory-alpha.wikia.com/Columbia
#  http://stexpanded.wikia.com/Columbia_(NX-02)
#
# found:
#  http://memory-alpha.wikia.com/Combadge
#  http://stexpanded.wikia.com/Combadge
#
# found:
#  http://memory-alpha.wikia.com/Comet
#  http://stexpanded.wikia.com/Comet
#
# not found:
#  http://stexpanded.wikia.com/Command_chair
#  http://memory-alpha.wikia.com/Command_chair
# found instead:
#  http://memory-alpha.wikia.com/Star_Trek:_Captain%27s_Chair
#
# found:
#  http://memory-alpha.wikia.com/Command_division
#  http://stexpanded.wikia.com/Command_division
#
# not found:
#  http://stexpanded.wikia.com/Commandant
#  http://memory-alpha.wikia.com/Commandant
# found instead:
#  http://memory-alpha.wikia.com/Commandante_Cadets
#
# not found:
#  http://stexpanded.wikia.com/Commander
#  http://memory-alpha.wikia.com/Commander
# found instead:
#  http://memory-alpha.wikia.com/Sub-commander
#
# found:
#  http://memory-alpha.wikia.com/Commander_in_chief
#  http://stexpanded.wikia.com/Commander-in-Chief
#
# not found:
#  http://stexpanded.wikia.com/Commanding_officer
#  http://memory-alpha.wikia.com/Commanding_officer
# found instead:
#  http://memory-alpha.wikia.com/Ranking_officer
#
# found:
#  http://memory-alpha.wikia.com/Commodore
#  http://stexpanded.wikia.com/Commodore
#
# not found:
#  http://stexpanded.wikia.com/Communications
#  http://memory-alpha.wikia.com/Communications
# found instead:
#  http://memory-alpha.wikia.com/Communications_(course)
#
# found:
#  http://memory-alpha.wikia.com/Communications_officer
#  http://stexpanded.wikia.com/Communications_officer
#
# not found:
#  http://stexpanded.wikia.com/Computer
#  http://memory-alpha.wikia.com/Computer
# found instead:
#  http://memory-alpha.wikia.com/Database
#
# not found:
#  http://stexpanded.wikia.com/Conference_room
#  http://memory-alpha.wikia.com/Conference_room
# found instead:
#  http://memory-alpha.wikia.com/Briefing_room
#
# found:
#  http://memory-alpha.wikia.com/Conflicts
#  http://stexpanded.wikia.com/Conflicts
#
# found:
#  http://memory-alpha.wikia.com/Constellation_class
#  http://stexpanded.wikia.com/Constellation_class
#
# not found:
#  http://stexpanded.wikia.com/USS_Valkyrie_(NCC-2590)
#  http://memory-alpha.wikia.com/Constellation_class_model
# found instead:
#  http://memory-alpha.wikia.com/USS_Stargazer
#
# found:
#  http://memory-alpha.wikia.com/Constitution_class
#  http://stexpanded.wikia.com/Constitution_class
#
# found:
#  http://memory-alpha.wikia.com/Continent
#  http://stexpanded.wikia.com/Continent
#
# found:
#  http://memory-alpha.wikia.com/Convoy
#  http://stexpanded.wikia.com/Convoy
#
# found:
#  http://memory-alpha.wikia.com/Copernicus_Ship_Yards
#  http://stexpanded.wikia.com/Copernicus_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Coridan
#  http://memory-alpha.wikia.com/Coridan
# found instead:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#  http://stexpanded.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Corporal
#  http://stexpanded.wikia.com/Corporal
#
# not found:
#  http://stexpanded.wikia.com/Corsair
#  http://memory-alpha.wikia.com/Corsair
# found instead:
#  http://memory-alpha.wikia.com/Frigate
#
# found:
#  http://memory-alpha.wikia.com/Cortical_stimulator
#  http://stexpanded.wikia.com/Cortical_stimulator
#
# found:
#  http://memory-alpha.wikia.com/Council_of_Ministers
#  http://stexpanded.wikia.com/Council_of_Ministers
#
# not found:
#  http://stexpanded.wikia.com/Counselor
#  http://memory-alpha.wikia.com/Counselor
# found instead:
#  http://memory-alpha.wikia.com/Assistant_ship%27s_counselor
#
# found:
#  http://memory-alpha.wikia.com/Country
#  http://stexpanded.wikia.com/Country
#
# found:
#  http://memory-alpha.wikia.com/Coup_d%27état
#  http://stexpanded.wikia.com/Coup_d%27état
#
# not found:
#  http://stexpanded.wikia.com/Court-martial
#  http://memory-alpha.wikia.com/Court_martial
# found instead:
#  http://memory-alpha.wikia.com/Judges_and_arbiters
#
# found:
#  http://memory-alpha.wikia.com/Crewman
#  http://stexpanded.wikia.com/Crewman
#
# found:
#  http://memory-alpha.wikia.com/Cruiser
#  http://stexpanded.wikia.com/Cruiser
#
# found:
#  http://memory-alpha.wikia.com/Cryogenic_stasis
#  http://stexpanded.wikia.com/Cryogenic_stasis
#
# not found:
#  http://stexpanded.wikia.com/Cryosatellite
#  http://memory-alpha.wikia.com/Cryonics_satellite
# found instead:
#  http://memory-alpha.wikia.com/Cryostasis_chamber
#
# found:
#  http://memory-alpha.wikia.com/Cuellar_system
#  http://stexpanded.wikia.com/Cuellar_system
#
# found:
#  http://memory-alpha.wikia.com/Cutting_beam
#  http://stexpanded.wikia.com/Cutting_beam
#
# found:
#  http://memory-alpha.wikia.com/Cygnet_XIV
#  http://stexpanded.wikia.com/Cygnet_XIV
#
# found:
#  http://memory-alpha.wikia.com/D%27Kora_class
#  http://stexpanded.wikia.com/D%27Kora_class
#
# found:
#  http://memory-alpha.wikia.com/D%27deridex_class
#  http://stexpanded.wikia.com/D%27deridex_class
#
# found:
#  http://memory-alpha.wikia.com/D%27jarra
#  http://stexpanded.wikia.com/D%27jarra
#
# found:
#  http://memory-alpha.wikia.com/D7_class
#  http://stexpanded.wikia.com/D7_class
#
# found:
#  http://memory-alpha.wikia.com/DNA
#  http://stexpanded.wikia.com/DNA
#
# found:
#  http://memory-alpha.wikia.com/Dabo
#  http://stexpanded.wikia.com/Dabo
#
# found:
#  http://memory-alpha.wikia.com/DaiMon
#  http://stexpanded.wikia.com/DaiMon
#
# found:
#  http://memory-alpha.wikia.com/Dakar
#  http://stexpanded.wikia.com/Dakar_(city)
#
# found:
#  http://memory-alpha.wikia.com/Damage_control_team
#  http://stexpanded.wikia.com/Damage_control
#
# not found:
#  http://stexpanded.wikia.com/Damar
#  http://memory-alpha.wikia.com/Damar
# found instead:
#  http://memory-alpha.wikia.com/Rusot
#
# found:
#  http://memory-alpha.wikia.com/Dampening_field
#  http://stexpanded.wikia.com/Dampening_field
#
# found:
#  http://memory-alpha.wikia.com/Dance
#  http://stexpanded.wikia.com/Dance
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Crewman)
#  http://stexpanded.wikia.com/Daniels_(Crewman)
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Lieutenant)
#  http://stexpanded.wikia.com/Daniels_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Danube_class
#  http://stexpanded.wikia.com/Danube_class
#
# found:
#  http://memory-alpha.wikia.com/Danula_II
#  http://stexpanded.wikia.com/Danula_II
#
# found:
#  http://memory-alpha.wikia.com/Dark_matter_nebula
#  http://stexpanded.wikia.com/Dark_matter_nebula
#
# found:
#  http://memory-alpha.wikia.com/Daro
#  http://stexpanded.wikia.com/Daro
#
# found:
#  http://memory-alpha.wikia.com/Data
#  http://stexpanded.wikia.com/Data
#
# found:
#  http://memory-alpha.wikia.com/Dave_Bailey
#  http://stexpanded.wikia.com/Dave_Bailey
#
# not found:
#  http://stexpanded.wikia.com/Dax_(symbiont)
#  http://memory-alpha.wikia.com/Dax_(symbiont)
# found instead:
#  http://memory-alpha.wikia.com/Curzon_Dax
#
# found:
#  http://memory-alpha.wikia.com/Daystrom_Institute
#  http://stexpanded.wikia.com/Daystrom_Institute
#
# found:
#  http://memory-alpha.wikia.com/DePaul
#  http://stexpanded.wikia.com/DePaul
#
# not found:
#  http://stexpanded.wikia.com/DeSalle
#  http://memory-alpha.wikia.com/DeSalle
# found instead:
#  http://memory-alpha.wikia.com/Phase
#
# not found:
#  http://stexpanded.wikia.com/Deanna_Troi
#  http://memory-alpha.wikia.com/Deanna_Troi
# found instead:
#  http://memory-alpha.wikia.com/Mirror_universe_starships
#
# found:
#  http://memory-alpha.wikia.com/Dedication_plaque
#  http://stexpanded.wikia.com/Dedication_plaque
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_3
#  http://stexpanded.wikia.com/Deep_Space_3
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_4
#  http://stexpanded.wikia.com/Deep_Space_4
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_5
#  http://stexpanded.wikia.com/Deep_Space_5
#
# not found:
#  http://stexpanded.wikia.com/Deep_Space_9
#  http://memory-alpha.wikia.com/Deep_Space_9
# found instead:
#  http://memory-alpha.wikia.com/Terok_Nor_(mirror)
#
# not found:
#  http://stexpanded.wikia.com/Venturi
#  http://memory-alpha.wikia.com/Deep_Space_9_visitors
# found instead:
#  http://memory-alpha.wikia.com/Ventu
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_Station_K-7
#  http://stexpanded.wikia.com/Deep_Space_Station_K-7
#
# not found:
#  http://stexpanded.wikia.com/USS_Defiant_(NX-74205)
#  http://memory-alpha.wikia.com/Defiant
# found instead:
#  http://memory-alpha.wikia.com/USS_Defiant_(2370)
#
# found:
#  http://memory-alpha.wikia.com/Defiant_class
#  http://stexpanded.wikia.com/Defiant_class
#
# not found:
#  http://stexpanded.wikia.com/Deflector_shield
#  http://memory-alpha.wikia.com/Deflector_shield
# found instead:
#  http://memory-alpha.wikia.com/Covariant_shielding
#
# not found:
#  http://stexpanded.wikia.com/Degree
#  http://memory-alpha.wikia.com/Degree
# found instead:
#  http://memory-alpha.wikia.com/Diploma
#
# found:
#  http://memory-alpha.wikia.com/Delphic_Expanse
#  http://stexpanded.wikia.com/Delphic_Expanse
#
# not found:
#  http://stexpanded.wikia.com/Delta_Flyer
#  http://memory-alpha.wikia.com/Delta_Flyer
# found instead:
#  http://memory-alpha.wikia.com/Delta_Flyer_type
#
# not found:
#  http://stexpanded.wikia.com/Delta_IV
#  http://memory-alpha.wikia.com/Delta_IV
# found instead:
#  http://memory-alpha.wikia.com/Deltan
#
# not found:
#  http://stexpanded.wikia.com/Delta_Quadrant
#  http://memory-alpha.wikia.com/Delta_Quadrant
# found instead:
#  http://memory-alpha.wikia.com/Beta_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Delta_Vega
#  http://memory-alpha.wikia.com/Delta_Vega
# found instead:
#  http://memory-alpha.wikia.com/Delta_Vega_sector
#
# found:
#  http://memory-alpha.wikia.com/Demilitarized_Zone
#  http://stexpanded.wikia.com/Demilitarized_Zone
#
# found:
#  http://memory-alpha.wikia.com/Demora_Sulu
#  http://stexpanded.wikia.com/Demora_Sulu
#
# not found:
#  http://stexpanded.wikia.com/Deneva
#  http://memory-alpha.wikia.com/Deneva
# found instead:
#  http://memory-alpha.wikia.com/Denevan
#
# found:
#  http://memory-alpha.wikia.com/Denmark
#  http://stexpanded.wikia.com/Denmark
#
# found:
#  http://memory-alpha.wikia.com/Denobula
#  http://stexpanded.wikia.com/Denobula
#
# found:
#  http://memory-alpha.wikia.com/Denobulan
#  http://stexpanded.wikia.com/Denobulan
#
# found:
#  http://memory-alpha.wikia.com/Dentistry
#  http://stexpanded.wikia.com/Dentist
#
# found:
#  http://memory-alpha.wikia.com/Department_of_Cartography
#  http://stexpanded.wikia.com/Department_of_Cartography
#
# found:
#  http://memory-alpha.wikia.com/Department_of_Temporal_Investigations
#  http://stexpanded.wikia.com/Department_of_Temporal_Investigations
#
# found:
#  http://memory-alpha.wikia.com/Dermal_regenerator
#  http://stexpanded.wikia.com/Dermal_regenerator
#
# found:
#  http://memory-alpha.wikia.com/Destroyer
#  http://stexpanded.wikia.com/Destroyer
#
# found:
#  http://memory-alpha.wikia.com/Detapa_Council
#  http://stexpanded.wikia.com/Detapa_Council
#
# found:
#  http://memory-alpha.wikia.com/Deuterium
#  http://stexpanded.wikia.com/Deuterium
#
# found:
#  http://memory-alpha.wikia.com/Devoras
#  http://stexpanded.wikia.com/IRW_Devoras
#
# not found:
#  http://stexpanded.wikia.com/Devore
#  http://memory-alpha.wikia.com/Devore
# found instead:
#  http://memory-alpha.wikia.com/Devore_Imperium
#
# found:
#  http://memory-alpha.wikia.com/Devos_II
#  http://stexpanded.wikia.com/Devos_II
#
# found:
#  http://memory-alpha.wikia.com/DiFalco
#  http://stexpanded.wikia.com/DiFalco
#
# found:
#  http://memory-alpha.wikia.com/Dikironium_cloud_creature
#  http://stexpanded.wikia.com/Dikironium_cloud_creature
#
# found:
#  http://memory-alpha.wikia.com/Dilithium
#  http://stexpanded.wikia.com/Dilithium
#
# found:
#  http://memory-alpha.wikia.com/Diplomacy_and_law
#  http://stexpanded.wikia.com/Diplomacy_and_law
#
# found:
#  http://memory-alpha.wikia.com/Directed_energy_weapon
#  http://stexpanded.wikia.com/Directed-energy_weapon
#
# not found:
#  http://stexpanded.wikia.com/Disruptor
#  http://memory-alpha.wikia.com/Disruptor
# found instead:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#  http://stexpanded.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_pistol
#  http://stexpanded.wikia.com/Disruptor_pistol
#
# not found:
#  http://stexpanded.wikia.com/Disruptor_rifle
#  http://memory-alpha.wikia.com/Disruptor_rifle
# found instead:
#  http://memory-alpha.wikia.com/Klingon_disruptor
#
# not found:
#  http://stexpanded.wikia.com/Distant_past
#  http://memory-alpha.wikia.com/Distant_past
# found instead:
#  http://memory-alpha.wikia.com/3rd_millennium_AD
#
# found:
#  http://memory-alpha.wikia.com/Distress_call
#  http://stexpanded.wikia.com/Distress_call
#
# found:
#  http://memory-alpha.wikia.com/Dividices
#  http://stexpanded.wikia.com/IRW_Dividices
#
# not found:
#  http://stexpanded.wikia.com/Division
#  http://memory-alpha.wikia.com/Division
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_division
#
# found:
#  http://memory-alpha.wikia.com/Doctor
#  http://stexpanded.wikia.com/Doctor
#
# found:
#  http://memory-alpha.wikia.com/Doctor_Who
#  http://stexpanded.wikia.com/Doctor_Who
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Medicine
#  http://stexpanded.wikia.com/Doctor_of_Medicine
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Philosophy
#  http://stexpanded.wikia.com/Doctor_of_Science
#
# not found:
#  http://stexpanded.wikia.com/Dominion
#  http://memory-alpha.wikia.com/Dominion
# found instead:
#  http://memory-alpha.wikia.com/Nygean
#
# found:
#  http://memory-alpha.wikia.com/Dominion_Headquarters
#  http://stexpanded.wikia.com/Dominion_Headquarters
#
# found:
#  http://memory-alpha.wikia.com/Dominion_War
#  http://stexpanded.wikia.com/Dominion_War
#
# found:
#  http://memory-alpha.wikia.com/Donatra
#  http://stexpanded.wikia.com/Donatra
#
# found:
#  http://memory-alpha.wikia.com/Dorian_Collins
#  http://stexpanded.wikia.com/Dorian_Collins_(USS_Baldwin)
#
# found:
#  http://memory-alpha.wikia.com/Dorvan_sector
#  http://stexpanded.wikia.com/Dorvan_sector
#
# found:
#  http://memory-alpha.wikia.com/Dragon
#  http://stexpanded.wikia.com/Dragon
#
# found:
# ...
#  http://stexpanded.wikia.com/USS_Zapata
#
# found:
#  http://memory-alpha.wikia.com/USS_Zhukov
#  http://stexpanded.wikia.com/USS_Zhukov_(NCC-26136)
#
# found:
#  http://memory-alpha.wikia.com/Uhlan
#  http://stexpanded.wikia.com/Uhlan
#
# found:
#  http://memory-alpha.wikia.com/Ultritium
#  http://stexpanded.wikia.com/Ultritium
#
# found:
#  http://memory-alpha.wikia.com/Ultritium_concussion_shell
#  http://stexpanded.wikia.com/Ultritium_concussion_shell
#
# found:
#  http://memory-alpha.wikia.com/Uniform
#  http://stexpanded.wikia.com/Uniform
#
# found:
#  http://memory-alpha.wikia.com/United_Earth
#  http://stexpanded.wikia.com/United_Earth
#
# found:
#  http://memory-alpha.wikia.com/United_Earth_Space_Probe_Agency
#  http://stexpanded.wikia.com/United_Earth_Space_Probe_Agency
#
# not found:
#  http://stexpanded.wikia.com/United_Federation_of_Planets
#  http://memory-alpha.wikia.com/United_Federation_of_Planets
# found instead:
#  http://memory-alpha.wikia.com/Charter_of_the_United_Federation_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/United_Nations
#  http://stexpanded.wikia.com/United_Nations
#
# found:
#  http://memory-alpha.wikia.com/United_States_armed_forces
#  http://stexpanded.wikia.com/United_States_armed_forces
#
# not found:
#  http://stexpanded.wikia.com/United_States_of_America
#  http://memory-alpha.wikia.com/United_States_of_America
# found instead:
#  http://memory-alpha.wikia.com/Americans
#
# found:
#  http://memory-alpha.wikia.com/Universal_translator
#  http://stexpanded.wikia.com/Universal_translator
#
# found:
#  http://memory-alpha.wikia.com/University
#  http://stexpanded.wikia.com/University
#
# found:
#  http://memory-alpha.wikia.com/University_of_Betazed
#  http://stexpanded.wikia.com/University_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/University_of_California,_Berkeley
#  http://stexpanded.wikia.com/University_of_California,_Berkeley
#
# found:
#  http://memory-alpha.wikia.com/University_of_Culat
#  http://stexpanded.wikia.com/University_of_Culat
#
# found:
#  http://memory-alpha.wikia.com/University_of_Mississippi
#  http://stexpanded.wikia.com/University_of_Mississippi
#
# found:
#  http://memory-alpha.wikia.com/Unnamed_Oberth_class_starships
#  http://stexpanded.wikia.com/USS_Bonestell_(NCC-31600)
#
# not found:
#  http://stexpanded.wikia.com/IKS_Vor%27cha
#  http://memory-alpha.wikia.com/Unnamed_Vor%27cha_class_starships
# found instead:
#  http://memory-alpha.wikia.com/IKS_Vor%27nak
#
# not found:
#  http://stexpanded.wikia.com/Utopia_Planitia
#  http://memory-alpha.wikia.com/Utopia_Planitia
# found instead:
#  http://memory-alpha.wikia.com/Utopia_Planitia_Gardens
#
# found:
#  http://memory-alpha.wikia.com/Utopia_Planitia_Fleet_Yards
#  http://stexpanded.wikia.com/Utopia_Planitia_Fleet_Yards
#
# found:
#  http://memory-alpha.wikia.com/Uttan_Narsu
#  http://stexpanded.wikia.com/Uttan_Narsu
#
# found:
#  http://memory-alpha.wikia.com/V%27Shar
#  http://stexpanded.wikia.com/V%27Shar
#
# found:
#  http://memory-alpha.wikia.com/Vaadwaur
#  http://stexpanded.wikia.com/Vaadwaur
#
# found:
#  http://memory-alpha.wikia.com/Vadosia
#  http://stexpanded.wikia.com/Vadosia
#
# not found:
#  http://stexpanded.wikia.com/Valdore
#  http://memory-alpha.wikia.com/Valdore
# found instead:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#
# found:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#  http://stexpanded.wikia.com/IRW_Valdore
#
# found:
#  http://memory-alpha.wikia.com/Valdore_type
#  http://stexpanded.wikia.com/Valdore_type
#
# found:
#  http://memory-alpha.wikia.com/Valeris
#  http://stexpanded.wikia.com/Valeris
#
# found:
#  http://memory-alpha.wikia.com/Valo_II
#  http://stexpanded.wikia.com/Valo_II
#
# found:
#  http://memory-alpha.wikia.com/Vash
#  http://stexpanded.wikia.com/Vash
#
# found:
#  http://memory-alpha.wikia.com/Vedek
#  http://stexpanded.wikia.com/Vedek
#
# found:
#  http://memory-alpha.wikia.com/Vedek_Assembly
#  http://stexpanded.wikia.com/Vedek_Assembly
#
# found:
#  http://memory-alpha.wikia.com/Velocity
#  http://stexpanded.wikia.com/Velocity
#
# found:
#  http://memory-alpha.wikia.com/Verathan
#  http://stexpanded.wikia.com/Verathan
#
# found:
#  http://memory-alpha.wikia.com/Veridian_III
#  http://stexpanded.wikia.com/Veridian_III
#
# found:
#  http://memory-alpha.wikia.com/Vetar
#  http://stexpanded.wikia.com/Vetar
#
# found:
#  http://memory-alpha.wikia.com/Vice_admiral
#  http://stexpanded.wikia.com/Vice_admiral
#
# found:
#  http://memory-alpha.wikia.com/Vidiian_Sodality
#  http://stexpanded.wikia.com/Vidiian_Sodality
#
# found:
#  http://memory-alpha.wikia.com/Viewscreen
#  http://stexpanded.wikia.com/Viewscreen
#
# found:
#  http://memory-alpha.wikia.com/Volleyball
#  http://stexpanded.wikia.com/Volleyball
#
# found:
#  http://memory-alpha.wikia.com/Vor%27cha_class
#  http://stexpanded.wikia.com/Vor%27cha_class
#
# found:
#  http://memory-alpha.wikia.com/Vorgon
#  http://stexpanded.wikia.com/Vorgon
#
# found:
#  http://memory-alpha.wikia.com/Vorik
#  http://stexpanded.wikia.com/Vorik
#
# found:
#  http://memory-alpha.wikia.com/Vorta
#  http://stexpanded.wikia.com/Vorta
#
# found:
#  http://memory-alpha.wikia.com/Vosk
#  http://stexpanded.wikia.com/Vosk
#
# found:
#  http://memory-alpha.wikia.com/Voth
#  http://stexpanded.wikia.com/Voth
#
# not found:
#  http://stexpanded.wikia.com/Merken_tr%27Vreenak
#  http://memory-alpha.wikia.com/Vreenak
# found instead:
#  http://memory-alpha.wikia.com/Oden
#
# not found:
#  http://stexpanded.wikia.com/Vulcan
#  http://memory-alpha.wikia.com/Vulcan
# found instead:
#  http://memory-alpha.wikia.com/Spock_(disambiguation)
#
# not found:
#  http://stexpanded.wikia.com/Vulcan%27s_Forge
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge
# found instead:
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_(planet)
#  http://stexpanded.wikia.com/Vulcan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_Science_Academy
#  http://stexpanded.wikia.com/Vulcan_Science_Academy
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_ranks
#  http://memory-alpha.wikia.com/Vulcan_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_system
#  http://memory-alpha.wikia.com/Vulcan_system
# found instead:
#  http://memory-alpha.wikia.com/40_Eridani_A
#
# found:
#  http://memory-alpha.wikia.com/Walker_Keel
#  http://stexpanded.wikia.com/Walker_Keel
#
# found:
#  http://memory-alpha.wikia.com/Warbird
#  http://stexpanded.wikia.com/Warbird
#
# found:
#  http://memory-alpha.wikia.com/Warp_coil
#  http://stexpanded.wikia.com/Warp_coil
#
# found:
#  http://memory-alpha.wikia.com/Warp_core
#  http://stexpanded.wikia.com/Warp_core
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_breach
#  http://stexpanded.wikia.com/Warp_core_breach
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_ejection_system
#  http://stexpanded.wikia.com/Warp_core_ejection_system
#
# found:
#  http://memory-alpha.wikia.com/Warp_drive
#  http://stexpanded.wikia.com/Warp_drive
#
# found:
#  http://memory-alpha.wikia.com/Warship
#  http://stexpanded.wikia.com/Warship
#
# not found:
#  http://stexpanded.wikia.com/Jennifer_Watley
#  http://memory-alpha.wikia.com/Watley
# found instead:
#  http://memory-alpha.wikia.com/Watley_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Weather_modification_network
#  http://stexpanded.wikia.com/Weather_modification_network
#
# found:
#  http://memory-alpha.wikia.com/Wedding
#  http://stexpanded.wikia.com/Wedding
#
# found:
#  http://memory-alpha.wikia.com/Wellington
#  http://stexpanded.wikia.com/Wellington
#
# found:
#  http://memory-alpha.wikia.com/Wendell_Greer
#  http://stexpanded.wikia.com/Wendell_Greer
#
# found:
#  http://memory-alpha.wikia.com/Wesley_Crusher
#  http://stexpanded.wikia.com/Wesley_Crusher
#
# found:
#  http://memory-alpha.wikia.com/West_Point
#  http://stexpanded.wikia.com/West_Point
#
# found:
#  http://memory-alpha.wikia.com/Weyoun
#  http://stexpanded.wikia.com/Weyoun
#
# found:
#  http://memory-alpha.wikia.com/Will_Decker
#  http://stexpanded.wikia.com/Willard_Decker
#
# not found:
#  http://stexpanded.wikia.com/William_Ross
#  http://memory-alpha.wikia.com/William_Ross
# found instead:
#  http://memory-alpha.wikia.com/Bennet_(Captain)
#
# found:
#  http://memory-alpha.wikia.com/William_Shakespeare
#  http://stexpanded.wikia.com/William_Shakespeare
#
# not found:
#  http://stexpanded.wikia.com/William_T._Riker
#  http://memory-alpha.wikia.com/William_T._Riker
# found instead:
#  http://memory-alpha.wikia.com/Personal_log,_William_T._Riker
#
# found:
#  http://memory-alpha.wikia.com/William_Telfer
#  http://stexpanded.wikia.com/William_Telfer
#
# found:
#  http://memory-alpha.wikia.com/Wine
#  http://stexpanded.wikia.com/Wine
#
# found:
#  http://memory-alpha.wikia.com/Wolf_359
#  http://stexpanded.wikia.com/Wolf_359
#
# not found:
#  http://stexpanded.wikia.com/Worf
#  http://memory-alpha.wikia.com/Worf
# found instead:
#  http://memory-alpha.wikia.com/Kurn
#
# found:
#  http://memory-alpha.wikia.com/World_War_II
#  http://stexpanded.wikia.com/World_War_II
#
# found:
#  http://memory-alpha.wikia.com/World_War_III
#  http://stexpanded.wikia.com/World_War_III
#
# found:
#  http://memory-alpha.wikia.com/Wormhole
#  http://stexpanded.wikia.com/Wormhole
#
# found:
#  http://memory-alpha.wikia.com/X-ray_laser
#  http://stexpanded.wikia.com/X-ray_laser
#
# found:
#  http://memory-alpha.wikia.com/Xenophobia
#  http://stexpanded.wikia.com/Xenophobia
#
# found:
#  http://memory-alpha.wikia.com/Xindi
#  http://stexpanded.wikia.com/Xindi
#
# found:
#  http://memory-alpha.wikia.com/Xindi-Aquatic
#  http://stexpanded.wikia.com/Xindi-Aquatic
#
# found:
#  http://memory-alpha.wikia.com/Xon
#  http://stexpanded.wikia.com/Xon
#
# found:
#  http://memory-alpha.wikia.com/Yaderan
#  http://stexpanded.wikia.com/Yaderan
#
# found:
#  http://memory-alpha.wikia.com/Yeager_type
#  http://stexpanded.wikia.com/Yeager_class
#
# found:
#  http://memory-alpha.wikia.com/Yelgrun
#  http://stexpanded.wikia.com/Yelgrun
#
# found:
#  http://memory-alpha.wikia.com/Yellow_alert
#  http://stexpanded.wikia.com/Yellow_alert
#
# found:
#  http://memory-alpha.wikia.com/Yellowstone_class
#  http://stexpanded.wikia.com/Yellowstone_class
#
# found:
#  http://memory-alpha.wikia.com/Yeoman
#  http://stexpanded.wikia.com/Yeoman
#
# found:
#  http://memory-alpha.wikia.com/Yoyodyne_Propulsion_Systems
#  http://stexpanded.wikia.com/Yoyodyne_Division
#
# found:
#  http://memory-alpha.wikia.com/Yridian
#  http://stexpanded.wikia.com/Yridian
#
# found:
#  http://memory-alpha.wikia.com/Zabathu
#  http://stexpanded.wikia.com/Zabathu
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_High_School
#  http://memory-alpha.wikia.com/Zefram_Cochrane_High_School
# found instead:
#  http://memory-alpha.wikia.com/Cochrane
#
# found:
#  http://memory-alpha.wikia.com/Zero_gravity
#  http://stexpanded.wikia.com/Zero_gravity
#
# found:
#  http://memory-alpha.wikia.com/Zhian%27tara
#  http://stexpanded.wikia.com/Zhian%27tara
#
# found:
#  http://memory-alpha.wikia.com/Zoo
#  http://stexpanded.wikia.com/Zoo
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship
#  http://stexpanded.wikia.com/class/starship-sidebar
#
# not found:
#  http://stexpanded.wikia.com/class/character
#  http://memory-alpha.wikia.com/class/sidebar_individual
# found instead:
#  http://memory-alpha.wikia.com/class/non_canon_character_page
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_year
#  http://stexpanded.wikia.com/class/yearbox
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship_class
#  http://stexpanded.wikia.com/class/starship-class
#
# found:
#  http://memory-alpha.wikia.com/class/uss
#  http://stexpanded.wikia.com/class/uss
#
# found:
#  http://memory-alpha.wikia.com/class/ds9
#  http://stexpanded.wikia.com/class/ds9
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_planet
#  http://stexpanded.wikia.com/class/planet_info
#
# not found:
#  http://stexpanded.wikia.com/class/battle_data
#  http://memory-alpha.wikia.com/class/sidebar_military_conflict
# found instead:
#  http://memory-alpha.wikia.com/class/mb
#
# found:
#  http://memory-alpha.wikia.com/class/voy
#  http://stexpanded.wikia.com/class/voy
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_species
#  http://stexpanded.wikia.com/class/sidebar_species
#
# found:
#  http://memory-alpha.wikia.com/class/tng
#  http://stexpanded.wikia.com/class/tng
#
# found:
#  http://memory-alpha.wikia.com/class/ent
#  http://stexpanded.wikia.com/class/ent
#
# found:
#  http://memory-alpha.wikia.com/class/film
#  http://stexpanded.wikia.com/class/film
#
# found:
#  http://memory-alpha.wikia.com/name
#  http://stexpanded.wikia.com/name
#
# found:
#  http://memory-alpha.wikia.com/species
#  http://stexpanded.wikia.com/species
#
# found:
#  http://memory-alpha.wikia.com/status
#  http://stexpanded.wikia.com/status
#
# found:
#  http://memory-alpha.wikia.com/rank
#  http://stexpanded.wikia.com/rank
#
# found:
#  http://memory-alpha.wikia.com/affiliation
#  http://stexpanded.wikia.com/affiliation
#
# not found:
#  http://stexpanded.wikia.com/defense
#  http://memory-alpha.wikia.com/defenses
# found instead:
#  http://memory-alpha.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/combatant
#  http://stexpanded.wikia.com/combatant
#
# found:
#  http://memory-alpha.wikia.com/type
#  http://stexpanded.wikia.com/type
#
# found:
#  http://memory-alpha.wikia.com/father
#  http://stexpanded.wikia.com/father
#
# found:
#  http://memory-alpha.wikia.com/gender
#  http://stexpanded.wikia.com/gender
#
# found:
#  http://memory-alpha.wikia.com/mother
#  http://stexpanded.wikia.com/mother
#
# found:
#  http://memory-alpha.wikia.com/born
#  http://stexpanded.wikia.com/born
#
# found:
#  http://memory-alpha.wikia.com/relatives
#  http://stexpanded.wikia.com/relatives
#
# found:
#  http://memory-alpha.wikia.com/died
#  http://stexpanded.wikia.com/died
#
# found:
#  http://memory-alpha.wikia.com/armament
#  http://stexpanded.wikia.com/armament
#
# found:
#  http://memory-alpha.wikia.com/spouse
#  http://stexpanded.wikia.com/spouse
#
# found:
#  http://memory-alpha.wikia.com/sibling
#  http://stexpanded.wikia.com/siblings
#
# found:
#  http://memory-alpha.wikia.com/children
#  http://stexpanded.wikia.com/children
#
# found:
#  http://memory-alpha.wikia.com/date
#  http://stexpanded.wikia.com/date
#
# found:
#  http://memory-alpha.wikia.com/location
#  http://stexpanded.wikia.com/location
#
# found:
#  http://memory-alpha.wikia.com/crew
#  http://stexpanded.wikia.com/crew
#
# found:
#  http://memory-alpha.wikia.com/result
#  http://stexpanded.wikia.com/result
#
# found:
#  http://memory-alpha.wikia.com/occupation
#  http://stexpanded.wikia.com/occupation
#
# found:
#  http://memory-alpha.wikia.com/strength
#  http://stexpanded.wikia.com/strength
#
# found:
#  http://memory-alpha.wikia.com/class
#  http://stexpanded.wikia.com/class
#
# found:
#  http://memory-alpha.wikia.com/planet
#  http://stexpanded.wikia.com/planet
#
# found:
#  http://memory-alpha.wikia.com/image
#  http://stexpanded.wikia.com/image
#
# found:
#  http://memory-alpha.wikia.com/military
#  http://stexpanded.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/capital
#  http://stexpanded.wikia.com/capital
#
# found:
#  http://memory-alpha.wikia.com/majorSpecies
#  http://stexpanded.wikia.com/majorSpecies
#
# found:
#  http://memory-alpha.wikia.com/headOfState
#  http://stexpanded.wikia.com/headOfState
#
# found:
#  http://memory-alpha.wikia.com/season
#  http://stexpanded.wikia.com/season
#
# found:
#  http://memory-alpha.wikia.com/year
#  http://stexpanded.wikia.com/year
#
# found:
#  http://memory-alpha.wikia.com/registry
#  http://stexpanded.wikia.com/registry
#
# found:
#  http://memory-alpha.wikia.com/headOfGovernment
#  http://stexpanded.wikia.com/headOfGovernment
#
# found:
#  http://memory-alpha.wikia.com/actor
#  http://stexpanded.wikia.com/actor
#
# not found:
#  http://stexpanded.wikia.com/found
#  http://memory-alpha.wikia.com/founded
# found instead:
#  http://memory-alpha.wikia.com/from
#
# found:
#  http://memory-alpha.wikia.com/guest
#  http://stexpanded.wikia.com/guest
#
# found:
#  http://memory-alpha.wikia.com/artist
#  http://stexpanded.wikia.com/artist
#
# found:
#  http://memory-alpha.wikia.com/publisher
#  http://stexpanded.wikia.com/publisher
#
# found:
#  http://memory-alpha.wikia.com/beam
#  http://stexpanded.wikia.com/beam

# %%
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node_neig.get(gold_pair[1]) == gold_pair[0]:
        print("found:", "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
    else:
        print("not found:", "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""),
              "\nfound instead:", "\n",
              mappings_big[top1dict_node_neig.get(gold_pair[1])]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
# Out:
# found:
#  http://memory-alpha.wikia.com/18th_century
#  http://stexpanded.wikia.com/18th_century
#
# found:
#  http://memory-alpha.wikia.com/1991
#  http://stexpanded.wikia.com/1991
#
# found:
#  http://memory-alpha.wikia.com/1992
#  http://stexpanded.wikia.com/1992
#
# not found:
#  http://stexpanded.wikia.com/1996
#  http://memory-alpha.wikia.com/1996
# found instead:
#  http://memory-alpha.wikia.com/Joachim
#
# found:
#  http://memory-alpha.wikia.com/19th_century
#  http://stexpanded.wikia.com/19th_century
#
# found:
#  http://memory-alpha.wikia.com/20th_century
#  http://stexpanded.wikia.com/20th_century
#
# found:
#  http://memory-alpha.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#  http://stexpanded.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#
# not found:
#  http://stexpanded.wikia.com/47
#  http://memory-alpha.wikia.com/47
# found instead:
#  http://memory-alpha.wikia.com/12_February
#
# found:
#  http://memory-alpha.wikia.com/602_Club
#  http://stexpanded.wikia.com/602_Club
#
# not found:
#  http://stexpanded.wikia.com/Magna_Roma
#  http://memory-alpha.wikia.com/892-IV
# found instead:
#  http://memory-alpha.wikia.com/Roman_Empire_(892-IV)
#
# not found:
#  http://stexpanded.wikia.com/Alyson_Foxton
#  http://memory-alpha.wikia.com/A.F.
# found instead:
#  http://memory-alpha.wikia.com/Alden
#
# found:
#  http://memory-alpha.wikia.com/Aaamazzarite
#  http://stexpanded.wikia.com/Aaamazzarite
#
# found:
#  http://memory-alpha.wikia.com/Aberdeen
#  http://stexpanded.wikia.com/Aberdeen
#
# found:
#  http://memory-alpha.wikia.com/Ablative_armor
#  http://stexpanded.wikia.com/Ablative_armor
#
# found:
#  http://memory-alpha.wikia.com/Acamarian
#  http://stexpanded.wikia.com/Acamarian
#
# found:
#  http://memory-alpha.wikia.com/Acting_captain
#  http://stexpanded.wikia.com/Acting_captain
#
# found:
#  http://memory-alpha.wikia.com/Actor
#  http://stexpanded.wikia.com/Actor
#
# found:
#  http://memory-alpha.wikia.com/Adarak_Prime
#  http://stexpanded.wikia.com/Adarak_Prime
#
# not found:
#  http://stexpanded.wikia.com/Admiral
#  http://memory-alpha.wikia.com/Admiral
# found instead:
#  http://memory-alpha.wikia.com/Fleet_admiral
#
# found:
#  http://memory-alpha.wikia.com/Advanced_Tactical_Training
#  http://stexpanded.wikia.com/Advanced_Tactical_Training_Program
#
# found:
#  http://memory-alpha.wikia.com/Aenar
#  http://stexpanded.wikia.com/Aenar
#
# found:
#  http://memory-alpha.wikia.com/Aeroshuttle
#  http://stexpanded.wikia.com/Aeroshuttle
#
# not found:
#  http://stexpanded.wikia.com/Africa
#  http://memory-alpha.wikia.com/Africa
# found instead:
#  http://memory-alpha.wikia.com/South_Africa
#
# found:
#  http://memory-alpha.wikia.com/Afterlife
#  http://stexpanded.wikia.com/Afterlife
#
# found:
#  http://memory-alpha.wikia.com/Aircraft_carrier
#  http://stexpanded.wikia.com/Aircraft_carrier
#
# found:
#  http://memory-alpha.wikia.com/Alaska
#  http://stexpanded.wikia.com/Alaska
#
# found:
#  http://memory-alpha.wikia.com/Alcohol
#  http://stexpanded.wikia.com/Alcohol
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran
#  http://stexpanded.wikia.com/Aldebaran_system
#
# not found:
#  http://stexpanded.wikia.com/Aldebaran_Prime
#  http://memory-alpha.wikia.com/Aldebaran_III
# found instead:
#  http://memory-alpha.wikia.com/Aldebaran
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran_whiskey
#  http://stexpanded.wikia.com/Aldebaran_whiskey
#
# found:
#  http://memory-alpha.wikia.com/Alden
#  http://stexpanded.wikia.com/Alden
#
# found:
#  http://memory-alpha.wikia.com/Alexander_Rozhenko
#  http://stexpanded.wikia.com/Alexander_Rozhenko
#
# found:
#  http://memory-alpha.wikia.com/Alien
#  http://stexpanded.wikia.com/Alien
#
# not found:
#  http://stexpanded.wikia.com/Alliance
#  http://memory-alpha.wikia.com/Alliance
# found instead:
#  http://memory-alpha.wikia.com/Alliance_(nation)
#
# found:
#  http://memory-alpha.wikia.com/Almatha_sector
#  http://stexpanded.wikia.com/Almatha_sector
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Centauri
#  http://stexpanded.wikia.com/Alpha_Centauri_system
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Quadrant
#  http://stexpanded.wikia.com/Alpha_Quadrant
#
# found:
#  http://memory-alpha.wikia.com/Alsuran_Empire
#  http://stexpanded.wikia.com/Alsuran
#
# found:
#  http://memory-alpha.wikia.com/Altair_water
#  http://stexpanded.wikia.com/Altair_water
#
# not found:
#  http://stexpanded.wikia.com/Alternate_reality
#  http://memory-alpha.wikia.com/Alternate_reality
# found instead:
#  http://memory-alpha.wikia.com/Quantum_reality
#
# not found:
#  http://stexpanded.wikia.com/Alternate_timeline
#  http://memory-alpha.wikia.com/Alternate_timeline
# found instead:
#  http://memory-alpha.wikia.com/Time_warp
#
# found:
#  http://memory-alpha.wikia.com/Altonian_brain_teaser
#  http://stexpanded.wikia.com/Altonian_brain_teaser
#
# found:
#  http://memory-alpha.wikia.com/Alynna_Nechayev
#  http://stexpanded.wikia.com/Alynna_Nechayev
#
# found:
#  http://memory-alpha.wikia.com/Amanda_Grayson
#  http://stexpanded.wikia.com/Amanda_Grayson
#
# not found:
#  http://stexpanded.wikia.com/Ambassador
#  http://memory-alpha.wikia.com/Ambassador
# found instead:
#  http://memory-alpha.wikia.com/Ambassadors
#
# found:
#  http://memory-alpha.wikia.com/Ambassador_class
#  http://stexpanded.wikia.com/Ambassador_class
#
# found:
#  http://memory-alpha.wikia.com/American_Civil_War
#  http://stexpanded.wikia.com/American_Civil_War
#
# found:
#  http://memory-alpha.wikia.com/American_Revolution
#  http://stexpanded.wikia.com/American_Revolutionary_War
#
# not found:
#  http://stexpanded.wikia.com/Amnesia
#  http://memory-alpha.wikia.com/Amnesia
# found instead:
#  http://memory-alpha.wikia.com/Anterograde_amnesia
#
# found:
#  http://memory-alpha.wikia.com/Amusement_park
#  http://stexpanded.wikia.com/Amusement_park
#
# found:
#  http://memory-alpha.wikia.com/Ancient_humanoid
#  http://stexpanded.wikia.com/Ancient_humanoid
#
# found:
#  http://memory-alpha.wikia.com/Andoria
#  http://stexpanded.wikia.com/Andoria
#
# found:
#  http://memory-alpha.wikia.com/Andorian
#  http://stexpanded.wikia.com/Andorian
#
# found:
#  http://memory-alpha.wikia.com/Andorian_Imperial_Guard
#  http://stexpanded.wikia.com/Andorian_Imperial_Guard
#
# found:
#  http://memory-alpha.wikia.com/Andorian_battle_cruiser
#  http://stexpanded.wikia.com/Kumari_class
#
# found:
#  http://memory-alpha.wikia.com/Android
#  http://stexpanded.wikia.com/Android
#
# found:
#  http://memory-alpha.wikia.com/Andromeda_Galaxy
#  http://stexpanded.wikia.com/Andromeda_Galaxy
#
# not found:
#  http://stexpanded.wikia.com/Anesthizine
#  http://memory-alpha.wikia.com/Anesthizine
# found instead:
#  http://memory-alpha.wikia.com/Anetrizine
#
# found:
#  http://memory-alpha.wikia.com/Antares_Ship_Yards
#  http://stexpanded.wikia.com/Antares_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Antares_class_(Starfleet)
#  http://memory-alpha.wikia.com/Antares_type
# found instead:
#  http://memory-alpha.wikia.com/USS_Antares
#
# found:
#  http://memory-alpha.wikia.com/Anthropology
#  http://stexpanded.wikia.com/Anthropology
#
# found:
#  http://memory-alpha.wikia.com/Antideuterium
#  http://stexpanded.wikia.com/Anti-deuterium
#
# not found:
#  http://stexpanded.wikia.com/Antimatter
#  http://memory-alpha.wikia.com/Antimatter
# found instead:
#  http://memory-alpha.wikia.com/Antiproton
#
# found:
#  http://memory-alpha.wikia.com/Antwerp
#  http://stexpanded.wikia.com/Antwerp
#
# found:
#  http://memory-alpha.wikia.com/Apollo_class
#  http://stexpanded.wikia.com/Apollo_class
#
# found:
#  http://memory-alpha.wikia.com/Aquiel_Uhnari
#  http://stexpanded.wikia.com/Aquiel_Uhnari
#
# found:
#  http://memory-alpha.wikia.com/Arboretum
#  http://stexpanded.wikia.com/Arboretum
#
# not found:
#  http://stexpanded.wikia.com/Archaeology
#  http://memory-alpha.wikia.com/Archaeology
# found instead:
#  http://memory-alpha.wikia.com/Archaeologist
#
# found:
#  http://memory-alpha.wikia.com/Archaeology_and_anthropology_officer
#  http://stexpanded.wikia.com/Archaeology_and_anthropology_officer
#
# found:
#  http://memory-alpha.wikia.com/Archanis_sector
#  http://stexpanded.wikia.com/Archanis_sector
#
# found:
#  http://memory-alpha.wikia.com/Architecture
#  http://stexpanded.wikia.com/Architecture
#
# found:
#  http://memory-alpha.wikia.com/Archon_(starship)
#  http://stexpanded.wikia.com/USS_Archon_(NCC-189)
#
# found:
#  http://memory-alpha.wikia.com/Arex
#  http://stexpanded.wikia.com/Arex
#
# not found:
#  http://stexpanded.wikia.com/Argo_type
#  http://memory-alpha.wikia.com/Argo_(shuttlecraft)
# found instead:
#  http://memory-alpha.wikia.com/Type_6_shuttlecraft
#
# found:
#  http://memory-alpha.wikia.com/Argolis_Cluster
#  http://stexpanded.wikia.com/Argolis_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Argus_X
#  http://stexpanded.wikia.com/Argus_X
#
# found:
#  http://memory-alpha.wikia.com/Ariannus
#  http://stexpanded.wikia.com/Ariannus
#
# found:
#  http://memory-alpha.wikia.com/Arkonian
#  http://stexpanded.wikia.com/Arkonian
#
# found:
#  http://memory-alpha.wikia.com/Armory
#  http://stexpanded.wikia.com/Armory
#
# found:
#  http://memory-alpha.wikia.com/Armory_officer
#  http://stexpanded.wikia.com/Armory_officer
#
# not found:
#  http://stexpanded.wikia.com/USS_Armstrong_(NCC-57537)
#  http://memory-alpha.wikia.com/Armstrong_(disambiguation)
# found instead:
#  http://memory-alpha.wikia.com/USS_Neil_Armstrong
#
# found:
#  http://memory-alpha.wikia.com/Armus
#  http://stexpanded.wikia.com/Armus
#
# found:
#  http://memory-alpha.wikia.com/Artificial_intelligence
#  http://stexpanded.wikia.com/Artificial_intelligence
#
# not found:
#  http://stexpanded.wikia.com/Asia
#  http://memory-alpha.wikia.com/Asia
# found instead:
#  http://memory-alpha.wikia.com/Eurasia
#
# found:
#  http://memory-alpha.wikia.com/Assault_team
#  http://stexpanded.wikia.com/Assault_team
#
# found:
#  http://memory-alpha.wikia.com/Assignment_patch
#  http://stexpanded.wikia.com/Assignment_patch
#
# found:
#  http://memory-alpha.wikia.com/Assimilation
#  http://stexpanded.wikia.com/Assimilation
#
# found:
#  http://memory-alpha.wikia.com/Assistant_chief_engineer
#  http://stexpanded.wikia.com/Assistant_chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Asteroid
#  http://stexpanded.wikia.com/Asteroid
#
# found:
#  http://memory-alpha.wikia.com/Astrometrics
#  http://stexpanded.wikia.com/Astrometrics
#
# found:
#  http://memory-alpha.wikia.com/Atlanta
#  http://stexpanded.wikia.com/Atlanta
#
# found:
#  http://memory-alpha.wikia.com/Atlantic_Ocean
#  http://stexpanded.wikia.com/Atlantic_Ocean
#
# found:
#  http://memory-alpha.wikia.com/Attack_cruiser
#  http://stexpanded.wikia.com/Attack_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Attack_fighter
#  http://stexpanded.wikia.com/Attack_fighter
#
# found:
#  http://memory-alpha.wikia.com/Auction
#  http://stexpanded.wikia.com/Auction
#
# not found:
#  http://stexpanded.wikia.com/Audrid_Dax
#  http://memory-alpha.wikia.com/Audrid_Dax
# found instead:
#  http://memory-alpha.wikia.com/Lela_Dax
#
# found:
#  http://memory-alpha.wikia.com/Augment
#  http://stexpanded.wikia.com/Augment
#
# found:
#  http://memory-alpha.wikia.com/Aurelian
#  http://stexpanded.wikia.com/Aurelian
#
# found:
#  http://memory-alpha.wikia.com/Australia
#  http://stexpanded.wikia.com/Australia
#
# found:
#  http://memory-alpha.wikia.com/Autarch
#  http://stexpanded.wikia.com/Autarch
#
# found:
#  http://memory-alpha.wikia.com/Auto-destruct
#  http://stexpanded.wikia.com/Auto-destruct
#
# found:
#  http://memory-alpha.wikia.com/Auxiliary_space_vessel
#  http://stexpanded.wikia.com/Auxiliary_craft
#
# found:
#  http://memory-alpha.wikia.com/Avenal_VII
#  http://stexpanded.wikia.com/Avenal_VII
#
# found:
#  http://memory-alpha.wikia.com/Away_mission
#  http://stexpanded.wikia.com/Away_mission
#
# found:
#  http://memory-alpha.wikia.com/Away_team
#  http://stexpanded.wikia.com/Away_team
#
# not found:
#  http://stexpanded.wikia.com/Axanar
#  http://memory-alpha.wikia.com/Axanar
# found instead:
#  http://memory-alpha.wikia.com/Axanar_Starbase_Terminal
#
# found:
#  http://memory-alpha.wikia.com/Azetbur
#  http://stexpanded.wikia.com/Azetbur
#
# found:
#  http://memory-alpha.wikia.com/B%27Elanna_Torres
#  http://stexpanded.wikia.com/B%27Elanna_Torres
#
# found:
#  http://memory-alpha.wikia.com/B.G._Robinson
#  http://stexpanded.wikia.com/B.G._Robinson
#
# not found:
#  http://stexpanded.wikia.com/Ba%27ku
#  http://memory-alpha.wikia.com/Ba%27ku
# found instead:
#  http://memory-alpha.wikia.com/Ba%27ku_(star)
#
# not found:
#  http://stexpanded.wikia.com/Badlands
#  http://memory-alpha.wikia.com/Badlands
# found instead:
#  http://memory-alpha.wikia.com/Etymology
#
# found:
#  http://memory-alpha.wikia.com/Baikonur_Cosmodrome
#  http://stexpanded.wikia.com/Baikonur_Cosmodrome
#
# found:
#  http://memory-alpha.wikia.com/Bajor
#  http://stexpanded.wikia.com/Bajor
#
# found:
#  http://memory-alpha.wikia.com/Bajor_sector
#  http://stexpanded.wikia.com/Bajor_sector
#
# found:
#  http://memory-alpha.wikia.com/Bajoran
#  http://stexpanded.wikia.com/Bajoran
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Militia
#  http://stexpanded.wikia.com/Bajoran_Militia
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Republic
#  http://stexpanded.wikia.com/Bajoran_Provisional_Government
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Resistance
#  http://stexpanded.wikia.com/Bajoran_Resistance
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_language
#  http://stexpanded.wikia.com/Bajoran_language
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_ranks
#  http://memory-alpha.wikia.com/Bajoran_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_religion
#  http://stexpanded.wikia.com/Bajoran_religion
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_system
#  http://memory-alpha.wikia.com/Bajoran_system
# found instead:
#  http://memory-alpha.wikia.com/Bajoran
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_wormhole
#  http://stexpanded.wikia.com/Bajoran_wormhole
#
# not found:
#  http://stexpanded.wikia.com/Bar
#  http://memory-alpha.wikia.com/Bar
# found instead:
#  http://memory-alpha.wikia.com/Tavern
#
# found:
#  http://memory-alpha.wikia.com/Barkonian
#  http://stexpanded.wikia.com/Barkonian
#
# found:
#  http://memory-alpha.wikia.com/Barnard%27s_Star
#  http://stexpanded.wikia.com/Barnard%27s_Star
#
# found:
#  http://memory-alpha.wikia.com/Barstow_(Commodore)
#  http://stexpanded.wikia.com/Barstow
#
# not found:
#  http://stexpanded.wikia.com/Bartender
#  http://memory-alpha.wikia.com/Bartender
# found instead:
#  http://memory-alpha.wikia.com/Waiter
#
# not found:
#  http://stexpanded.wikia.com/Baseball
#  http://memory-alpha.wikia.com/Baseball
# found instead:
#  http://memory-alpha.wikia.com/Soccer
#
# found:
#  http://memory-alpha.wikia.com/Basketball
#  http://stexpanded.wikia.com/Basketball
#
# found:
#  http://memory-alpha.wikia.com/Bat%27leth
#  http://stexpanded.wikia.com/Bat%27leth
#
# found:
#  http://memory-alpha.wikia.com/Battle_cruiser
#  http://stexpanded.wikia.com/Battle_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Axanar
#  http://stexpanded.wikia.com/Battle_of_Axanar
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Betazed
#  http://stexpanded.wikia.com/Battle_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cardassia
#  http://stexpanded.wikia.com/Battle_of_Cardassia
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cheron
#  http://stexpanded.wikia.com/Battle_of_Cheron
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Klach_D%27kel_Brakt
#  http://stexpanded.wikia.com/Battle_of_Klach_D%27kel_Brakt
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Procyon_V
#  http://stexpanded.wikia.com/Battle_of_Procyon_V
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Ricktor_Prime
#  http://stexpanded.wikia.com/Battle_of_Ricktor_Prime
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Sector_001
#  http://stexpanded.wikia.com/Battle_of_Sector_001
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_the_Omarion_Nebula
#  http://stexpanded.wikia.com/Battle_of_the_Omarion_Nebula
#
# found:
#  http://memory-alpha.wikia.com/Battleship
#  http://stexpanded.wikia.com/Battleship
#
# found:
#  http://memory-alpha.wikia.com/Beer
#  http://stexpanded.wikia.com/Beer
#
# found:
#  http://memory-alpha.wikia.com/Bekk
#  http://stexpanded.wikia.com/Bekk
#
# found:
#  http://memory-alpha.wikia.com/Belgium
#  http://stexpanded.wikia.com/Belgium
#
# found:
#  http://memory-alpha.wikia.com/Bendii_Syndrome
#  http://stexpanded.wikia.com/Bendii_Syndrome
#
# found:
#  http://memory-alpha.wikia.com/Benecia_Colony
#  http://stexpanded.wikia.com/Benecia_Colony
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Finney
#  http://stexpanded.wikia.com/Ben_Finney
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Maxwell
#  http://stexpanded.wikia.com/Benjamin_Maxwell
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Sisko
#  http://stexpanded.wikia.com/Benjamin_Sisko
#
# found:
#  http://memory-alpha.wikia.com/Benny_Russell
#  http://stexpanded.wikia.com/Benny_Russell
#
# found:
#  http://memory-alpha.wikia.com/Benzar
#  http://stexpanded.wikia.com/Benzar
#
# not found:
#  http://stexpanded.wikia.com/Benzenite
#  http://memory-alpha.wikia.com/Benzenite
# found instead:
#  http://memory-alpha.wikia.com/Magnesite
#
# found:
#  http://memory-alpha.wikia.com/Benzite_system
#  http://stexpanded.wikia.com/Benzite_system
#
# found:
#  http://memory-alpha.wikia.com/Berengaria_VII
#  http://stexpanded.wikia.com/Berengaria_VII
#
# not found:
#  http://stexpanded.wikia.com/Berlin
#  http://memory-alpha.wikia.com/Berlin
# found instead:
#  http://memory-alpha.wikia.com/New_Berlin
#
# found:
#  http://memory-alpha.wikia.com/Berlinghoff_Rasmussen
#  http://stexpanded.wikia.com/Berlinghoff_Rasmussen
#
# found:
#  http://memory-alpha.wikia.com/Berthold_ray
#  http://stexpanded.wikia.com/Berthold_ray
#
# found:
#  http://memory-alpha.wikia.com/Beta_Antares_Ship_Yards
#  http://stexpanded.wikia.com/Beta_Antares_Ship_Yards
#
# found:
#  http://memory-alpha.wikia.com/Beta_Quadrant
#  http://stexpanded.wikia.com/Beta_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Beverly_Crusher
#  http://memory-alpha.wikia.com/Beverly_Crusher
# found instead:
#  http://memory-alpha.wikia.com/Gates_McFadden
#
# found:
#  http://memory-alpha.wikia.com/Bible
#  http://stexpanded.wikia.com/Bible
#
# found:
#  http://memory-alpha.wikia.com/Bilitrium
#  http://stexpanded.wikia.com/Bilitrium
#
# found:
#  http://memory-alpha.wikia.com/Bio-dampener
#  http://stexpanded.wikia.com/Bio-dampener
#
# found:
#  http://memory-alpha.wikia.com/Bio-neural_circuitry
#  http://stexpanded.wikia.com/Bio-neural_circuitry
#
# found:
#  http://memory-alpha.wikia.com/Biosynthetic_limb
#  http://stexpanded.wikia.com/Biosynthetic_limb
#
# found:
#  http://memory-alpha.wikia.com/Bird-of-Prey
#  http://stexpanded.wikia.com/Bird-of-Prey
#
# not found:
#  http://stexpanded.wikia.com/Birthday
#  http://memory-alpha.wikia.com/Birthday
# found instead:
#  http://memory-alpha.wikia.com/Birthday_party
#
# not found:
#  http://stexpanded.wikia.com/Black_hole
#  http://memory-alpha.wikia.com/Black_hole
# found instead:
#  http://memory-alpha.wikia.com/Singularity
#
# found:
#  http://memory-alpha.wikia.com/Bloodwine
#  http://stexpanded.wikia.com/Bloodwine
#
# found:
#  http://memory-alpha.wikia.com/Blue_alert
#  http://stexpanded.wikia.com/Blue_alert
#
# found:
#  http://memory-alpha.wikia.com/Bolarus_IX
#  http://stexpanded.wikia.com/Bolarus_IX
#
# found:
#  http://memory-alpha.wikia.com/Bolian
#  http://stexpanded.wikia.com/Bolian
#
# not found:
#  http://stexpanded.wikia.com/SS_Bonaventure
#  http://memory-alpha.wikia.com/Bonaventure
# found instead:
#  http://memory-alpha.wikia.com/Bonaventure_(C1-21)
#
# not found:
#  http://stexpanded.wikia.com/Boothby
#  http://memory-alpha.wikia.com/Boothby
# found instead:
#  http://memory-alpha.wikia.com/Boothby_(Species_8472)
#
# not found:
#  http://stexpanded.wikia.com/Borath
#  http://memory-alpha.wikia.com/Borath
# found instead:
#  http://memory-alpha.wikia.com/Vorta
#
# found:
#  http://memory-alpha.wikia.com/Border
#  http://stexpanded.wikia.com/Border
#
# found:
#  http://memory-alpha.wikia.com/Borg
#  http://stexpanded.wikia.com/Borg
#
# not found:
#  http://stexpanded.wikia.com/Borg_Collective
#  http://memory-alpha.wikia.com/Borg_Collective
# found instead:
#  http://memory-alpha.wikia.com/Borg_drone
#
# found:
#  http://memory-alpha.wikia.com/Borg_Queen
#  http://stexpanded.wikia.com/Borg_Queen
#
# found:
#  http://memory-alpha.wikia.com/Borg_cube
#  http://stexpanded.wikia.com/Borg_cube
#
# found:
#  http://memory-alpha.wikia.com/Borg_drone
#  http://stexpanded.wikia.com/Borg_drone
#
# found:
#  http://memory-alpha.wikia.com/Borg_probe
#  http://stexpanded.wikia.com/Borg_probe
#
# found:
#  http://memory-alpha.wikia.com/Borg_sphere
#  http://stexpanded.wikia.com/Borg_sphere
#
# found:
#  http://memory-alpha.wikia.com/Borg_tactical_cube
#  http://stexpanded.wikia.com/Borg_tactical_cube
#
# found:
#  http://memory-alpha.wikia.com/Borias_Cluster
#  http://stexpanded.wikia.com/Borias_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Bowsers
#  http://stexpanded.wikia.com/Bowser
#
# found:
#  http://memory-alpha.wikia.com/Boy_Scout
#  http://stexpanded.wikia.com/Boy_Scouts
#
# found:
#  http://memory-alpha.wikia.com/Bradbury_class
#  http://stexpanded.wikia.com/Bradbury_class
#
# found:
#  http://memory-alpha.wikia.com/Braxton
#  http://stexpanded.wikia.com/Braxton
#
# found:
#  http://memory-alpha.wikia.com/Bread
#  http://stexpanded.wikia.com/Bread
#
# found:
#  http://memory-alpha.wikia.com/Breen
#  http://stexpanded.wikia.com/Breen
#
# found:
#  http://memory-alpha.wikia.com/Breen_(planet)
#  http://stexpanded.wikia.com/Breen_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Breen_Confederacy
#  http://stexpanded.wikia.com/Breen_Confederacy
#
# found:
#  http://memory-alpha.wikia.com/Breen_attack_on_Earth
#  http://stexpanded.wikia.com/Breen_attack_on_Earth
#
# found:
#  http://memory-alpha.wikia.com/Breen_warship
#  http://stexpanded.wikia.com/Gor_Taan_class
#
# found:
#  http://memory-alpha.wikia.com/Briar_Patch
#  http://stexpanded.wikia.com/Briar_Patch
#
# not found:
#  http://stexpanded.wikia.com/Bridge
#  http://memory-alpha.wikia.com/Bridge
# found instead:
#  http://memory-alpha.wikia.com/Bridge_officer
#
# found:
#  http://memory-alpha.wikia.com/Bridge_Officer%27s_Test
#  http://stexpanded.wikia.com/Bridge_Officer%27s_Test
#
# found:
#  http://memory-alpha.wikia.com/Bridge_officer
#  http://stexpanded.wikia.com/Bridge_officer
#
# not found:
#  http://stexpanded.wikia.com/Brig
#  http://memory-alpha.wikia.com/Brig
# found instead:
#  http://memory-alpha.wikia.com/Security_holding_area
#
# not found:
#  http://stexpanded.wikia.com/Brigadier_general
#  http://memory-alpha.wikia.com/Brigadier
# found instead:
#  http://memory-alpha.wikia.com/General
#
# not found:
#  http://stexpanded.wikia.com/Briori
#  http://memory-alpha.wikia.com/Briori
# found instead:
#  http://memory-alpha.wikia.com/1937
#
# found:
#  http://memory-alpha.wikia.com/Brisbane
#  http://stexpanded.wikia.com/Brisbane
#
# found:
#  http://memory-alpha.wikia.com/Bruce_Maddox
#  http://stexpanded.wikia.com/Bruce_Maddox
#
# found:
#  http://memory-alpha.wikia.com/Brussels
#  http://stexpanded.wikia.com/Brussels
#
# found:
#  http://memory-alpha.wikia.com/Bryma
#  http://stexpanded.wikia.com/Bryma
#
# not found:
#  http://stexpanded.wikia.com/Cadet
#  http://memory-alpha.wikia.com/Cadet
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_cadets
#
# found:
#  http://memory-alpha.wikia.com/Cait
#  http://stexpanded.wikia.com/Cait
#
# not found:
#  http://stexpanded.wikia.com/Caitian
#  http://memory-alpha.wikia.com/Caitian
# found instead:
#  http://memory-alpha.wikia.com/Cait
#
# found:
#  http://memory-alpha.wikia.com/California
#  http://stexpanded.wikia.com/California
#
# not found:
#  http://stexpanded.wikia.com/Calvin_Hudson
#  http://memory-alpha.wikia.com/Calvin_Hudson
# found instead:
#  http://memory-alpha.wikia.com/Tyler_(male)
#
# found:
#  http://memory-alpha.wikia.com/Canberra
#  http://stexpanded.wikia.com/Canberra
#
# not found:
#  http://stexpanded.wikia.com/Canon
#  http://memory-alpha.wikia.com/Canon
# found instead:
#  http://memory-alpha.wikia.com/Fan_fiction
#
# found:
#  http://memory-alpha.wikia.com/Canopus_III
#  http://stexpanded.wikia.com/Canopus_III
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_dining_room
#  http://stexpanded.wikia.com/Captain%27s_dining_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_ready_room
#  http://stexpanded.wikia.com/Captain%27s_ready_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_yacht
#  http://stexpanded.wikia.com/Captain%27s_yacht
#
# found:
#  http://memory-alpha.wikia.com/Captain_of_engineering
#  http://stexpanded.wikia.com/Captain_of_Engineering
#
# found:
#  http://memory-alpha.wikia.com/Cardassia_Prime
#  http://stexpanded.wikia.com/Cardassia_Prime
#
# not found:
#  http://stexpanded.wikia.com/Cardassian
#  http://memory-alpha.wikia.com/Cardassian
# found instead:
#  http://memory-alpha.wikia.com/Cardassian_language
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Central_Command
#  http://stexpanded.wikia.com/Cardassian_Central_Command
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Liberation_Front
#  http://stexpanded.wikia.com/Cardassian_Rebellion
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Union
#  http://stexpanded.wikia.com/Cardassian_Union
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_dissident_movement
#  http://stexpanded.wikia.com/Cardassian_dissident_movement
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_neck_trick
#  http://stexpanded.wikia.com/Cardassian_neck_trick
#
# not found:
#  http://stexpanded.wikia.com/Cardassian_ranks
#  http://memory-alpha.wikia.com/Cardassian_ranks
# found instead:
#  http://memory-alpha.wikia.com/Legate
#
# not found:
#  http://stexpanded.wikia.com/Caretaker_(MCNL)
#  http://memory-alpha.wikia.com/Caretaker_(episode)
# found instead:
#  http://memory-alpha.wikia.com/Phage_(episode)
#
# found:
#  http://memory-alpha.wikia.com/Cargo_bay
#  http://stexpanded.wikia.com/Cargo_bay
#
# not found:
#  http://stexpanded.wikia.com/Work_bee
#  http://memory-alpha.wikia.com/Cargo_management_unit
# found instead:
#  http://memory-alpha.wikia.com/Workbee_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Regnancy_of_the_Carnelian_Throne
#  http://memory-alpha.wikia.com/Carnelian_minefield
# found instead:
#  http://memory-alpha.wikia.com/Empire
#
# found:
#  http://memory-alpha.wikia.com/Carol_Marcus
#  http://stexpanded.wikia.com/Carol_Marcus
#
# found:
#  http://memory-alpha.wikia.com/Carrington_Award
#  http://stexpanded.wikia.com/Carrington_Award
#
# found:
#  http://memory-alpha.wikia.com/Carson_(Ensign)
#  http://stexpanded.wikia.com/Sara_Carson
#
# found:
#  http://memory-alpha.wikia.com/Cartwright
#  http://stexpanded.wikia.com/Cartwright
#
# found:
#  http://memory-alpha.wikia.com/Casino
#  http://stexpanded.wikia.com/Casino
#
# found:
#  http://memory-alpha.wikia.com/Casperia_Prime
#  http://stexpanded.wikia.com/Casperia_Prime
#
# found:
#  http://memory-alpha.wikia.com/Cat
#  http://stexpanded.wikia.com/Cat
#
# not found:
#  http://stexpanded.wikia.com/Cell_(group)
#  http://memory-alpha.wikia.com/Cell
# found instead:
#  http://memory-alpha.wikia.com/Cell_(organization)
#
# found:
#  http://memory-alpha.wikia.com/Centaur_type
#  http://stexpanded.wikia.com/Centaur_class
#
# found:
#  http://memory-alpha.wikia.com/Central_University
#  http://stexpanded.wikia.com/Central_University
#
# not found:
#  http://stexpanded.wikia.com/Centurion
#  http://memory-alpha.wikia.com/Centurion
# found instead:
#  http://memory-alpha.wikia.com/Lieutenant_commander
#
# found:
#  http://memory-alpha.wikia.com/Cestus_III
#  http://stexpanded.wikia.com/Cestus_III
#
# found:
#  http://memory-alpha.wikia.com/Ceti_Alpha_V
#  http://stexpanded.wikia.com/Ceti_Alpha_V
#
# not found:
#  http://stexpanded.wikia.com/Chakotay
#  http://memory-alpha.wikia.com/Chakotay
# found instead:
#  http://memory-alpha.wikia.com/Patrick_Stewart_(Starfleet)
#
# found:
#  http://memory-alpha.wikia.com/Challenger_class
#  http://stexpanded.wikia.com/Challenger_class
#
# found:
#  http://memory-alpha.wikia.com/Champagne
#  http://stexpanded.wikia.com/Champagne
#
# found:
#  http://memory-alpha.wikia.com/Chancellor_of_the_Klingon_High_Council
#  http://stexpanded.wikia.com/Chancellor_of_the_Klingon_High_Council
#
# not found:
#  http://stexpanded.wikia.com/IKS_Che%27gra
#  http://memory-alpha.wikia.com/Chang%27s_Bird-of-Prey
# found instead:
#  http://memory-alpha.wikia.com/IKS_Hor%27Cha
#
# found:
#  http://memory-alpha.wikia.com/Change_of_Command
#  http://stexpanded.wikia.com/Change_of_Command
#
# not found:
#  http://stexpanded.wikia.com/Changeling
#  http://memory-alpha.wikia.com/Changeling
# found instead:
#  http://memory-alpha.wikia.com/Shapeshifter
#
# found:
#  http://memory-alpha.wikia.com/Charlene_Masters
#  http://stexpanded.wikia.com/Charlene_Masters
#
# found:
#  http://memory-alpha.wikia.com/Charles_Tucker_III
#  http://stexpanded.wikia.com/Charles_Tucker_III
#
# not found:
#  http://stexpanded.wikia.com/Chef
#  http://memory-alpha.wikia.com/Chef
# found instead:
#  http://memory-alpha.wikia.com/Caterer
#
# found:
#  http://memory-alpha.wikia.com/Chell
#  http://stexpanded.wikia.com/Chell
#
# found:
#  http://memory-alpha.wikia.com/Cheyenne_class
#  http://stexpanded.wikia.com/Cheyenne_class
#
# found:
#  http://memory-alpha.wikia.com/Chicago
#  http://stexpanded.wikia.com/Chicago
#
# not found:
#  http://stexpanded.wikia.com/Chief
#  http://memory-alpha.wikia.com/Chief
# found instead:
#  http://memory-alpha.wikia.com/Section_chief
#
# found:
#  http://memory-alpha.wikia.com/Chief_engineering_officer
#  http://stexpanded.wikia.com/Chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Chief_medical_officer
#  http://stexpanded.wikia.com/Chief_medical_officer
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Operations
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Security
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Security
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_operations
#  http://stexpanded.wikia.com/Chief_of_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_security
#  http://stexpanded.wikia.com/Security_chief
#
# found:
#  http://memory-alpha.wikia.com/Chin%27toka_system
#  http://stexpanded.wikia.com/Chin%27toka_system
#
# not found:
#  http://stexpanded.wikia.com/China
#  http://memory-alpha.wikia.com/China
# found instead:
#  http://memory-alpha.wikia.com/Russia
#
# found:
#  http://memory-alpha.wikia.com/Christchurch
#  http://stexpanded.wikia.com/Christchurch
#
# found:
#  http://memory-alpha.wikia.com/Christianity
#  http://stexpanded.wikia.com/Christianity
#
# found:
#  http://memory-alpha.wikia.com/Christine_Chapel
#  http://stexpanded.wikia.com/Christine_Chapel
#
# found:
#  http://memory-alpha.wikia.com/Christmas
#  http://stexpanded.wikia.com/Christmas
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike
#  http://memory-alpha.wikia.com/Christopher_Pike
# found instead:
#  http://memory-alpha.wikia.com/Christopher_Pike_(alternate_reality)
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_(alternate_reality)
#  http://stexpanded.wikia.com/Christopher_Pike_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike_(mirror)
#  http://memory-alpha.wikia.com/Christopher_Pike_(mirror)
# found instead:
#  http://memory-alpha.wikia.com/Mirror_universe
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_Medal_of_Valor
#  http://stexpanded.wikia.com/Christopher_Pike_Medal_of_Valor
#
# found:
#  http://memory-alpha.wikia.com/Chroniton
#  http://stexpanded.wikia.com/Chroniton
#
# found:
#  http://memory-alpha.wikia.com/Chroniton_radiation
#  http://stexpanded.wikia.com/Chroniton_radiation
#
# found:
#  http://memory-alpha.wikia.com/Chronometric_particle
#  http://stexpanded.wikia.com/Chronometric_particle
#
# found:
#  http://memory-alpha.wikia.com/City
#  http://stexpanded.wikia.com/City
#
# found:
#  http://memory-alpha.wikia.com/Clark_Terrell
#  http://stexpanded.wikia.com/Clark_Terrell
#
# found:
#  http://memory-alpha.wikia.com/Clarke%27s_Disease
#  http://stexpanded.wikia.com/Clarke%27s_Disease
#
# found:
#  http://memory-alpha.wikia.com/Class_4_probe
#  http://stexpanded.wikia.com/Class_4_probe
#
# found:
#  http://memory-alpha.wikia.com/Class_D
#  http://stexpanded.wikia.com/Class_D_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_H
#  http://stexpanded.wikia.com/Class_H_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_J_planet
#  http://stexpanded.wikia.com/Class_J_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_L
#  http://stexpanded.wikia.com/Class_L_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_M
#  http://stexpanded.wikia.com/Class_M_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_N
#  http://stexpanded.wikia.com/Class_N_planet
#
# not found:
#  http://stexpanded.wikia.com/Cloaking_device
#  http://memory-alpha.wikia.com/Cloaking_device
# found instead:
#  http://memory-alpha.wikia.com/Class_4_cloaking_device
#
# found:
#  http://memory-alpha.wikia.com/Clone
#  http://stexpanded.wikia.com/Clone
#
# found:
#  http://memory-alpha.wikia.com/Coalition_of_Planets
#  http://stexpanded.wikia.com/Coalition_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/Coaxial_warp_drive
#  http://stexpanded.wikia.com/Coaxial_warp_drive
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_Medal_of_Excellence
#  http://memory-alpha.wikia.com/Cochrane_Medal_of_Excellence
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_Medal_of_Commendation
#
# found:
#  http://memory-alpha.wikia.com/Code_47
#  http://stexpanded.wikia.com/Code_47
#
# found:
#  http://memory-alpha.wikia.com/Coffee
#  http://stexpanded.wikia.com/Coffee
#
# not found:
#  http://stexpanded.wikia.com/Coffin
#  http://memory-alpha.wikia.com/Coffin
# found instead:
#  http://memory-alpha.wikia.com/Graveyard
#
# found:
#  http://memory-alpha.wikia.com/Cold_Station_12
#  http://stexpanded.wikia.com/Cold_Station_12
#
# found:
#  http://memory-alpha.wikia.com/Cold_start
#  http://stexpanded.wikia.com/Cold_start
#
# found:
#  http://memory-alpha.wikia.com/Colonel
#  http://stexpanded.wikia.com/Colonel
#
# not found:
#  http://stexpanded.wikia.com/Colony
#  http://memory-alpha.wikia.com/Colony
# found instead:
#  http://memory-alpha.wikia.com/Federation_colonies
#
# found:
#  http://memory-alpha.wikia.com/Colorado
#  http://stexpanded.wikia.com/Colorado
#
# found:
#  http://memory-alpha.wikia.com/Columbia
#  http://stexpanded.wikia.com/Columbia_(NX-02)
#
# found:
#  http://memory-alpha.wikia.com/Combadge
#  http://stexpanded.wikia.com/Combadge
#
# found:
#  http://memory-alpha.wikia.com/Comet
#  http://stexpanded.wikia.com/Comet
#
# not found:
#  http://stexpanded.wikia.com/Command_chair
#  http://memory-alpha.wikia.com/Command_chair
# found instead:
#  http://memory-alpha.wikia.com/Star_Trek:_Captain%27s_Chair
#
# found:
#  http://memory-alpha.wikia.com/Command_division
#  http://stexpanded.wikia.com/Command_division
#
# not found:
#  http://stexpanded.wikia.com/Commandant
#  http://memory-alpha.wikia.com/Commandant
# found instead:
#  http://memory-alpha.wikia.com/Commandante_Cadets
#
# not found:
#  http://stexpanded.wikia.com/Commander
#  http://memory-alpha.wikia.com/Commander
# found instead:
#  http://memory-alpha.wikia.com/Commander,_Starfleet
#
# found:
#  http://memory-alpha.wikia.com/Commander_in_chief
#  http://stexpanded.wikia.com/Commander-in-Chief
#
# not found:
#  http://stexpanded.wikia.com/Commanding_officer
#  http://memory-alpha.wikia.com/Commanding_officer
# found instead:
#  http://memory-alpha.wikia.com/Ranking_officer
#
# found:
#  http://memory-alpha.wikia.com/Commodore
#  http://stexpanded.wikia.com/Commodore
#
# found:
#  http://memory-alpha.wikia.com/Communications
#  http://stexpanded.wikia.com/Communications
#
# found:
#  http://memory-alpha.wikia.com/Communications_officer
#  http://stexpanded.wikia.com/Communications_officer
#
# not found:
#  http://stexpanded.wikia.com/Computer
#  http://memory-alpha.wikia.com/Computer
# found instead:
#  http://memory-alpha.wikia.com/Database
#
# not found:
#  http://stexpanded.wikia.com/Conference_room
#  http://memory-alpha.wikia.com/Conference_room
# found instead:
#  http://memory-alpha.wikia.com/Briefing_room
#
# found:
#  http://memory-alpha.wikia.com/Conflicts
#  http://stexpanded.wikia.com/Conflicts
#
# found:
#  http://memory-alpha.wikia.com/Constellation_class
#  http://stexpanded.wikia.com/Constellation_class
#
# not found:
#  http://stexpanded.wikia.com/USS_Valkyrie_(NCC-2590)
#  http://memory-alpha.wikia.com/Constellation_class_model
# found instead:
#  http://memory-alpha.wikia.com/USS_Stargazer
#
# found:
#  http://memory-alpha.wikia.com/Constitution_class
#  http://stexpanded.wikia.com/Constitution_class
#
# found:
#  http://memory-alpha.wikia.com/Continent
#  http://stexpanded.wikia.com/Continent
#
# found:
#  http://memory-alpha.wikia.com/Convoy
#  http://stexpanded.wikia.com/Convoy
#
# found:
#  http://memory-alpha.wikia.com/Copernicus_Ship_Yards
#  http://stexpanded.wikia.com/Copernicus_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Coridan
#  http://memory-alpha.wikia.com/Coridan
# found instead:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#  http://stexpanded.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Corporal
#  http://stexpanded.wikia.com/Corporal
#
# not found:
#  http://stexpanded.wikia.com/Corsair
#  http://memory-alpha.wikia.com/Corsair
# found instead:
#  http://memory-alpha.wikia.com/Frigate
#
# found:
#  http://memory-alpha.wikia.com/Cortical_stimulator
#  http://stexpanded.wikia.com/Cortical_stimulator
#
# found:
#  http://memory-alpha.wikia.com/Council_of_Ministers
#  http://stexpanded.wikia.com/Council_of_Ministers
#
# not found:
#  http://stexpanded.wikia.com/Counselor
#  http://memory-alpha.wikia.com/Counselor
# found instead:
#  http://memory-alpha.wikia.com/Assistant_ship%27s_counselor
#
# found:
#  http://memory-alpha.wikia.com/Country
#  http://stexpanded.wikia.com/Country
#
# found:
#  http://memory-alpha.wikia.com/Coup_d%27état
#  http://stexpanded.wikia.com/Coup_d%27état
#
# not found:
#  http://stexpanded.wikia.com/Court-martial
#  http://memory-alpha.wikia.com/Court_martial
# found instead:
#  http://memory-alpha.wikia.com/Judges_and_arbiters
#
# found:
#  http://memory-alpha.wikia.com/Crewman
#  http://stexpanded.wikia.com/Crewman
#
# found:
#  http://memory-alpha.wikia.com/Cruiser
#  http://stexpanded.wikia.com/Cruiser
#
# found:
#  http://memory-alpha.wikia.com/Cryogenic_stasis
#  http://stexpanded.wikia.com/Cryogenic_stasis
#
# not found:
#  http://stexpanded.wikia.com/Cryosatellite
#  http://memory-alpha.wikia.com/Cryonics_satellite
# found instead:
#  http://memory-alpha.wikia.com/Cryostasis_chamber
#
# found:
#  http://memory-alpha.wikia.com/Cuellar_system
#  http://stexpanded.wikia.com/Cuellar_system
#
# found:
#  http://memory-alpha.wikia.com/Cutting_beam
#  http://stexpanded.wikia.com/Cutting_beam
#
# found:
#  http://memory-alpha.wikia.com/Cygnet_XIV
#  http://stexpanded.wikia.com/Cygnet_XIV
#
# found:
#  http://memory-alpha.wikia.com/D%27Kora_class
#  http://stexpanded.wikia.com/D%27Kora_class
#
# found:
#  http://memory-alpha.wikia.com/D%27deridex_class
#  http://stexpanded.wikia.com/D%27deridex_class
#
# found:
#  http://memory-alpha.wikia.com/D%27jarra
#  http://stexpanded.wikia.com/D%27jarra
#
# found:
#  http://memory-alpha.wikia.com/D7_class
#  http://stexpanded.wikia.com/D7_class
#
# found:
#  http://memory-alpha.wikia.com/DNA
#  http://stexpanded.wikia.com/DNA
#
# found:
#  http://memory-alpha.wikia.com/Dabo
#  http://stexpanded.wikia.com/Dabo
#
# found:
#  http://memory-alpha.wikia.com/DaiMon
#  http://stexpanded.wikia.com/DaiMon
#
# found:
#  http://memory-alpha.wikia.com/Dakar
#  http://stexpanded.wikia.com/Dakar_(city)
#
# found:
#  http://memory-alpha.wikia.com/Damage_control_team
#  http://stexpanded.wikia.com/Damage_control
#
# not found:
#  http://stexpanded.wikia.com/Damar
#  http://memory-alpha.wikia.com/Damar
# found instead:
#  http://memory-alpha.wikia.com/Rusot
#
# found:
#  http://memory-alpha.wikia.com/Dampening_field
#  http://stexpanded.wikia.com/Dampening_field
#
# found:
#  http://memory-alpha.wikia.com/Dance
#  http://stexpanded.wikia.com/Dance
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Crewman)
#  http://stexpanded.wikia.com/Daniels_(Crewman)
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Lieutenant)
#  http://stexpanded.wikia.com/Daniels_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Danube_class
#  http://stexpanded.wikia.com/Danube_class
#
# found:
#  http://memory-alpha.wikia.com/Danula_II
#  http://stexpanded.wikia.com/Danula_II
#
# found:
#  http://memory-alpha.wikia.com/Dark_matter_nebula
#  http://stexpanded.wikia.com/Dark_matter_nebula
#
# found:
#  http://memory-alpha.wikia.com/Daro
#  http://stexpanded.wikia.com/Daro
#
# found:
#  http://memory-alpha.wikia.com/Data
#  http://stexpanded.wikia.com/Data
#
# found:
#  http://memory-alpha.wikia.com/Dave_Bailey
#  http://stexpanded.wikia.com/Dave_Bailey
#
# not found:
#  http://stexpanded.wikia.com/Dax_(symbiont)
#  http://memory-alpha.wikia.com/Dax_(symbiont)
# found instead:
#  http://memory-alpha.wikia.com/Curzon_Dax
#
# found:
#  http://memory-alpha.wikia.com/Daystrom_Institute
#  http://stexpanded.wikia.com/Daystrom_Institute
#
# found:
#  http://memory-alpha.wikia.com/DePaul
#  http://stexpanded.wikia.com/DePaul
#
# not found:
#  http://stexpanded.wikia.com/DeSalle
#  http://memory-alpha.wikia.com/DeSalle
# found instead:
#  http://memory-alpha.wikia.com/Phase
#
# not found:
#  http://stexpanded.wikia.com/Deanna_Troi
#  http://memory-alpha.wikia.com/Deanna_Troi
# found instead:
#  http://memory-alpha.wikia.com/Klingon-Cardassian_Alliance_personnel
#
# found:
#  http://memory-alpha.wikia.com/Dedication_plaque
#  http://stexpanded.wikia.com/Dedication_plaque
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_3
#  http://stexpanded.wikia.com/Deep_Space_3
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_4
#  http://stexpanded.wikia.com/Deep_Space_4
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_5
#  http://stexpanded.wikia.com/Deep_Space_5
#
# not found:
#  http://stexpanded.wikia.com/Deep_Space_9
#  http://memory-alpha.wikia.com/Deep_Space_9
# found instead:
#  http://memory-alpha.wikia.com/Terok_Nor_(mirror)
#
# not found:
#  http://stexpanded.wikia.com/Venturi
#  http://memory-alpha.wikia.com/Deep_Space_9_visitors
# found instead:
#  http://memory-alpha.wikia.com/Ventu
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_Station_K-7
#  http://stexpanded.wikia.com/Deep_Space_Station_K-7
#
# not found:
#  http://stexpanded.wikia.com/USS_Defiant_(NX-74205)
#  http://memory-alpha.wikia.com/Defiant
# found instead:
#  http://memory-alpha.wikia.com/USS_Defiant_(2370)
#
# found:
#  http://memory-alpha.wikia.com/Defiant_class
#  http://stexpanded.wikia.com/Defiant_class
#
# not found:
#  http://stexpanded.wikia.com/Deflector_shield
#  http://memory-alpha.wikia.com/Deflector_shield
# found instead:
#  http://memory-alpha.wikia.com/Covariant_shielding
#
# found:
#  http://memory-alpha.wikia.com/Degree
#  http://stexpanded.wikia.com/Degree
#
# found:
#  http://memory-alpha.wikia.com/Delphic_Expanse
#  http://stexpanded.wikia.com/Delphic_Expanse
#
# not found:
#  http://stexpanded.wikia.com/Delta_Flyer
#  http://memory-alpha.wikia.com/Delta_Flyer
# found instead:
#  http://memory-alpha.wikia.com/Delta_Flyer_type
#
# not found:
#  http://stexpanded.wikia.com/Delta_IV
#  http://memory-alpha.wikia.com/Delta_IV
# found instead:
#  http://memory-alpha.wikia.com/Deltan
#
# not found:
#  http://stexpanded.wikia.com/Delta_Quadrant
#  http://memory-alpha.wikia.com/Delta_Quadrant
# found instead:
#  http://memory-alpha.wikia.com/Alpha_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Delta_Vega
#  http://memory-alpha.wikia.com/Delta_Vega
# found instead:
#  http://memory-alpha.wikia.com/Delta_Vega_sector
#
# found:
#  http://memory-alpha.wikia.com/Demilitarized_Zone
#  http://stexpanded.wikia.com/Demilitarized_Zone
#
# found:
#  http://memory-alpha.wikia.com/Demora_Sulu
#  http://stexpanded.wikia.com/Demora_Sulu
#
# not found:
#  http://stexpanded.wikia.com/Deneva
#  http://memory-alpha.wikia.com/Deneva
# found instead:
#  http://memory-alpha.wikia.com/Denevan
#
# found:
#  http://memory-alpha.wikia.com/Denmark
#  http://stexpanded.wikia.com/Denmark
#
# found:
#  http://memory-alpha.wikia.com/Denobula
#  http://stexpanded.wikia.com/Denobula
#
# found:
#  http://memory-alpha.wikia.com/Denobulan
#  http://stexpanded.wikia.com/Denobulan
#
# found:
#  http://memory-alpha.wikia.com/Dentistry
#  http://stexpanded.wikia.com/Dentist
#
# found:
#  http://memory-alpha.wikia.com/Department_of_Cartography
#  http://stexpanded.wikia.com/Department_of_Cartography
#
# found:
#  http://memory-alpha.wikia.com/Department_of_Temporal_Investigations
#  http://stexpanded.wikia.com/Department_of_Temporal_Investigations
#
# found:
#  http://memory-alpha.wikia.com/Dermal_regenerator
#  http://stexpanded.wikia.com/Dermal_regenerator
#
# found:
#  http://memory-alpha.wikia.com/Destroyer
#  http://stexpanded.wikia.com/Destroyer
#
# found:
#  http://memory-alpha.wikia.com/Detapa_Council
#  http://stexpanded.wikia.com/Detapa_Council
#
# found:
#  http://memory-alpha.wikia.com/Deuterium
#  http://stexpanded.wikia.com/Deuterium
#
# found:
#  http://memory-alpha.wikia.com/Devoras
#  http://stexpanded.wikia.com/IRW_Devoras
#
# not found:
#  http://stexpanded.wikia.com/Devore
#  http://memory-alpha.wikia.com/Devore
# found instead:
#  http://memory-alpha.wikia.com/Devore_Imperium
#
# found:
#  http://memory-alpha.wikia.com/Devos_II
#  http://stexpanded.wikia.com/Devos_II
#
# found:
#  http://memory-alpha.wikia.com/DiFalco
#  http://stexpanded.wikia.com/DiFalco
#
# found:
#  http://memory-alpha.wikia.com/Dikironium_cloud_creature
#  http://stexpanded.wikia.com/Dikironium_cloud_creature
#
# found:
#  http://memory-alpha.wikia.com/Dilithium
#  http://stexpanded.wikia.com/Dilithium
#
# found:
#  http://memory-alpha.wikia.com/Diplomacy_and_law
#  http://stexpanded.wikia.com/Diplomacy_and_law
#
# found:
#  http://memory-alpha.wikia.com/Directed_energy_weapon
#  http://stexpanded.wikia.com/Directed-energy_weapon
#
# not found:
#  http://stexpanded.wikia.com/Disruptor
#  http://memory-alpha.wikia.com/Disruptor
# found instead:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#  http://stexpanded.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_pistol
#  http://stexpanded.wikia.com/Disruptor_pistol
#
# not found:
#  http://stexpanded.wikia.com/Disruptor_rifle
#  http://memory-alpha.wikia.com/Disruptor_rifle
# found instead:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#
# not found:
#  http://stexpanded.wikia.com/Distant_past
#  http://memory-alpha.wikia.com/Distant_past
# found instead:
#  http://memory-alpha.wikia.com/3rd_century
#
# found:
#  http://memory-alpha.wikia.com/Distress_call
#  http://stexpanded.wikia.com/Distress_call
#
# found:
#  http://memory-alpha.wikia.com/Dividices
#  http://stexpanded.wikia.com/IRW_Dividices
#
# not found:
#  http://stexpanded.wikia.com/Division
#  http://memory-alpha.wikia.com/Division
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_division
#
# found:
#  http://memory-alpha.wikia.com/Doctor
#  http://stexpanded.wikia.com/Doctor
#
# found:
#  http://memory-alpha.wikia.com/Doctor_Who
#  http://stexpanded.wikia.com/Doctor_Who
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Medicine
#  http://stexpanded.wikia.com/Doctor_of_Medicine
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Philosophy
#  http://stexpanded.wikia.com/Doctor_of_Science
#
# not found:
#  http://stexpanded.wikia.com/Dominion
#  http://memory-alpha.wikia.com/Dominion
# found instead:
#  http://memory-alpha.wikia.com/Nygean
#
# found:
#  http://memory-alpha.wikia.com/Dominion_Headquarters
#  http://stexpanded.wikia.com/Dominion_Headquarters
#
# found:
#  http://memory-alpha.wikia.com/Dominion_War
#  http://stexpanded.wikia.com/Dominion_War
#
# found:
#  http://memory-alpha.wikia.com/Donatra
#  http://stexpanded.wikia.com/Donatra
#
# found:
#  http://memory-alpha.wikia.com/Dorian_Collins
#  http://stexpanded.wikia.com/Dorian_Collins_(USS_Baldwin)
#
# found:
#  http://memory-alpha.wikia.com/Dorvan_sector
#  http://stexpanded.wikia.com/Dorvan_sector
#
# found:
#  http://memory-alpha.wikia.com/Dragon
#  http://stexpanded.wikia.com/Dragon
#
# found:
#  http://memory-alpha.wikia.com/Dreadnought
#  http://stexpanded.wikia.com/Dreadnought
#
# found:
#  http://memory-alpha.wikia.com/Dukat
#  http://stexpanded.wikia.com/Dukat
#
# found:
#  http://memory-alpha.wikia.com/Dulmur
#  http://stexpanded.wikia.com/Dulmur
#
# found:
#  http://memory-alpha.wikia.com/Duranium
#  http://stexpanded.wikia.com/Duranium
#
# found:
# ...
#
# found:
#  http://memory-alpha.wikia.com/USS_Yukon
#  http://stexpanded.wikia.com/USS_Yukon
#
# found:
#  http://memory-alpha.wikia.com/USS_Zapata
#  http://stexpanded.wikia.com/USS_Zapata
#
# found:
#  http://memory-alpha.wikia.com/USS_Zhukov
#  http://stexpanded.wikia.com/USS_Zhukov_(NCC-26136)
#
# found:
#  http://memory-alpha.wikia.com/Uhlan
#  http://stexpanded.wikia.com/Uhlan
#
# found:
#  http://memory-alpha.wikia.com/Ultritium
#  http://stexpanded.wikia.com/Ultritium
#
# found:
#  http://memory-alpha.wikia.com/Ultritium_concussion_shell
#  http://stexpanded.wikia.com/Ultritium_concussion_shell
#
# found:
#  http://memory-alpha.wikia.com/Uniform
#  http://stexpanded.wikia.com/Uniform
#
# found:
#  http://memory-alpha.wikia.com/United_Earth
#  http://stexpanded.wikia.com/United_Earth
#
# found:
#  http://memory-alpha.wikia.com/United_Earth_Space_Probe_Agency
#  http://stexpanded.wikia.com/United_Earth_Space_Probe_Agency
#
# not found:
#  http://stexpanded.wikia.com/United_Federation_of_Planets
#  http://memory-alpha.wikia.com/United_Federation_of_Planets
# found instead:
#  http://memory-alpha.wikia.com/Charter_of_the_United_Federation_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/United_Nations
#  http://stexpanded.wikia.com/United_Nations
#
# found:
#  http://memory-alpha.wikia.com/United_States_armed_forces
#  http://stexpanded.wikia.com/United_States_armed_forces
#
# found:
#  http://memory-alpha.wikia.com/United_States_of_America
#  http://stexpanded.wikia.com/United_States_of_America
#
# found:
#  http://memory-alpha.wikia.com/Universal_translator
#  http://stexpanded.wikia.com/Universal_translator
#
# found:
#  http://memory-alpha.wikia.com/University
#  http://stexpanded.wikia.com/University
#
# found:
#  http://memory-alpha.wikia.com/University_of_Betazed
#  http://stexpanded.wikia.com/University_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/University_of_California,_Berkeley
#  http://stexpanded.wikia.com/University_of_California,_Berkeley
#
# found:
#  http://memory-alpha.wikia.com/University_of_Culat
#  http://stexpanded.wikia.com/University_of_Culat
#
# found:
#  http://memory-alpha.wikia.com/University_of_Mississippi
#  http://stexpanded.wikia.com/University_of_Mississippi
#
# found:
#  http://memory-alpha.wikia.com/Unnamed_Oberth_class_starships
#  http://stexpanded.wikia.com/USS_Bonestell_(NCC-31600)
#
# not found:
#  http://stexpanded.wikia.com/IKS_Vor%27cha
#  http://memory-alpha.wikia.com/Unnamed_Vor%27cha_class_starships
# found instead:
#  http://memory-alpha.wikia.com/IKS_Vor%27nak
#
# found:
#  http://memory-alpha.wikia.com/Utopia_Planitia
#  http://stexpanded.wikia.com/Utopia_Planitia
#
# found:
#  http://memory-alpha.wikia.com/Utopia_Planitia_Fleet_Yards
#  http://stexpanded.wikia.com/Utopia_Planitia_Fleet_Yards
#
# found:
#  http://memory-alpha.wikia.com/Uttan_Narsu
#  http://stexpanded.wikia.com/Uttan_Narsu
#
# found:
#  http://memory-alpha.wikia.com/V%27Shar
#  http://stexpanded.wikia.com/V%27Shar
#
# found:
#  http://memory-alpha.wikia.com/Vaadwaur
#  http://stexpanded.wikia.com/Vaadwaur
#
# found:
#  http://memory-alpha.wikia.com/Vadosia
#  http://stexpanded.wikia.com/Vadosia
#
# not found:
#  http://stexpanded.wikia.com/Valdore
#  http://memory-alpha.wikia.com/Valdore
# found instead:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#
# found:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#  http://stexpanded.wikia.com/IRW_Valdore
#
# found:
#  http://memory-alpha.wikia.com/Valdore_type
#  http://stexpanded.wikia.com/Valdore_type
#
# found:
#  http://memory-alpha.wikia.com/Valeris
#  http://stexpanded.wikia.com/Valeris
#
# found:
#  http://memory-alpha.wikia.com/Valo_II
#  http://stexpanded.wikia.com/Valo_II
#
# found:
#  http://memory-alpha.wikia.com/Vash
#  http://stexpanded.wikia.com/Vash
#
# found:
#  http://memory-alpha.wikia.com/Vedek
#  http://stexpanded.wikia.com/Vedek
#
# found:
#  http://memory-alpha.wikia.com/Vedek_Assembly
#  http://stexpanded.wikia.com/Vedek_Assembly
#
# found:
#  http://memory-alpha.wikia.com/Velocity
#  http://stexpanded.wikia.com/Velocity
#
# found:
#  http://memory-alpha.wikia.com/Verathan
#  http://stexpanded.wikia.com/Verathan
#
# found:
#  http://memory-alpha.wikia.com/Veridian_III
#  http://stexpanded.wikia.com/Veridian_III
#
# found:
#  http://memory-alpha.wikia.com/Vetar
#  http://stexpanded.wikia.com/Vetar
#
# found:
#  http://memory-alpha.wikia.com/Vice_admiral
#  http://stexpanded.wikia.com/Vice_admiral
#
# found:
#  http://memory-alpha.wikia.com/Vidiian_Sodality
#  http://stexpanded.wikia.com/Vidiian_Sodality
#
# found:
#  http://memory-alpha.wikia.com/Viewscreen
#  http://stexpanded.wikia.com/Viewscreen
#
# found:
#  http://memory-alpha.wikia.com/Volleyball
#  http://stexpanded.wikia.com/Volleyball
#
# found:
#  http://memory-alpha.wikia.com/Vor%27cha_class
#  http://stexpanded.wikia.com/Vor%27cha_class
#
# found:
#  http://memory-alpha.wikia.com/Vorgon
#  http://stexpanded.wikia.com/Vorgon
#
# found:
#  http://memory-alpha.wikia.com/Vorik
#  http://stexpanded.wikia.com/Vorik
#
# found:
#  http://memory-alpha.wikia.com/Vorta
#  http://stexpanded.wikia.com/Vorta
#
# found:
#  http://memory-alpha.wikia.com/Vosk
#  http://stexpanded.wikia.com/Vosk
#
# found:
#  http://memory-alpha.wikia.com/Voth
#  http://stexpanded.wikia.com/Voth
#
# not found:
#  http://stexpanded.wikia.com/Merken_tr%27Vreenak
#  http://memory-alpha.wikia.com/Vreenak
# found instead:
#  http://memory-alpha.wikia.com/Hamlet
#
# not found:
#  http://stexpanded.wikia.com/Vulcan
#  http://memory-alpha.wikia.com/Vulcan
# found instead:
#  http://memory-alpha.wikia.com/Spock_(disambiguation)
#
# not found:
#  http://stexpanded.wikia.com/Vulcan%27s_Forge
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge
# found instead:
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_(planet)
#  http://stexpanded.wikia.com/Vulcan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_Science_Academy
#  http://stexpanded.wikia.com/Vulcan_Science_Academy
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_ranks
#  http://memory-alpha.wikia.com/Vulcan_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_system
#  http://memory-alpha.wikia.com/Vulcan_system
# found instead:
#  http://memory-alpha.wikia.com/40_Eridani_A
#
# found:
#  http://memory-alpha.wikia.com/Walker_Keel
#  http://stexpanded.wikia.com/Walker_Keel
#
# found:
#  http://memory-alpha.wikia.com/Warbird
#  http://stexpanded.wikia.com/Warbird
#
# found:
#  http://memory-alpha.wikia.com/Warp_coil
#  http://stexpanded.wikia.com/Warp_coil
#
# found:
#  http://memory-alpha.wikia.com/Warp_core
#  http://stexpanded.wikia.com/Warp_core
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_breach
#  http://stexpanded.wikia.com/Warp_core_breach
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_ejection_system
#  http://stexpanded.wikia.com/Warp_core_ejection_system
#
# found:
#  http://memory-alpha.wikia.com/Warp_drive
#  http://stexpanded.wikia.com/Warp_drive
#
# found:
#  http://memory-alpha.wikia.com/Warship
#  http://stexpanded.wikia.com/Warship
#
# not found:
#  http://stexpanded.wikia.com/Jennifer_Watley
#  http://memory-alpha.wikia.com/Watley
# found instead:
#  http://memory-alpha.wikia.com/Watley_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Weather_modification_network
#  http://stexpanded.wikia.com/Weather_modification_network
#
# found:
#  http://memory-alpha.wikia.com/Wedding
#  http://stexpanded.wikia.com/Wedding
#
# found:
#  http://memory-alpha.wikia.com/Wellington
#  http://stexpanded.wikia.com/Wellington
#
# found:
#  http://memory-alpha.wikia.com/Wendell_Greer
#  http://stexpanded.wikia.com/Wendell_Greer
#
# found:
#  http://memory-alpha.wikia.com/Wesley_Crusher
#  http://stexpanded.wikia.com/Wesley_Crusher
#
# found:
#  http://memory-alpha.wikia.com/West_Point
#  http://stexpanded.wikia.com/West_Point
#
# found:
#  http://memory-alpha.wikia.com/Weyoun
#  http://stexpanded.wikia.com/Weyoun
#
# found:
#  http://memory-alpha.wikia.com/Will_Decker
#  http://stexpanded.wikia.com/Willard_Decker
#
# not found:
#  http://stexpanded.wikia.com/William_Ross
#  http://memory-alpha.wikia.com/William_Ross
# found instead:
#  http://memory-alpha.wikia.com/Bennet_(Captain)
#
# found:
#  http://memory-alpha.wikia.com/William_Shakespeare
#  http://stexpanded.wikia.com/William_Shakespeare
#
# not found:
#  http://stexpanded.wikia.com/William_T._Riker
#  http://memory-alpha.wikia.com/William_T._Riker
# found instead:
#  http://memory-alpha.wikia.com/Personal_log,_William_T._Riker
#
# found:
#  http://memory-alpha.wikia.com/William_Telfer
#  http://stexpanded.wikia.com/William_Telfer
#
# found:
#  http://memory-alpha.wikia.com/Wine
#  http://stexpanded.wikia.com/Wine
#
# found:
#  http://memory-alpha.wikia.com/Wolf_359
#  http://stexpanded.wikia.com/Wolf_359
#
# not found:
#  http://stexpanded.wikia.com/Worf
#  http://memory-alpha.wikia.com/Worf
# found instead:
#  http://memory-alpha.wikia.com/Kurn
#
# found:
#  http://memory-alpha.wikia.com/World_War_II
#  http://stexpanded.wikia.com/World_War_II
#
# found:
#  http://memory-alpha.wikia.com/World_War_III
#  http://stexpanded.wikia.com/World_War_III
#
# found:
#  http://memory-alpha.wikia.com/Wormhole
#  http://stexpanded.wikia.com/Wormhole
#
# found:
#  http://memory-alpha.wikia.com/X-ray_laser
#  http://stexpanded.wikia.com/X-ray_laser
#
# found:
#  http://memory-alpha.wikia.com/Xenophobia
#  http://stexpanded.wikia.com/Xenophobia
#
# found:
#  http://memory-alpha.wikia.com/Xindi
#  http://stexpanded.wikia.com/Xindi
#
# found:
#  http://memory-alpha.wikia.com/Xindi-Aquatic
#  http://stexpanded.wikia.com/Xindi-Aquatic
#
# found:
#  http://memory-alpha.wikia.com/Xon
#  http://stexpanded.wikia.com/Xon
#
# found:
#  http://memory-alpha.wikia.com/Yaderan
#  http://stexpanded.wikia.com/Yaderan
#
# found:
#  http://memory-alpha.wikia.com/Yeager_type
#  http://stexpanded.wikia.com/Yeager_class
#
# found:
#  http://memory-alpha.wikia.com/Yelgrun
#  http://stexpanded.wikia.com/Yelgrun
#
# found:
#  http://memory-alpha.wikia.com/Yellow_alert
#  http://stexpanded.wikia.com/Yellow_alert
#
# found:
#  http://memory-alpha.wikia.com/Yellowstone_class
#  http://stexpanded.wikia.com/Yellowstone_class
#
# found:
#  http://memory-alpha.wikia.com/Yeoman
#  http://stexpanded.wikia.com/Yeoman
#
# found:
#  http://memory-alpha.wikia.com/Yoyodyne_Propulsion_Systems
#  http://stexpanded.wikia.com/Yoyodyne_Division
#
# found:
#  http://memory-alpha.wikia.com/Yridian
#  http://stexpanded.wikia.com/Yridian
#
# found:
#  http://memory-alpha.wikia.com/Zabathu
#  http://stexpanded.wikia.com/Zabathu
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_High_School
#  http://memory-alpha.wikia.com/Zefram_Cochrane_High_School
# found instead:
#  http://memory-alpha.wikia.com/Cochrane
#
# found:
#  http://memory-alpha.wikia.com/Zero_gravity
#  http://stexpanded.wikia.com/Zero_gravity
#
# found:
#  http://memory-alpha.wikia.com/Zhian%27tara
#  http://stexpanded.wikia.com/Zhian%27tara
#
# found:
#  http://memory-alpha.wikia.com/Zoo
#  http://stexpanded.wikia.com/Zoo
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship
#  http://stexpanded.wikia.com/class/starship-sidebar
#
# not found:
#  http://stexpanded.wikia.com/class/character
#  http://memory-alpha.wikia.com/class/sidebar_individual
# found instead:
#  http://memory-alpha.wikia.com/class/mb
#
# not found:
#  http://stexpanded.wikia.com/class/yearbox
#  http://memory-alpha.wikia.com/class/sidebar_year
# found instead:
#  http://memory-alpha.wikia.com/class/ste
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship_class
#  http://stexpanded.wikia.com/class/starship-class
#
# found:
#  http://memory-alpha.wikia.com/class/uss
#  http://stexpanded.wikia.com/class/uss
#
# found:
#  http://memory-alpha.wikia.com/class/ds9
#  http://stexpanded.wikia.com/class/ds9
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_planet
#  http://stexpanded.wikia.com/class/planet_info
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_military_conflict
#  http://stexpanded.wikia.com/class/battle_data
#
# found:
#  http://memory-alpha.wikia.com/class/voy
#  http://stexpanded.wikia.com/class/voy
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_species
#  http://stexpanded.wikia.com/class/sidebar_species
#
# found:
#  http://memory-alpha.wikia.com/class/tng
#  http://stexpanded.wikia.com/class/tng
#
# found:
#  http://memory-alpha.wikia.com/class/ent
#  http://stexpanded.wikia.com/class/ent
#
# found:
#  http://memory-alpha.wikia.com/class/film
#  http://stexpanded.wikia.com/class/film
#
# found:
#  http://memory-alpha.wikia.com/name
#  http://stexpanded.wikia.com/name
#
# found:
#  http://memory-alpha.wikia.com/species
#  http://stexpanded.wikia.com/species
#
# found:
#  http://memory-alpha.wikia.com/status
#  http://stexpanded.wikia.com/status
#
# found:
#  http://memory-alpha.wikia.com/rank
#  http://stexpanded.wikia.com/rank
#
# found:
#  http://memory-alpha.wikia.com/affiliation
#  http://stexpanded.wikia.com/affiliation
#
# not found:
#  http://stexpanded.wikia.com/defense
#  http://memory-alpha.wikia.com/defenses
# found instead:
#  http://memory-alpha.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/combatant
#  http://stexpanded.wikia.com/combatant
#
# found:
#  http://memory-alpha.wikia.com/type
#  http://stexpanded.wikia.com/type
#
# found:
#  http://memory-alpha.wikia.com/father
#  http://stexpanded.wikia.com/father
#
# found:
#  http://memory-alpha.wikia.com/gender
#  http://stexpanded.wikia.com/gender
#
# found:
#  http://memory-alpha.wikia.com/mother
#  http://stexpanded.wikia.com/mother
#
# found:
#  http://memory-alpha.wikia.com/born
#  http://stexpanded.wikia.com/born
#
# found:
#  http://memory-alpha.wikia.com/relatives
#  http://stexpanded.wikia.com/relatives
#
# found:
#  http://memory-alpha.wikia.com/died
#  http://stexpanded.wikia.com/died
#
# found:
#  http://memory-alpha.wikia.com/armament
#  http://stexpanded.wikia.com/armament
#
# found:
#  http://memory-alpha.wikia.com/spouse
#  http://stexpanded.wikia.com/spouse
#
# found:
#  http://memory-alpha.wikia.com/sibling
#  http://stexpanded.wikia.com/siblings
#
# found:
#  http://memory-alpha.wikia.com/children
#  http://stexpanded.wikia.com/children
#
# found:
#  http://memory-alpha.wikia.com/date
#  http://stexpanded.wikia.com/date
#
# found:
#  http://memory-alpha.wikia.com/location
#  http://stexpanded.wikia.com/location
#
# found:
#  http://memory-alpha.wikia.com/crew
#  http://stexpanded.wikia.com/crew
#
# found:
#  http://memory-alpha.wikia.com/result
#  http://stexpanded.wikia.com/result
#
# found:
#  http://memory-alpha.wikia.com/occupation
#  http://stexpanded.wikia.com/occupation
#
# found:
#  http://memory-alpha.wikia.com/strength
#  http://stexpanded.wikia.com/strength
#
# found:
#  http://memory-alpha.wikia.com/class
#  http://stexpanded.wikia.com/class
#
# found:
#  http://memory-alpha.wikia.com/planet
#  http://stexpanded.wikia.com/planet
#
# found:
#  http://memory-alpha.wikia.com/image
#  http://stexpanded.wikia.com/image
#
# found:
#  http://memory-alpha.wikia.com/military
#  http://stexpanded.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/capital
#  http://stexpanded.wikia.com/capital
#
# found:
#  http://memory-alpha.wikia.com/majorSpecies
#  http://stexpanded.wikia.com/majorSpecies
#
# found:
#  http://memory-alpha.wikia.com/headOfState
#  http://stexpanded.wikia.com/headOfState
#
# found:
#  http://memory-alpha.wikia.com/season
#  http://stexpanded.wikia.com/season
#
# found:
#  http://memory-alpha.wikia.com/year
#  http://stexpanded.wikia.com/year
#
# found:
#  http://memory-alpha.wikia.com/registry
#  http://stexpanded.wikia.com/registry
#
# found:
#  http://memory-alpha.wikia.com/headOfGovernment
#  http://stexpanded.wikia.com/headOfGovernment
#
# found:
#  http://memory-alpha.wikia.com/actor
#  http://stexpanded.wikia.com/actor
#
# not found:
#  http://stexpanded.wikia.com/found
#  http://memory-alpha.wikia.com/founded
# found instead:
#  http://memory-alpha.wikia.com/from
#
# found:
#  http://memory-alpha.wikia.com/guest
#  http://stexpanded.wikia.com/guest
#
# found:
#  http://memory-alpha.wikia.com/artist
#  http://stexpanded.wikia.com/artist
#
# found:
#  http://memory-alpha.wikia.com/publisher
#  http://stexpanded.wikia.com/publisher
#
# found:
#  http://memory-alpha.wikia.com/beam
#  http://stexpanded.wikia.com/beam

# %%
all_pairs = len(gold_pairs)
# for gold_pair in tqdm(gold_pairs):
for gold_pair in gold_pairs:
    if top1dict_node_neig_comm.get(gold_pair[1]) == gold_pair[0]:
        print("found:", "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
    else:
        print("not found:", "\n",
              mappings_small[gold_pair[1]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n",
              mappings_big[gold_pair[0]]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""),
              "\nfound instead:", "\n",
              mappings_big[top1dict_node_neig_comm.get(gold_pair[1])]
              .replace("dbkwik.webdatacommons.org/", "")
              .replace("property/", "")
              .replace("resource/", ""), "\n")
# Out:
# found:
#  http://memory-alpha.wikia.com/18th_century
#  http://stexpanded.wikia.com/18th_century
#
# found:
#  http://memory-alpha.wikia.com/1991
#  http://stexpanded.wikia.com/1991
#
# not found:
#  http://stexpanded.wikia.com/1992
#  http://memory-alpha.wikia.com/1992
# found instead:
#  http://memory-alpha.wikia.com/Khan_Noonien_Singh_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/1996
#  http://memory-alpha.wikia.com/1996
# found instead:
#  http://memory-alpha.wikia.com/Joachim
#
# found:
#  http://memory-alpha.wikia.com/19th_century
#  http://stexpanded.wikia.com/19th_century
#
# found:
#  http://memory-alpha.wikia.com/20th_century
#  http://stexpanded.wikia.com/20th_century
#
# found:
#  http://memory-alpha.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#  http://stexpanded.wikia.com/40_Eridani_A_Starfleet_Construction_Yards
#
# not found:
#  http://stexpanded.wikia.com/47
#  http://memory-alpha.wikia.com/47
# found instead:
#  http://memory-alpha.wikia.com/Square_root
#
# found:
#  http://memory-alpha.wikia.com/602_Club
#  http://stexpanded.wikia.com/602_Club
#
# not found:
#  http://stexpanded.wikia.com/Magna_Roma
#  http://memory-alpha.wikia.com/892-IV
# found instead:
#  http://memory-alpha.wikia.com/Roman_Empire_(892-IV)
#
# not found:
#  http://stexpanded.wikia.com/Alyson_Foxton
#  http://memory-alpha.wikia.com/A.F.
# found instead:
#  http://memory-alpha.wikia.com/Alden
#
# not found:
#  http://stexpanded.wikia.com/Aaamazzarite
#  http://memory-alpha.wikia.com/Aaamazzarite
# found instead:
#  http://memory-alpha.wikia.com/Mazarite
#
# found:
#  http://memory-alpha.wikia.com/Aberdeen
#  http://stexpanded.wikia.com/Aberdeen
#
# found:
#  http://memory-alpha.wikia.com/Ablative_armor
#  http://stexpanded.wikia.com/Ablative_armor
#
# found:
#  http://memory-alpha.wikia.com/Acamarian
#  http://stexpanded.wikia.com/Acamarian
#
# found:
#  http://memory-alpha.wikia.com/Acting_captain
#  http://stexpanded.wikia.com/Acting_captain
#
# found:
#  http://memory-alpha.wikia.com/Actor
#  http://stexpanded.wikia.com/Actor
#
# found:
#  http://memory-alpha.wikia.com/Adarak_Prime
#  http://stexpanded.wikia.com/Adarak_Prime
#
# not found:
#  http://stexpanded.wikia.com/Admiral
#  http://memory-alpha.wikia.com/Admiral
# found instead:
#  http://memory-alpha.wikia.com/Fleet_admiral
#
# found:
#  http://memory-alpha.wikia.com/Advanced_Tactical_Training
#  http://stexpanded.wikia.com/Advanced_Tactical_Training_Program
#
# found:
#  http://memory-alpha.wikia.com/Aenar
#  http://stexpanded.wikia.com/Aenar
#
# found:
#  http://memory-alpha.wikia.com/Aeroshuttle
#  http://stexpanded.wikia.com/Aeroshuttle
#
# not found:
#  http://stexpanded.wikia.com/Africa
#  http://memory-alpha.wikia.com/Africa
# found instead:
#  http://memory-alpha.wikia.com/South_Africa
#
# found:
#  http://memory-alpha.wikia.com/Afterlife
#  http://stexpanded.wikia.com/Afterlife
#
# found:
#  http://memory-alpha.wikia.com/Aircraft_carrier
#  http://stexpanded.wikia.com/Aircraft_carrier
#
# found:
#  http://memory-alpha.wikia.com/Alaska
#  http://stexpanded.wikia.com/Alaska
#
# found:
#  http://memory-alpha.wikia.com/Alcohol
#  http://stexpanded.wikia.com/Alcohol
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran
#  http://stexpanded.wikia.com/Aldebaran_system
#
# not found:
#  http://stexpanded.wikia.com/Aldebaran_Prime
#  http://memory-alpha.wikia.com/Aldebaran_III
# found instead:
#  http://memory-alpha.wikia.com/Aldebaran
#
# found:
#  http://memory-alpha.wikia.com/Aldebaran_whiskey
#  http://stexpanded.wikia.com/Aldebaran_whiskey
#
# found:
#  http://memory-alpha.wikia.com/Alden
#  http://stexpanded.wikia.com/Alden
#
# found:
#  http://memory-alpha.wikia.com/Alexander_Rozhenko
#  http://stexpanded.wikia.com/Alexander_Rozhenko
#
# found:
#  http://memory-alpha.wikia.com/Alien
#  http://stexpanded.wikia.com/Alien
#
# not found:
#  http://stexpanded.wikia.com/Alliance
#  http://memory-alpha.wikia.com/Alliance
# found instead:
#  http://memory-alpha.wikia.com/Alliance_(nation)
#
# found:
#  http://memory-alpha.wikia.com/Almatha_sector
#  http://stexpanded.wikia.com/Almatha_sector
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Centauri
#  http://stexpanded.wikia.com/Alpha_Centauri_system
#
# found:
#  http://memory-alpha.wikia.com/Alpha_Quadrant
#  http://stexpanded.wikia.com/Alpha_Quadrant
#
# found:
#  http://memory-alpha.wikia.com/Alsuran_Empire
#  http://stexpanded.wikia.com/Alsuran
#
# found:
#  http://memory-alpha.wikia.com/Altair_water
#  http://stexpanded.wikia.com/Altair_water
#
# not found:
#  http://stexpanded.wikia.com/Alternate_reality
#  http://memory-alpha.wikia.com/Alternate_reality
# found instead:
#  http://memory-alpha.wikia.com/Quantum_reality
#
# not found:
#  http://stexpanded.wikia.com/Alternate_timeline
#  http://memory-alpha.wikia.com/Alternate_timeline
# found instead:
#  http://memory-alpha.wikia.com/Time
#
# found:
#  http://memory-alpha.wikia.com/Altonian_brain_teaser
#  http://stexpanded.wikia.com/Altonian_brain_teaser
#
# found:
#  http://memory-alpha.wikia.com/Alynna_Nechayev
#  http://stexpanded.wikia.com/Alynna_Nechayev
#
# found:
#  http://memory-alpha.wikia.com/Amanda_Grayson
#  http://stexpanded.wikia.com/Amanda_Grayson
#
# not found:
#  http://stexpanded.wikia.com/Ambassador
#  http://memory-alpha.wikia.com/Ambassador
# found instead:
#  http://memory-alpha.wikia.com/Ambassadors
#
# found:
#  http://memory-alpha.wikia.com/Ambassador_class
#  http://stexpanded.wikia.com/Ambassador_class
#
# found:
#  http://memory-alpha.wikia.com/American_Civil_War
#  http://stexpanded.wikia.com/American_Civil_War
#
# found:
#  http://memory-alpha.wikia.com/American_Revolution
#  http://stexpanded.wikia.com/American_Revolutionary_War
#
# not found:
#  http://stexpanded.wikia.com/Amnesia
#  http://memory-alpha.wikia.com/Amnesia
# found instead:
#  http://memory-alpha.wikia.com/Anterograde_amnesia
#
# found:
#  http://memory-alpha.wikia.com/Amusement_park
#  http://stexpanded.wikia.com/Amusement_park
#
# not found:
#  http://stexpanded.wikia.com/Ancient_humanoid
#  http://memory-alpha.wikia.com/Ancient_humanoid
# found instead:
#  http://memory-alpha.wikia.com/Preservers
#
# found:
#  http://memory-alpha.wikia.com/Andoria
#  http://stexpanded.wikia.com/Andoria
#
# found:
#  http://memory-alpha.wikia.com/Andorian
#  http://stexpanded.wikia.com/Andorian
#
# found:
#  http://memory-alpha.wikia.com/Andorian_Imperial_Guard
#  http://stexpanded.wikia.com/Andorian_Imperial_Guard
#
# found:
#  http://memory-alpha.wikia.com/Andorian_battle_cruiser
#  http://stexpanded.wikia.com/Kumari_class
#
# found:
#  http://memory-alpha.wikia.com/Android
#  http://stexpanded.wikia.com/Android
#
# found:
#  http://memory-alpha.wikia.com/Andromeda_Galaxy
#  http://stexpanded.wikia.com/Andromeda_Galaxy
#
# found:
#  http://memory-alpha.wikia.com/Anesthizine
#  http://stexpanded.wikia.com/Anesthizine
#
# found:
#  http://memory-alpha.wikia.com/Antares_Ship_Yards
#  http://stexpanded.wikia.com/Antares_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Antares_class_(Starfleet)
#  http://memory-alpha.wikia.com/Antares_type
# found instead:
#  http://memory-alpha.wikia.com/USS_Antares
#
# found:
#  http://memory-alpha.wikia.com/Anthropology
#  http://stexpanded.wikia.com/Anthropology
#
# found:
#  http://memory-alpha.wikia.com/Antideuterium
#  http://stexpanded.wikia.com/Anti-deuterium
#
# not found:
#  http://stexpanded.wikia.com/Antimatter
#  http://memory-alpha.wikia.com/Antimatter
# found instead:
#  http://memory-alpha.wikia.com/Antiproton
#
# found:
#  http://memory-alpha.wikia.com/Antwerp
#  http://stexpanded.wikia.com/Antwerp
#
# found:
#  http://memory-alpha.wikia.com/Apollo_class
#  http://stexpanded.wikia.com/Apollo_class
#
# found:
#  http://memory-alpha.wikia.com/Aquiel_Uhnari
#  http://stexpanded.wikia.com/Aquiel_Uhnari
#
# found:
#  http://memory-alpha.wikia.com/Arboretum
#  http://stexpanded.wikia.com/Arboretum
#
# not found:
#  http://stexpanded.wikia.com/Archaeology
#  http://memory-alpha.wikia.com/Archaeology
# found instead:
#  http://memory-alpha.wikia.com/Archaeologist
#
# found:
#  http://memory-alpha.wikia.com/Archaeology_and_anthropology_officer
#  http://stexpanded.wikia.com/Archaeology_and_anthropology_officer
#
# found:
#  http://memory-alpha.wikia.com/Archanis_sector
#  http://stexpanded.wikia.com/Archanis_sector
#
# found:
#  http://memory-alpha.wikia.com/Architecture
#  http://stexpanded.wikia.com/Architecture
#
# found:
#  http://memory-alpha.wikia.com/Archon_(starship)
#  http://stexpanded.wikia.com/USS_Archon_(NCC-189)
#
# found:
#  http://memory-alpha.wikia.com/Arex
#  http://stexpanded.wikia.com/Arex
#
# not found:
#  http://stexpanded.wikia.com/Argo_type
#  http://memory-alpha.wikia.com/Argo_(shuttlecraft)
# found instead:
#  http://memory-alpha.wikia.com/Type_6_shuttlecraft
#
# found:
#  http://memory-alpha.wikia.com/Argolis_Cluster
#  http://stexpanded.wikia.com/Argolis_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Argus_X
#  http://stexpanded.wikia.com/Argus_X
#
# found:
#  http://memory-alpha.wikia.com/Ariannus
#  http://stexpanded.wikia.com/Ariannus
#
# found:
#  http://memory-alpha.wikia.com/Arkonian
#  http://stexpanded.wikia.com/Arkonian
#
# found:
#  http://memory-alpha.wikia.com/Armory
#  http://stexpanded.wikia.com/Armory
#
# found:
#  http://memory-alpha.wikia.com/Armory_officer
#  http://stexpanded.wikia.com/Armory_officer
#
# not found:
#  http://stexpanded.wikia.com/USS_Armstrong_(NCC-57537)
#  http://memory-alpha.wikia.com/Armstrong_(disambiguation)
# found instead:
#  http://memory-alpha.wikia.com/USS_Neil_Armstrong
#
# found:
#  http://memory-alpha.wikia.com/Armus
#  http://stexpanded.wikia.com/Armus
#
# found:
#  http://memory-alpha.wikia.com/Artificial_intelligence
#  http://stexpanded.wikia.com/Artificial_intelligence
#
# found:
#  http://memory-alpha.wikia.com/Asia
#  http://stexpanded.wikia.com/Asia
#
# found:
#  http://memory-alpha.wikia.com/Assault_team
#  http://stexpanded.wikia.com/Assault_team
#
# found:
#  http://memory-alpha.wikia.com/Assignment_patch
#  http://stexpanded.wikia.com/Assignment_patch
#
# found:
#  http://memory-alpha.wikia.com/Assimilation
#  http://stexpanded.wikia.com/Assimilation
#
# found:
#  http://memory-alpha.wikia.com/Assistant_chief_engineer
#  http://stexpanded.wikia.com/Assistant_chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Asteroid
#  http://stexpanded.wikia.com/Asteroid
#
# found:
#  http://memory-alpha.wikia.com/Astrometrics
#  http://stexpanded.wikia.com/Astrometrics
#
# found:
#  http://memory-alpha.wikia.com/Atlanta
#  http://stexpanded.wikia.com/Atlanta
#
# found:
#  http://memory-alpha.wikia.com/Atlantic_Ocean
#  http://stexpanded.wikia.com/Atlantic_Ocean
#
# found:
#  http://memory-alpha.wikia.com/Attack_cruiser
#  http://stexpanded.wikia.com/Attack_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Attack_fighter
#  http://stexpanded.wikia.com/Attack_fighter
#
# found:
#  http://memory-alpha.wikia.com/Auction
#  http://stexpanded.wikia.com/Auction
#
# not found:
#  http://stexpanded.wikia.com/Audrid_Dax
#  http://memory-alpha.wikia.com/Audrid_Dax
# found instead:
#  http://memory-alpha.wikia.com/Lela_Dax
#
# found:
#  http://memory-alpha.wikia.com/Augment
#  http://stexpanded.wikia.com/Augment
#
# found:
#  http://memory-alpha.wikia.com/Aurelian
#  http://stexpanded.wikia.com/Aurelian
#
# found:
#  http://memory-alpha.wikia.com/Australia
#  http://stexpanded.wikia.com/Australia
#
# found:
#  http://memory-alpha.wikia.com/Autarch
#  http://stexpanded.wikia.com/Autarch
#
# found:
#  http://memory-alpha.wikia.com/Auto-destruct
#  http://stexpanded.wikia.com/Auto-destruct
#
# found:
#  http://memory-alpha.wikia.com/Auxiliary_space_vessel
#  http://stexpanded.wikia.com/Auxiliary_craft
#
# found:
#  http://memory-alpha.wikia.com/Avenal_VII
#  http://stexpanded.wikia.com/Avenal_VII
#
# found:
#  http://memory-alpha.wikia.com/Away_mission
#  http://stexpanded.wikia.com/Away_mission
#
# found:
#  http://memory-alpha.wikia.com/Away_team
#  http://stexpanded.wikia.com/Away_team
#
# not found:
#  http://stexpanded.wikia.com/Axanar
#  http://memory-alpha.wikia.com/Axanar
# found instead:
#  http://memory-alpha.wikia.com/Axanar_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Azetbur
#  http://stexpanded.wikia.com/Azetbur
#
# found:
#  http://memory-alpha.wikia.com/B%27Elanna_Torres
#  http://stexpanded.wikia.com/B%27Elanna_Torres
#
# found:
#  http://memory-alpha.wikia.com/B.G._Robinson
#  http://stexpanded.wikia.com/B.G._Robinson
#
# not found:
#  http://stexpanded.wikia.com/Ba%27ku
#  http://memory-alpha.wikia.com/Ba%27ku
# found instead:
#  http://memory-alpha.wikia.com/Ba%27ku_planet
#
# not found:
#  http://stexpanded.wikia.com/Badlands
#  http://memory-alpha.wikia.com/Badlands
# found instead:
#  http://memory-alpha.wikia.com/Etymology
#
# found:
#  http://memory-alpha.wikia.com/Baikonur_Cosmodrome
#  http://stexpanded.wikia.com/Baikonur_Cosmodrome
#
# found:
#  http://memory-alpha.wikia.com/Bajor
#  http://stexpanded.wikia.com/Bajor
#
# found:
#  http://memory-alpha.wikia.com/Bajor_sector
#  http://stexpanded.wikia.com/Bajor_sector
#
# found:
#  http://memory-alpha.wikia.com/Bajoran
#  http://stexpanded.wikia.com/Bajoran
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Militia
#  http://stexpanded.wikia.com/Bajoran_Militia
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Republic
#  http://stexpanded.wikia.com/Bajoran_Provisional_Government
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_Resistance
#  http://stexpanded.wikia.com/Bajoran_Resistance
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_language
#  http://stexpanded.wikia.com/Bajoran_language
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_ranks
#  http://memory-alpha.wikia.com/Bajoran_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_religion
#  http://stexpanded.wikia.com/Bajoran_religion
#
# not found:
#  http://stexpanded.wikia.com/Bajoran_system
#  http://memory-alpha.wikia.com/Bajoran_system
# found instead:
#  http://memory-alpha.wikia.com/Bajoran
#
# found:
#  http://memory-alpha.wikia.com/Bajoran_wormhole
#  http://stexpanded.wikia.com/Bajoran_wormhole
#
# not found:
#  http://stexpanded.wikia.com/Bar
#  http://memory-alpha.wikia.com/Bar
# found instead:
#  http://memory-alpha.wikia.com/Tavern
#
# found:
#  http://memory-alpha.wikia.com/Barkonian
#  http://stexpanded.wikia.com/Barkonian
#
# found:
#  http://memory-alpha.wikia.com/Barnard%27s_Star
#  http://stexpanded.wikia.com/Barnard%27s_Star
#
# found:
#  http://memory-alpha.wikia.com/Barstow_(Commodore)
#  http://stexpanded.wikia.com/Barstow
#
# not found:
#  http://stexpanded.wikia.com/Bartender
#  http://memory-alpha.wikia.com/Bartender
# found instead:
#  http://memory-alpha.wikia.com/Waiter
#
# not found:
#  http://stexpanded.wikia.com/Baseball
#  http://memory-alpha.wikia.com/Baseball
# found instead:
#  http://memory-alpha.wikia.com/Soccer
#
# found:
#  http://memory-alpha.wikia.com/Basketball
#  http://stexpanded.wikia.com/Basketball
#
# found:
#  http://memory-alpha.wikia.com/Bat%27leth
#  http://stexpanded.wikia.com/Bat%27leth
#
# found:
#  http://memory-alpha.wikia.com/Battle_cruiser
#  http://stexpanded.wikia.com/Battle_cruiser
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Axanar
#  http://stexpanded.wikia.com/Battle_of_Axanar
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Betazed
#  http://stexpanded.wikia.com/Battle_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cardassia
#  http://stexpanded.wikia.com/Battle_of_Cardassia
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Cheron
#  http://stexpanded.wikia.com/Battle_of_Cheron
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Klach_D%27kel_Brakt
#  http://stexpanded.wikia.com/Battle_of_Klach_D%27kel_Brakt
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Procyon_V
#  http://stexpanded.wikia.com/Battle_of_Procyon_V
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Ricktor_Prime
#  http://stexpanded.wikia.com/Battle_of_Ricktor_Prime
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_Sector_001
#  http://stexpanded.wikia.com/Battle_of_Sector_001
#
# found:
#  http://memory-alpha.wikia.com/Battle_of_the_Omarion_Nebula
#  http://stexpanded.wikia.com/Battle_of_the_Omarion_Nebula
#
# found:
#  http://memory-alpha.wikia.com/Battleship
#  http://stexpanded.wikia.com/Battleship
#
# found:
#  http://memory-alpha.wikia.com/Beer
#  http://stexpanded.wikia.com/Beer
#
# found:
#  http://memory-alpha.wikia.com/Bekk
#  http://stexpanded.wikia.com/Bekk
#
# found:
#  http://memory-alpha.wikia.com/Belgium
#  http://stexpanded.wikia.com/Belgium
#
# found:
#  http://memory-alpha.wikia.com/Bendii_Syndrome
#  http://stexpanded.wikia.com/Bendii_Syndrome
#
# found:
#  http://memory-alpha.wikia.com/Benecia_Colony
#  http://stexpanded.wikia.com/Benecia_Colony
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Finney
#  http://stexpanded.wikia.com/Ben_Finney
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Maxwell
#  http://stexpanded.wikia.com/Benjamin_Maxwell
#
# found:
#  http://memory-alpha.wikia.com/Benjamin_Sisko
#  http://stexpanded.wikia.com/Benjamin_Sisko
#
# found:
#  http://memory-alpha.wikia.com/Benny_Russell
#  http://stexpanded.wikia.com/Benny_Russell
#
# found:
#  http://memory-alpha.wikia.com/Benzar
#  http://stexpanded.wikia.com/Benzar
#
# not found:
#  http://stexpanded.wikia.com/Benzenite
#  http://memory-alpha.wikia.com/Benzenite
# found instead:
#  http://memory-alpha.wikia.com/Magnesite
#
# found:
#  http://memory-alpha.wikia.com/Benzite_system
#  http://stexpanded.wikia.com/Benzite_system
#
# found:
#  http://memory-alpha.wikia.com/Berengaria_VII
#  http://stexpanded.wikia.com/Berengaria_VII
#
# not found:
#  http://stexpanded.wikia.com/Berlin
#  http://memory-alpha.wikia.com/Berlin
# found instead:
#  http://memory-alpha.wikia.com/Berlin_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Berlinghoff_Rasmussen
#  http://stexpanded.wikia.com/Berlinghoff_Rasmussen
#
# found:
#  http://memory-alpha.wikia.com/Berthold_ray
#  http://stexpanded.wikia.com/Berthold_ray
#
# found:
#  http://memory-alpha.wikia.com/Beta_Antares_Ship_Yards
#  http://stexpanded.wikia.com/Beta_Antares_Ship_Yards
#
# found:
#  http://memory-alpha.wikia.com/Beta_Quadrant
#  http://stexpanded.wikia.com/Beta_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Beverly_Crusher
#  http://memory-alpha.wikia.com/Beverly_Crusher
# found instead:
#  http://memory-alpha.wikia.com/Gates_McFadden
#
# found:
#  http://memory-alpha.wikia.com/Bible
#  http://stexpanded.wikia.com/Bible
#
# found:
#  http://memory-alpha.wikia.com/Bilitrium
#  http://stexpanded.wikia.com/Bilitrium
#
# found:
#  http://memory-alpha.wikia.com/Bio-dampener
#  http://stexpanded.wikia.com/Bio-dampener
#
# found:
#  http://memory-alpha.wikia.com/Bio-neural_circuitry
#  http://stexpanded.wikia.com/Bio-neural_circuitry
#
# found:
#  http://memory-alpha.wikia.com/Biosynthetic_limb
#  http://stexpanded.wikia.com/Biosynthetic_limb
#
# found:
#  http://memory-alpha.wikia.com/Bird-of-Prey
#  http://stexpanded.wikia.com/Bird-of-Prey
#
# not found:
#  http://stexpanded.wikia.com/Birthday
#  http://memory-alpha.wikia.com/Birthday
# found instead:
#  http://memory-alpha.wikia.com/Birthday_party
#
# not found:
#  http://stexpanded.wikia.com/Black_hole
#  http://memory-alpha.wikia.com/Black_hole
# found instead:
#  http://memory-alpha.wikia.com/Singularity
#
# found:
#  http://memory-alpha.wikia.com/Bloodwine
#  http://stexpanded.wikia.com/Bloodwine
#
# found:
#  http://memory-alpha.wikia.com/Blue_alert
#  http://stexpanded.wikia.com/Blue_alert
#
# found:
#  http://memory-alpha.wikia.com/Bolarus_IX
#  http://stexpanded.wikia.com/Bolarus_IX
#
# found:
#  http://memory-alpha.wikia.com/Bolian
#  http://stexpanded.wikia.com/Bolian
#
# not found:
#  http://stexpanded.wikia.com/SS_Bonaventure
#  http://memory-alpha.wikia.com/Bonaventure
# found instead:
#  http://memory-alpha.wikia.com/Bonaventure_(C1-21)
#
# not found:
#  http://stexpanded.wikia.com/Boothby
#  http://memory-alpha.wikia.com/Boothby
# found instead:
#  http://memory-alpha.wikia.com/Boothby_(Species_8472)
#
# not found:
#  http://stexpanded.wikia.com/Borath
#  http://memory-alpha.wikia.com/Borath
# found instead:
#  http://memory-alpha.wikia.com/Vorta
#
# not found:
#  http://stexpanded.wikia.com/Border
#  http://memory-alpha.wikia.com/Border
# found instead:
#  http://memory-alpha.wikia.com/Annexation
#
# not found:
#  http://stexpanded.wikia.com/Borg
#  http://memory-alpha.wikia.com/Borg
# found instead:
#  http://memory-alpha.wikia.com/Borg_history
#
# not found:
#  http://stexpanded.wikia.com/Borg_Collective
#  http://memory-alpha.wikia.com/Borg_Collective
# found instead:
#  http://memory-alpha.wikia.com/Borg_Queen
#
# found:
#  http://memory-alpha.wikia.com/Borg_Queen
#  http://stexpanded.wikia.com/Borg_Queen
#
# found:
#  http://memory-alpha.wikia.com/Borg_cube
#  http://stexpanded.wikia.com/Borg_cube
#
# found:
#  http://memory-alpha.wikia.com/Borg_drone
#  http://stexpanded.wikia.com/Borg_drone
#
# found:
#  http://memory-alpha.wikia.com/Borg_probe
#  http://stexpanded.wikia.com/Borg_probe
#
# found:
#  http://memory-alpha.wikia.com/Borg_sphere
#  http://stexpanded.wikia.com/Borg_sphere
#
# found:
#  http://memory-alpha.wikia.com/Borg_tactical_cube
#  http://stexpanded.wikia.com/Borg_tactical_cube
#
# found:
#  http://memory-alpha.wikia.com/Borias_Cluster
#  http://stexpanded.wikia.com/Borias_Cluster
#
# found:
#  http://memory-alpha.wikia.com/Bowsers
#  http://stexpanded.wikia.com/Bowser
#
# found:
#  http://memory-alpha.wikia.com/Boy_Scout
#  http://stexpanded.wikia.com/Boy_Scouts
#
# found:
#  http://memory-alpha.wikia.com/Bradbury_class
#  http://stexpanded.wikia.com/Bradbury_class
#
# found:
#  http://memory-alpha.wikia.com/Braxton
#  http://stexpanded.wikia.com/Braxton
#
# found:
#  http://memory-alpha.wikia.com/Bread
#  http://stexpanded.wikia.com/Bread
#
# found:
#  http://memory-alpha.wikia.com/Breen
#  http://stexpanded.wikia.com/Breen
#
# found:
#  http://memory-alpha.wikia.com/Breen_(planet)
#  http://stexpanded.wikia.com/Breen_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Breen_Confederacy
#  http://stexpanded.wikia.com/Breen_Confederacy
#
# found:
#  http://memory-alpha.wikia.com/Breen_attack_on_Earth
#  http://stexpanded.wikia.com/Breen_attack_on_Earth
#
# found:
#  http://memory-alpha.wikia.com/Breen_warship
#  http://stexpanded.wikia.com/Gor_Taan_class
#
# found:
#  http://memory-alpha.wikia.com/Briar_Patch
#  http://stexpanded.wikia.com/Briar_Patch
#
# not found:
#  http://stexpanded.wikia.com/Bridge
#  http://memory-alpha.wikia.com/Bridge
# found instead:
#  http://memory-alpha.wikia.com/Bridge_officer
#
# found:
#  http://memory-alpha.wikia.com/Bridge_Officer%27s_Test
#  http://stexpanded.wikia.com/Bridge_Officer%27s_Test
#
# found:
#  http://memory-alpha.wikia.com/Bridge_officer
#  http://stexpanded.wikia.com/Bridge_officer
#
# not found:
#  http://stexpanded.wikia.com/Brig
#  http://memory-alpha.wikia.com/Brig
# found instead:
#  http://memory-alpha.wikia.com/Security_holding_area
#
# not found:
#  http://stexpanded.wikia.com/Brigadier_general
#  http://memory-alpha.wikia.com/Brigadier
# found instead:
#  http://memory-alpha.wikia.com/General
#
# not found:
#  http://stexpanded.wikia.com/Briori
#  http://memory-alpha.wikia.com/Briori
# found instead:
#  http://memory-alpha.wikia.com/1937
#
# found:
#  http://memory-alpha.wikia.com/Brisbane
#  http://stexpanded.wikia.com/Brisbane
#
# found:
#  http://memory-alpha.wikia.com/Bruce_Maddox
#  http://stexpanded.wikia.com/Bruce_Maddox
#
# found:
#  http://memory-alpha.wikia.com/Brussels
#  http://stexpanded.wikia.com/Brussels
#
# found:
#  http://memory-alpha.wikia.com/Bryma
#  http://stexpanded.wikia.com/Bryma
#
# not found:
#  http://stexpanded.wikia.com/Cadet
#  http://memory-alpha.wikia.com/Cadet
# found instead:
#  http://memory-alpha.wikia.com/Enlisted
#
# found:
#  http://memory-alpha.wikia.com/Cait
#  http://stexpanded.wikia.com/Cait
#
# found:
#  http://memory-alpha.wikia.com/Caitian
#  http://stexpanded.wikia.com/Caitian
#
# found:
#  http://memory-alpha.wikia.com/California
#  http://stexpanded.wikia.com/California
#
# not found:
#  http://stexpanded.wikia.com/Calvin_Hudson
#  http://memory-alpha.wikia.com/Calvin_Hudson
# found instead:
#  http://memory-alpha.wikia.com/Columbus
#
# found:
#  http://memory-alpha.wikia.com/Canberra
#  http://stexpanded.wikia.com/Canberra
#
# not found:
#  http://stexpanded.wikia.com/Canon
#  http://memory-alpha.wikia.com/Canon
# found instead:
#  http://memory-alpha.wikia.com/Fan_fiction
#
# found:
#  http://memory-alpha.wikia.com/Canopus_III
#  http://stexpanded.wikia.com/Canopus_III
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_dining_room
#  http://stexpanded.wikia.com/Captain%27s_dining_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_ready_room
#  http://stexpanded.wikia.com/Captain%27s_ready_room
#
# found:
#  http://memory-alpha.wikia.com/Captain%27s_yacht
#  http://stexpanded.wikia.com/Captain%27s_yacht
#
# found:
#  http://memory-alpha.wikia.com/Captain_of_engineering
#  http://stexpanded.wikia.com/Captain_of_Engineering
#
# found:
#  http://memory-alpha.wikia.com/Cardassia_Prime
#  http://stexpanded.wikia.com/Cardassia_Prime
#
# not found:
#  http://stexpanded.wikia.com/Cardassian
#  http://memory-alpha.wikia.com/Cardassian
# found instead:
#  http://memory-alpha.wikia.com/Cardassian_language
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Central_Command
#  http://stexpanded.wikia.com/Cardassian_Central_Command
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Liberation_Front
#  http://stexpanded.wikia.com/Cardassian_Rebellion
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_Union
#  http://stexpanded.wikia.com/Cardassian_Union
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_dissident_movement
#  http://stexpanded.wikia.com/Cardassian_dissident_movement
#
# found:
#  http://memory-alpha.wikia.com/Cardassian_neck_trick
#  http://stexpanded.wikia.com/Cardassian_neck_trick
#
# not found:
#  http://stexpanded.wikia.com/Cardassian_ranks
#  http://memory-alpha.wikia.com/Cardassian_ranks
# found instead:
#  http://memory-alpha.wikia.com/Legate
#
# not found:
#  http://stexpanded.wikia.com/Caretaker_(MCNL)
#  http://memory-alpha.wikia.com/Caretaker_(episode)
# found instead:
#  http://memory-alpha.wikia.com/Once_Upon_a_Time_(episode)
#
# found:
#  http://memory-alpha.wikia.com/Cargo_bay
#  http://stexpanded.wikia.com/Cargo_bay
#
# not found:
#  http://stexpanded.wikia.com/Work_bee
#  http://memory-alpha.wikia.com/Cargo_management_unit
# found instead:
#  http://memory-alpha.wikia.com/Workbee_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Regnancy_of_the_Carnelian_Throne
#  http://memory-alpha.wikia.com/Carnelian_minefield
# found instead:
#  http://memory-alpha.wikia.com/Spartacus
#
# found:
#  http://memory-alpha.wikia.com/Carol_Marcus
#  http://stexpanded.wikia.com/Carol_Marcus
#
# found:
#  http://memory-alpha.wikia.com/Carrington_Award
#  http://stexpanded.wikia.com/Carrington_Award
#
# found:
#  http://memory-alpha.wikia.com/Carson_(Ensign)
#  http://stexpanded.wikia.com/Sara_Carson
#
# found:
#  http://memory-alpha.wikia.com/Cartwright
#  http://stexpanded.wikia.com/Cartwright
#
# found:
#  http://memory-alpha.wikia.com/Casino
#  http://stexpanded.wikia.com/Casino
#
# found:
#  http://memory-alpha.wikia.com/Casperia_Prime
#  http://stexpanded.wikia.com/Casperia_Prime
#
# found:
#  http://memory-alpha.wikia.com/Cat
#  http://stexpanded.wikia.com/Cat
#
# not found:
#  http://stexpanded.wikia.com/Cell_(group)
#  http://memory-alpha.wikia.com/Cell
# found instead:
#  http://memory-alpha.wikia.com/Cell_(organization)
#
# found:
#  http://memory-alpha.wikia.com/Centaur_type
#  http://stexpanded.wikia.com/Centaur_class
#
# found:
#  http://memory-alpha.wikia.com/Central_University
#  http://stexpanded.wikia.com/Central_University
#
# not found:
#  http://stexpanded.wikia.com/Centurion
#  http://memory-alpha.wikia.com/Centurion
# found instead:
#  http://memory-alpha.wikia.com/Romulan_ranks
#
# found:
#  http://memory-alpha.wikia.com/Cestus_III
#  http://stexpanded.wikia.com/Cestus_III
#
# found:
#  http://memory-alpha.wikia.com/Ceti_Alpha_V
#  http://stexpanded.wikia.com/Ceti_Alpha_V
#
# not found:
#  http://stexpanded.wikia.com/Chakotay
#  http://memory-alpha.wikia.com/Chakotay
# found instead:
#  http://memory-alpha.wikia.com/Chell
#
# found:
#  http://memory-alpha.wikia.com/Challenger_class
#  http://stexpanded.wikia.com/Challenger_class
#
# found:
#  http://memory-alpha.wikia.com/Champagne
#  http://stexpanded.wikia.com/Champagne
#
# found:
#  http://memory-alpha.wikia.com/Chancellor_of_the_Klingon_High_Council
#  http://stexpanded.wikia.com/Chancellor_of_the_Klingon_High_Council
#
# not found:
#  http://stexpanded.wikia.com/IKS_Che%27gra
#  http://memory-alpha.wikia.com/Chang%27s_Bird-of-Prey
# found instead:
#  http://memory-alpha.wikia.com/IKS_Vor%27nak
#
# found:
#  http://memory-alpha.wikia.com/Change_of_Command
#  http://stexpanded.wikia.com/Change_of_Command
#
# not found:
#  http://stexpanded.wikia.com/Changeling
#  http://memory-alpha.wikia.com/Changeling
# found instead:
#  http://memory-alpha.wikia.com/Solids
#
# found:
#  http://memory-alpha.wikia.com/Charlene_Masters
#  http://stexpanded.wikia.com/Charlene_Masters
#
# found:
#  http://memory-alpha.wikia.com/Charles_Tucker_III
#  http://stexpanded.wikia.com/Charles_Tucker_III
#
# not found:
#  http://stexpanded.wikia.com/Chef
#  http://memory-alpha.wikia.com/Chef
# found instead:
#  http://memory-alpha.wikia.com/Cook_stove
#
# found:
#  http://memory-alpha.wikia.com/Chell
#  http://stexpanded.wikia.com/Chell
#
# found:
#  http://memory-alpha.wikia.com/Cheyenne_class
#  http://stexpanded.wikia.com/Cheyenne_class
#
# found:
#  http://memory-alpha.wikia.com/Chicago
#  http://stexpanded.wikia.com/Chicago
#
# not found:
#  http://stexpanded.wikia.com/Chief
#  http://memory-alpha.wikia.com/Chief
# found instead:
#  http://memory-alpha.wikia.com/Section_chief
#
# found:
#  http://memory-alpha.wikia.com/Chief_engineering_officer
#  http://stexpanded.wikia.com/Chief_engineer
#
# found:
#  http://memory-alpha.wikia.com/Chief_medical_officer
#  http://stexpanded.wikia.com/Chief_medical_officer
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Operations
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_Starfleet_Security
#  http://stexpanded.wikia.com/Chief_of_Starfleet_Security
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_operations
#  http://stexpanded.wikia.com/Chief_of_Operations
#
# found:
#  http://memory-alpha.wikia.com/Chief_of_security
#  http://stexpanded.wikia.com/Security_chief
#
# found:
#  http://memory-alpha.wikia.com/Chin%27toka_system
#  http://stexpanded.wikia.com/Chin%27toka_system
#
# not found:
#  http://stexpanded.wikia.com/China
#  http://memory-alpha.wikia.com/China
# found instead:
#  http://memory-alpha.wikia.com/India
#
# found:
#  http://memory-alpha.wikia.com/Christchurch
#  http://stexpanded.wikia.com/Christchurch
#
# found:
#  http://memory-alpha.wikia.com/Christianity
#  http://stexpanded.wikia.com/Christianity
#
# not found:
#  http://stexpanded.wikia.com/Christine_Chapel
#  http://memory-alpha.wikia.com/Christine_Chapel
# found instead:
#  http://memory-alpha.wikia.com/Christine_Chapel_(alternate_reality)
#
# found:
#  http://memory-alpha.wikia.com/Christmas
#  http://stexpanded.wikia.com/Christmas
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike
#  http://memory-alpha.wikia.com/Christopher_Pike
# found instead:
#  http://memory-alpha.wikia.com/Mirror_universe
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_(alternate_reality)
#  http://stexpanded.wikia.com/Christopher_Pike_(alternate_reality)
#
# not found:
#  http://stexpanded.wikia.com/Christopher_Pike_(mirror)
#  http://memory-alpha.wikia.com/Christopher_Pike_(mirror)
# found instead:
#  http://memory-alpha.wikia.com/Mirror_universe
#
# found:
#  http://memory-alpha.wikia.com/Christopher_Pike_Medal_of_Valor
#  http://stexpanded.wikia.com/Christopher_Pike_Medal_of_Valor
#
# found:
#  http://memory-alpha.wikia.com/Chroniton
#  http://stexpanded.wikia.com/Chroniton
#
# found:
#  http://memory-alpha.wikia.com/Chroniton_radiation
#  http://stexpanded.wikia.com/Chroniton_radiation
#
# found:
#  http://memory-alpha.wikia.com/Chronometric_particle
#  http://stexpanded.wikia.com/Chronometric_particle
#
# found:
#  http://memory-alpha.wikia.com/City
#  http://stexpanded.wikia.com/City
#
# found:
#  http://memory-alpha.wikia.com/Clark_Terrell
#  http://stexpanded.wikia.com/Clark_Terrell
#
# found:
#  http://memory-alpha.wikia.com/Clarke%27s_Disease
#  http://stexpanded.wikia.com/Clarke%27s_Disease
#
# found:
#  http://memory-alpha.wikia.com/Class_4_probe
#  http://stexpanded.wikia.com/Class_4_probe
#
# found:
#  http://memory-alpha.wikia.com/Class_D
#  http://stexpanded.wikia.com/Class_D_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_H
#  http://stexpanded.wikia.com/Class_H_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_J_planet
#  http://stexpanded.wikia.com/Class_J_planet
#
# found:
#  http://memory-alpha.wikia.com/Class_L
#  http://stexpanded.wikia.com/Class_L_planet
#
# not found:
#  http://stexpanded.wikia.com/Class_M_planet
#  http://memory-alpha.wikia.com/Class_M
# found instead:
#  http://memory-alpha.wikia.com/2390s
#
# not found:
#  http://stexpanded.wikia.com/Class_N_planet
#  http://memory-alpha.wikia.com/Class_N
# found instead:
#  http://memory-alpha.wikia.com/Planetary_classification
#
# found:
#  http://memory-alpha.wikia.com/Cloaking_device
#  http://stexpanded.wikia.com/Cloaking_device
#
# found:
#  http://memory-alpha.wikia.com/Clone
#  http://stexpanded.wikia.com/Clone
#
# found:
#  http://memory-alpha.wikia.com/Coalition_of_Planets
#  http://stexpanded.wikia.com/Coalition_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/Coaxial_warp_drive
#  http://stexpanded.wikia.com/Coaxial_warp_drive
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_Medal_of_Excellence
#  http://memory-alpha.wikia.com/Cochrane_Medal_of_Excellence
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_Medal_of_Honor
#
# found:
#  http://memory-alpha.wikia.com/Code_47
#  http://stexpanded.wikia.com/Code_47
#
# found:
#  http://memory-alpha.wikia.com/Coffee
#  http://stexpanded.wikia.com/Coffee
#
# not found:
#  http://stexpanded.wikia.com/Coffin
#  http://memory-alpha.wikia.com/Coffin
# found instead:
#  http://memory-alpha.wikia.com/Graveyard
#
# found:
#  http://memory-alpha.wikia.com/Cold_Station_12
#  http://stexpanded.wikia.com/Cold_Station_12
#
# found:
#  http://memory-alpha.wikia.com/Cold_start
#  http://stexpanded.wikia.com/Cold_start
#
# found:
#  http://memory-alpha.wikia.com/Colonel
#  http://stexpanded.wikia.com/Colonel
#
# not found:
#  http://stexpanded.wikia.com/Colony
#  http://memory-alpha.wikia.com/Colony
# found instead:
#  http://memory-alpha.wikia.com/Federation_colonies
#
# found:
#  http://memory-alpha.wikia.com/Colorado
#  http://stexpanded.wikia.com/Colorado
#
# found:
#  http://memory-alpha.wikia.com/Columbia
#  http://stexpanded.wikia.com/Columbia_(NX-02)
#
# found:
#  http://memory-alpha.wikia.com/Combadge
#  http://stexpanded.wikia.com/Combadge
#
# found:
#  http://memory-alpha.wikia.com/Comet
#  http://stexpanded.wikia.com/Comet
#
# not found:
#  http://stexpanded.wikia.com/Command_chair
#  http://memory-alpha.wikia.com/Command_chair
# found instead:
#  http://memory-alpha.wikia.com/Star_Trek:_Captain%27s_Chair
#
# found:
#  http://memory-alpha.wikia.com/Command_division
#  http://stexpanded.wikia.com/Command_division
#
# found:
#  http://memory-alpha.wikia.com/Commandant
#  http://stexpanded.wikia.com/Commandant
#
# not found:
#  http://stexpanded.wikia.com/Commander
#  http://memory-alpha.wikia.com/Commander
# found instead:
#  http://memory-alpha.wikia.com/Commander,_Starfleet
#
# found:
#  http://memory-alpha.wikia.com/Commander_in_chief
#  http://stexpanded.wikia.com/Commander-in-Chief
#
# not found:
#  http://stexpanded.wikia.com/Commanding_officer
#  http://memory-alpha.wikia.com/Commanding_officer
# found instead:
#  http://memory-alpha.wikia.com/Ranking_officer
#
# found:
#  http://memory-alpha.wikia.com/Commodore
#  http://stexpanded.wikia.com/Commodore
#
# found:
#  http://memory-alpha.wikia.com/Communications
#  http://stexpanded.wikia.com/Communications
#
# found:
#  http://memory-alpha.wikia.com/Communications_officer
#  http://stexpanded.wikia.com/Communications_officer
#
# not found:
#  http://stexpanded.wikia.com/Computer
#  http://memory-alpha.wikia.com/Computer
# found instead:
#  http://memory-alpha.wikia.com/Database
#
# not found:
#  http://stexpanded.wikia.com/Conference_room
#  http://memory-alpha.wikia.com/Conference_room
# found instead:
#  http://memory-alpha.wikia.com/Briefing_room
#
# found:
#  http://memory-alpha.wikia.com/Conflicts
#  http://stexpanded.wikia.com/Conflicts
#
# found:
#  http://memory-alpha.wikia.com/Constellation_class
#  http://stexpanded.wikia.com/Constellation_class
#
# not found:
#  http://stexpanded.wikia.com/USS_Valkyrie_(NCC-2590)
#  http://memory-alpha.wikia.com/Constellation_class_model
# found instead:
#  http://memory-alpha.wikia.com/USS_Stargazer
#
# found:
#  http://memory-alpha.wikia.com/Constitution_class
#  http://stexpanded.wikia.com/Constitution_class
#
# found:
#  http://memory-alpha.wikia.com/Continent
#  http://stexpanded.wikia.com/Continent
#
# found:
#  http://memory-alpha.wikia.com/Convoy
#  http://stexpanded.wikia.com/Convoy
#
# found:
#  http://memory-alpha.wikia.com/Copernicus_Ship_Yards
#  http://stexpanded.wikia.com/Copernicus_Ship_Yards
#
# not found:
#  http://stexpanded.wikia.com/Coridan
#  http://memory-alpha.wikia.com/Coridan
# found instead:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Coridan_(planet)
#  http://stexpanded.wikia.com/Coridan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Corporal
#  http://stexpanded.wikia.com/Corporal
#
# not found:
#  http://stexpanded.wikia.com/Corsair
#  http://memory-alpha.wikia.com/Corsair
# found instead:
#  http://memory-alpha.wikia.com/Frigate
#
# not found:
#  http://stexpanded.wikia.com/Cortical_stimulator
#  http://memory-alpha.wikia.com/Cortical_stimulator
# found instead:
#  http://memory-alpha.wikia.com/Neuro-cortical_stimulator
#
# found:
#  http://memory-alpha.wikia.com/Council_of_Ministers
#  http://stexpanded.wikia.com/Council_of_Ministers
#
# not found:
#  http://stexpanded.wikia.com/Counselor
#  http://memory-alpha.wikia.com/Counselor
# found instead:
#  http://memory-alpha.wikia.com/Assistant_ship%27s_counselor
#
# found:
#  http://memory-alpha.wikia.com/Country
#  http://stexpanded.wikia.com/Country
#
# found:
#  http://memory-alpha.wikia.com/Coup_d%27état
#  http://stexpanded.wikia.com/Coup_d%27état
#
# found:
#  http://memory-alpha.wikia.com/Court_martial
#  http://stexpanded.wikia.com/Court-martial
#
# found:
#  http://memory-alpha.wikia.com/Crewman
#  http://stexpanded.wikia.com/Crewman
#
# found:
#  http://memory-alpha.wikia.com/Cruiser
#  http://stexpanded.wikia.com/Cruiser
#
# found:
#  http://memory-alpha.wikia.com/Cryogenic_stasis
#  http://stexpanded.wikia.com/Cryogenic_stasis
#
# not found:
#  http://stexpanded.wikia.com/Cryosatellite
#  http://memory-alpha.wikia.com/Cryonics_satellite
# found instead:
#  http://memory-alpha.wikia.com/Cryostasis_chamber
#
# found:
#  http://memory-alpha.wikia.com/Cuellar_system
#  http://stexpanded.wikia.com/Cuellar_system
#
# found:
#  http://memory-alpha.wikia.com/Cutting_beam
#  http://stexpanded.wikia.com/Cutting_beam
#
# found:
#  http://memory-alpha.wikia.com/Cygnet_XIV
#  http://stexpanded.wikia.com/Cygnet_XIV
#
# found:
#  http://memory-alpha.wikia.com/D%27Kora_class
#  http://stexpanded.wikia.com/D%27Kora_class
#
# found:
#  http://memory-alpha.wikia.com/D%27deridex_class
#  http://stexpanded.wikia.com/D%27deridex_class
#
# found:
#  http://memory-alpha.wikia.com/D%27jarra
#  http://stexpanded.wikia.com/D%27jarra
#
# found:
#  http://memory-alpha.wikia.com/D7_class
#  http://stexpanded.wikia.com/D7_class
#
# found:
#  http://memory-alpha.wikia.com/DNA
#  http://stexpanded.wikia.com/DNA
#
# found:
#  http://memory-alpha.wikia.com/Dabo
#  http://stexpanded.wikia.com/Dabo
#
# found:
#  http://memory-alpha.wikia.com/DaiMon
#  http://stexpanded.wikia.com/DaiMon
#
# found:
#  http://memory-alpha.wikia.com/Dakar
#  http://stexpanded.wikia.com/Dakar_(city)
#
# found:
#  http://memory-alpha.wikia.com/Damage_control_team
#  http://stexpanded.wikia.com/Damage_control
#
# not found:
#  http://stexpanded.wikia.com/Damar
#  http://memory-alpha.wikia.com/Damar
# found instead:
#  http://memory-alpha.wikia.com/Rusot
#
# found:
#  http://memory-alpha.wikia.com/Dampening_field
#  http://stexpanded.wikia.com/Dampening_field
#
# found:
#  http://memory-alpha.wikia.com/Dance
#  http://stexpanded.wikia.com/Dance
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Crewman)
#  http://stexpanded.wikia.com/Daniels_(Crewman)
#
# found:
#  http://memory-alpha.wikia.com/Daniels_(Lieutenant)
#  http://stexpanded.wikia.com/Daniels_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Danube_class
#  http://stexpanded.wikia.com/Danube_class
#
# found:
#  http://memory-alpha.wikia.com/Danula_II
#  http://stexpanded.wikia.com/Danula_II
#
# found:
#  http://memory-alpha.wikia.com/Dark_matter_nebula
#  http://stexpanded.wikia.com/Dark_matter_nebula
#
# found:
#  http://memory-alpha.wikia.com/Daro
#  http://stexpanded.wikia.com/Daro
#
# found:
#  http://memory-alpha.wikia.com/Data
#  http://stexpanded.wikia.com/Data
#
# found:
#  http://memory-alpha.wikia.com/Dave_Bailey
#  http://stexpanded.wikia.com/Dave_Bailey
#
# not found:
#  http://stexpanded.wikia.com/Dax_(symbiont)
#  http://memory-alpha.wikia.com/Dax_(symbiont)
# found instead:
#  http://memory-alpha.wikia.com/Curzon_Dax
#
# found:
#  http://memory-alpha.wikia.com/Daystrom_Institute
#  http://stexpanded.wikia.com/Daystrom_Institute
#
# found:
#  http://memory-alpha.wikia.com/DePaul
#  http://stexpanded.wikia.com/DePaul
#
# not found:
#  http://stexpanded.wikia.com/DeSalle
#  http://memory-alpha.wikia.com/DeSalle
# found instead:
#  http://memory-alpha.wikia.com/Phase
#
# not found:
#  http://stexpanded.wikia.com/Deanna_Troi
#  http://memory-alpha.wikia.com/Deanna_Troi
# found instead:
#  http://memory-alpha.wikia.com/Klingon-Cardassian_Alliance_personnel
#
# found:
#  http://memory-alpha.wikia.com/Dedication_plaque
#  http://stexpanded.wikia.com/Dedication_plaque
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_3
#  http://stexpanded.wikia.com/Deep_Space_3
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_4
#  http://stexpanded.wikia.com/Deep_Space_4
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_5
#  http://stexpanded.wikia.com/Deep_Space_5
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_9
#  http://stexpanded.wikia.com/Deep_Space_9
#
# not found:
#  http://stexpanded.wikia.com/Venturi
#  http://memory-alpha.wikia.com/Deep_Space_9_visitors
# found instead:
#  http://memory-alpha.wikia.com/Ventu
#
# found:
#  http://memory-alpha.wikia.com/Deep_Space_Station_K-7
#  http://stexpanded.wikia.com/Deep_Space_Station_K-7
#
# not found:
#  http://stexpanded.wikia.com/USS_Defiant_(NX-74205)
#  http://memory-alpha.wikia.com/Defiant
# found instead:
#  http://memory-alpha.wikia.com/USS_Defiant_(2370)
#
# found:
#  http://memory-alpha.wikia.com/Defiant_class
#  http://stexpanded.wikia.com/Defiant_class
#
# not found:
#  http://stexpanded.wikia.com/Deflector_shield
#  http://memory-alpha.wikia.com/Deflector_shield
# found instead:
#  http://memory-alpha.wikia.com/Multi-spectrum_shielding
#
# found:
#  http://memory-alpha.wikia.com/Degree
#  http://stexpanded.wikia.com/Degree
#
# found:
#  http://memory-alpha.wikia.com/Delphic_Expanse
#  http://stexpanded.wikia.com/Delphic_Expanse
#
# not found:
#  http://stexpanded.wikia.com/Delta_Flyer
#  http://memory-alpha.wikia.com/Delta_Flyer
# found instead:
#  http://memory-alpha.wikia.com/Delta_Flyer_type
#
# not found:
#  http://stexpanded.wikia.com/Delta_IV
#  http://memory-alpha.wikia.com/Delta_IV
# found instead:
#  http://memory-alpha.wikia.com/Deltan
#
# not found:
#  http://stexpanded.wikia.com/Delta_Quadrant
#  http://memory-alpha.wikia.com/Delta_Quadrant
# found instead:
#  http://memory-alpha.wikia.com/Alpha_Quadrant
#
# not found:
#  http://stexpanded.wikia.com/Delta_Vega
#  http://memory-alpha.wikia.com/Delta_Vega
# found instead:
#  http://memory-alpha.wikia.com/Delta_Vega_sector
#
# found:
#  http://memory-alpha.wikia.com/Demilitarized_Zone
#  http://stexpanded.wikia.com/Demilitarized_Zone
#
# found:
#  http://memory-alpha.wikia.com/Demora_Sulu
#  http://stexpanded.wikia.com/Demora_Sulu
#
# not found:
#  http://stexpanded.wikia.com/Deneva
#  http://memory-alpha.wikia.com/Deneva
# found instead:
#  http://memory-alpha.wikia.com/Denevan
#
# found:
#  http://memory-alpha.wikia.com/Denmark
#  http://stexpanded.wikia.com/Denmark
#
# found:
#  http://memory-alpha.wikia.com/Denobula
#  http://stexpanded.wikia.com/Denobula
#
# found:
#  http://memory-alpha.wikia.com/Denobulan
#  http://stexpanded.wikia.com/Denobulan
#
# found:
#  http://memory-alpha.wikia.com/Dentistry
#  http://stexpanded.wikia.com/Dentist
#
# found:
#  http://memory-alpha.wikia.com/Department_of_Cartography
#  http://stexpanded.wikia.com/Department_of_Cartography
#
# not found:
#  http://stexpanded.wikia.com/Department_of_Temporal_Investigations
#  http://memory-alpha.wikia.com/Department_of_Temporal_Investigations
# found instead:
#  http://memory-alpha.wikia.com/Temporal_violation
#
# found:
#  http://memory-alpha.wikia.com/Dermal_regenerator
#  http://stexpanded.wikia.com/Dermal_regenerator
#
# found:
#  http://memory-alpha.wikia.com/Destroyer
#  http://stexpanded.wikia.com/Destroyer
#
# found:
#  http://memory-alpha.wikia.com/Detapa_Council
#  http://stexpanded.wikia.com/Detapa_Council
#
# found:
#  http://memory-alpha.wikia.com/Deuterium
#  http://stexpanded.wikia.com/Deuterium
#
# found:
#  http://memory-alpha.wikia.com/Devoras
#  http://stexpanded.wikia.com/IRW_Devoras
#
# not found:
#  http://stexpanded.wikia.com/Devore
#  http://memory-alpha.wikia.com/Devore
# found instead:
#  http://memory-alpha.wikia.com/Devore_Imperium
#
# found:
#  http://memory-alpha.wikia.com/Devos_II
#  http://stexpanded.wikia.com/Devos_II
#
# found:
#  http://memory-alpha.wikia.com/DiFalco
#  http://stexpanded.wikia.com/DiFalco
#
# found:
#  http://memory-alpha.wikia.com/Dikironium_cloud_creature
#  http://stexpanded.wikia.com/Dikironium_cloud_creature
#
# found:
#  http://memory-alpha.wikia.com/Dilithium
#  http://stexpanded.wikia.com/Dilithium
#
# found:
#  http://memory-alpha.wikia.com/Diplomacy_and_law
#  http://stexpanded.wikia.com/Diplomacy_and_law
#
# found:
#  http://memory-alpha.wikia.com/Directed_energy_weapon
#  http://stexpanded.wikia.com/Directed-energy_weapon
#
# not found:
#  http://stexpanded.wikia.com/Disruptor
#  http://memory-alpha.wikia.com/Disruptor
# found instead:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#  http://stexpanded.wikia.com/Disruptor_cannon
#
# found:
#  http://memory-alpha.wikia.com/Disruptor_pistol
#  http://stexpanded.wikia.com/Disruptor_pistol
#
# not found:
#  http://stexpanded.wikia.com/Disruptor_rifle
#  http://memory-alpha.wikia.com/Disruptor_rifle
# found instead:
#  http://memory-alpha.wikia.com/Disruptor_cannon
#
# not found:
#  http://stexpanded.wikia.com/Distant_past
#  http://memory-alpha.wikia.com/Distant_past
# found instead:
#  http://memory-alpha.wikia.com/3rd_century
#
# found:
#  http://memory-alpha.wikia.com/Distress_call
#  http://stexpanded.wikia.com/Distress_call
#
# found:
#  http://memory-alpha.wikia.com/Dividices
#  http://stexpanded.wikia.com/IRW_Dividices
#
# not found:
#  http://stexpanded.wikia.com/Division
#  http://memory-alpha.wikia.com/Division
# found instead:
#  http://memory-alpha.wikia.com/Starfleet_division
#
# found:
#  http://memory-alpha.wikia.com/Doctor
#  http://stexpanded.wikia.com/Doctor
#
# found:
#  http://memory-alpha.wikia.com/Doctor_Who
#  http://stexpanded.wikia.com/Doctor_Who
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Medicine
#  http://stexpanded.wikia.com/Doctor_of_Medicine
#
# found:
#  http://memory-alpha.wikia.com/Doctor_of_Philosophy
#  http://stexpanded.wikia.com/Doctor_of_Science
#
# not found:
#  http://stexpanded.wikia.com/Dominion
#  http://memory-alpha.wikia.com/Dominion
# found instead:
#  http://memory-alpha.wikia.com/Dominion_starship_classes
#
# found:
#  http://memory-alpha.wikia.com/Dominion_Headquarters
#  http://stexpanded.wikia.com/Dominion_Headquarters
#
# found:
#  http://memory-alpha.wikia.com/Dominion_War
#  http://stexpanded.wikia.com/Dominion_War
#
# found:
#  http://memory-alpha.wikia.com/Donatra
#  http://stexpanded.wikia.com/Donatra
#
# found:
#  http://memory-alpha.wikia.com/Dorian_Collins
#  http://stexpanded.wikia.com/Dorian_Collins_(USS_Baldwin)
#
# found:
#  http://memory-alpha.wikia.com/Dorvan_sector
#  http://stexpanded.wikia.com/Dorvan_sector
#
# found:
#  http://memory-alpha.wikia.com/Dragon
#  http://stexpanded.wikia.com/Dragon
#
# found:
#  http://memory-alpha.wikia.com/Dreadnought
#  http://stexpanded.wikia.com/Dreadnought
#
# found:
#  http://memory-alpha.wikia.com/Dukat
#  http://stexpanded.wikia.com/Dukat
#
# ...
#  http://memory-alpha.wikia.com/USS_Zhukov
#  http://stexpanded.wikia.com/USS_Zhukov_(NCC-26136)
#
# found:
#  http://memory-alpha.wikia.com/Uhlan
#  http://stexpanded.wikia.com/Uhlan
#
# found:
#  http://memory-alpha.wikia.com/Ultritium
#  http://stexpanded.wikia.com/Ultritium
#
# found:
#  http://memory-alpha.wikia.com/Ultritium_concussion_shell
#  http://stexpanded.wikia.com/Ultritium_concussion_shell
#
# found:
#  http://memory-alpha.wikia.com/Uniform
#  http://stexpanded.wikia.com/Uniform
#
# found:
#  http://memory-alpha.wikia.com/United_Earth
#  http://stexpanded.wikia.com/United_Earth
#
# found:
#  http://memory-alpha.wikia.com/United_Earth_Space_Probe_Agency
#  http://stexpanded.wikia.com/United_Earth_Space_Probe_Agency
#
# not found:
#  http://stexpanded.wikia.com/United_Federation_of_Planets
#  http://memory-alpha.wikia.com/United_Federation_of_Planets
# found instead:
#  http://memory-alpha.wikia.com/Charter_of_the_United_Federation_of_Planets
#
# found:
#  http://memory-alpha.wikia.com/United_Nations
#  http://stexpanded.wikia.com/United_Nations
#
# found:
#  http://memory-alpha.wikia.com/United_States_armed_forces
#  http://stexpanded.wikia.com/United_States_armed_forces
#
# found:
#  http://memory-alpha.wikia.com/United_States_of_America
#  http://stexpanded.wikia.com/United_States_of_America
#
# found:
#  http://memory-alpha.wikia.com/Universal_translator
#  http://stexpanded.wikia.com/Universal_translator
#
# found:
#  http://memory-alpha.wikia.com/University
#  http://stexpanded.wikia.com/University
#
# found:
#  http://memory-alpha.wikia.com/University_of_Betazed
#  http://stexpanded.wikia.com/University_of_Betazed
#
# found:
#  http://memory-alpha.wikia.com/University_of_California,_Berkeley
#  http://stexpanded.wikia.com/University_of_California,_Berkeley
#
# found:
#  http://memory-alpha.wikia.com/University_of_Culat
#  http://stexpanded.wikia.com/University_of_Culat
#
# found:
#  http://memory-alpha.wikia.com/University_of_Mississippi
#  http://stexpanded.wikia.com/University_of_Mississippi
#
# found:
#  http://memory-alpha.wikia.com/Unnamed_Oberth_class_starships
#  http://stexpanded.wikia.com/USS_Bonestell_(NCC-31600)
#
# not found:
#  http://stexpanded.wikia.com/IKS_Vor%27cha
#  http://memory-alpha.wikia.com/Unnamed_Vor%27cha_class_starships
# found instead:
#  http://memory-alpha.wikia.com/IKS_Vor%27nak
#
# not found:
#  http://stexpanded.wikia.com/Utopia_Planitia
#  http://memory-alpha.wikia.com/Utopia_Planitia
# found instead:
#  http://memory-alpha.wikia.com/Utopia_Planitia_Gardens
#
# found:
#  http://memory-alpha.wikia.com/Utopia_Planitia_Fleet_Yards
#  http://stexpanded.wikia.com/Utopia_Planitia_Fleet_Yards
#
# found:
#  http://memory-alpha.wikia.com/Uttan_Narsu
#  http://stexpanded.wikia.com/Uttan_Narsu
#
# found:
#  http://memory-alpha.wikia.com/V%27Shar
#  http://stexpanded.wikia.com/V%27Shar
#
# found:
#  http://memory-alpha.wikia.com/Vaadwaur
#  http://stexpanded.wikia.com/Vaadwaur
#
# found:
#  http://memory-alpha.wikia.com/Vadosia
#  http://stexpanded.wikia.com/Vadosia
#
# not found:
#  http://stexpanded.wikia.com/Valdore
#  http://memory-alpha.wikia.com/Valdore
# found instead:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#
# found:
#  http://memory-alpha.wikia.com/Valdore_(starship)
#  http://stexpanded.wikia.com/IRW_Valdore
#
# found:
#  http://memory-alpha.wikia.com/Valdore_type
#  http://stexpanded.wikia.com/Valdore_type
#
# found:
#  http://memory-alpha.wikia.com/Valeris
#  http://stexpanded.wikia.com/Valeris
#
# found:
#  http://memory-alpha.wikia.com/Valo_II
#  http://stexpanded.wikia.com/Valo_II
#
# found:
#  http://memory-alpha.wikia.com/Vash
#  http://stexpanded.wikia.com/Vash
#
# found:
#  http://memory-alpha.wikia.com/Vedek
#  http://stexpanded.wikia.com/Vedek
#
# found:
#  http://memory-alpha.wikia.com/Vedek_Assembly
#  http://stexpanded.wikia.com/Vedek_Assembly
#
# found:
#  http://memory-alpha.wikia.com/Velocity
#  http://stexpanded.wikia.com/Velocity
#
# found:
#  http://memory-alpha.wikia.com/Verathan
#  http://stexpanded.wikia.com/Verathan
#
# found:
#  http://memory-alpha.wikia.com/Veridian_III
#  http://stexpanded.wikia.com/Veridian_III
#
# found:
#  http://memory-alpha.wikia.com/Vetar
#  http://stexpanded.wikia.com/Vetar
#
# found:
#  http://memory-alpha.wikia.com/Vice_admiral
#  http://stexpanded.wikia.com/Vice_admiral
#
# found:
#  http://memory-alpha.wikia.com/Vidiian_Sodality
#  http://stexpanded.wikia.com/Vidiian_Sodality
#
# not found:
#  http://stexpanded.wikia.com/Viewscreen
#  http://memory-alpha.wikia.com/Viewscreen
# found instead:
#  http://memory-alpha.wikia.com/Mine
#
# found:
#  http://memory-alpha.wikia.com/Volleyball
#  http://stexpanded.wikia.com/Volleyball
#
# found:
#  http://memory-alpha.wikia.com/Vor%27cha_class
#  http://stexpanded.wikia.com/Vor%27cha_class
#
# found:
#  http://memory-alpha.wikia.com/Vorgon
#  http://stexpanded.wikia.com/Vorgon
#
# found:
#  http://memory-alpha.wikia.com/Vorik
#  http://stexpanded.wikia.com/Vorik
#
# found:
#  http://memory-alpha.wikia.com/Vorta
#  http://stexpanded.wikia.com/Vorta
#
# found:
#  http://memory-alpha.wikia.com/Vosk
#  http://stexpanded.wikia.com/Vosk
#
# found:
#  http://memory-alpha.wikia.com/Voth
#  http://stexpanded.wikia.com/Voth
#
# not found:
#  http://stexpanded.wikia.com/Merken_tr%27Vreenak
#  http://memory-alpha.wikia.com/Vreenak
# found instead:
#  http://memory-alpha.wikia.com/Terellian
#
# not found:
#  http://stexpanded.wikia.com/Vulcan
#  http://memory-alpha.wikia.com/Vulcan
# found instead:
#  http://memory-alpha.wikia.com/Spock_(disambiguation)
#
# not found:
#  http://stexpanded.wikia.com/Vulcan%27s_Forge
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge
# found instead:
#  http://memory-alpha.wikia.com/Vulcan%27s_Forge_(disambiguation)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_(planet)
#  http://stexpanded.wikia.com/Vulcan_(planet)
#
# found:
#  http://memory-alpha.wikia.com/Vulcan_Science_Academy
#  http://stexpanded.wikia.com/Vulcan_Science_Academy
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_ranks
#  http://memory-alpha.wikia.com/Vulcan_ranks
# found instead:
#  http://memory-alpha.wikia.com/Rank_insignia
#
# not found:
#  http://stexpanded.wikia.com/Vulcan_system
#  http://memory-alpha.wikia.com/Vulcan_system
# found instead:
#  http://memory-alpha.wikia.com/40_Eridani_A
#
# found:
#  http://memory-alpha.wikia.com/Walker_Keel
#  http://stexpanded.wikia.com/Walker_Keel
#
# not found:
#  http://stexpanded.wikia.com/Warbird
#  http://memory-alpha.wikia.com/Warbird
# found instead:
#  http://memory-alpha.wikia.com/D%27deridex_class
#
# found:
#  http://memory-alpha.wikia.com/Warp_coil
#  http://stexpanded.wikia.com/Warp_coil
#
# found:
#  http://memory-alpha.wikia.com/Warp_core
#  http://stexpanded.wikia.com/Warp_core
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_breach
#  http://stexpanded.wikia.com/Warp_core_breach
#
# found:
#  http://memory-alpha.wikia.com/Warp_core_ejection_system
#  http://stexpanded.wikia.com/Warp_core_ejection_system
#
# found:
#  http://memory-alpha.wikia.com/Warp_drive
#  http://stexpanded.wikia.com/Warp_drive
#
# found:
#  http://memory-alpha.wikia.com/Warship
#  http://stexpanded.wikia.com/Warship
#
# not found:
#  http://stexpanded.wikia.com/Jennifer_Watley
#  http://memory-alpha.wikia.com/Watley
# found instead:
#  http://memory-alpha.wikia.com/Watley_(Lieutenant)
#
# found:
#  http://memory-alpha.wikia.com/Weather_modification_network
#  http://stexpanded.wikia.com/Weather_modification_network
#
# found:
#  http://memory-alpha.wikia.com/Wedding
#  http://stexpanded.wikia.com/Wedding
#
# found:
#  http://memory-alpha.wikia.com/Wellington
#  http://stexpanded.wikia.com/Wellington
#
# found:
#  http://memory-alpha.wikia.com/Wendell_Greer
#  http://stexpanded.wikia.com/Wendell_Greer
#
# found:
#  http://memory-alpha.wikia.com/Wesley_Crusher
#  http://stexpanded.wikia.com/Wesley_Crusher
#
# found:
#  http://memory-alpha.wikia.com/West_Point
#  http://stexpanded.wikia.com/West_Point
#
# found:
#  http://memory-alpha.wikia.com/Weyoun
#  http://stexpanded.wikia.com/Weyoun
#
# found:
#  http://memory-alpha.wikia.com/Will_Decker
#  http://stexpanded.wikia.com/Willard_Decker
#
# not found:
#  http://stexpanded.wikia.com/William_Ross
#  http://memory-alpha.wikia.com/William_Ross
# found instead:
#  http://memory-alpha.wikia.com/Richard_B._Barnett
#
# found:
#  http://memory-alpha.wikia.com/William_Shakespeare
#  http://stexpanded.wikia.com/William_Shakespeare
#
# not found:
#  http://stexpanded.wikia.com/William_T._Riker
#  http://memory-alpha.wikia.com/William_T._Riker
# found instead:
#  http://memory-alpha.wikia.com/Personal_log,_William_T._Riker
#
# found:
#  http://memory-alpha.wikia.com/William_Telfer
#  http://stexpanded.wikia.com/William_Telfer
#
# found:
#  http://memory-alpha.wikia.com/Wine
#  http://stexpanded.wikia.com/Wine
#
# found:
#  http://memory-alpha.wikia.com/Wolf_359
#  http://stexpanded.wikia.com/Wolf_359
#
# not found:
#  http://stexpanded.wikia.com/Worf
#  http://memory-alpha.wikia.com/Worf
# found instead:
#  http://memory-alpha.wikia.com/Kurn
#
# found:
#  http://memory-alpha.wikia.com/World_War_II
#  http://stexpanded.wikia.com/World_War_II
#
# found:
#  http://memory-alpha.wikia.com/World_War_III
#  http://stexpanded.wikia.com/World_War_III
#
# found:
#  http://memory-alpha.wikia.com/Wormhole
#  http://stexpanded.wikia.com/Wormhole
#
# found:
#  http://memory-alpha.wikia.com/X-ray_laser
#  http://stexpanded.wikia.com/X-ray_laser
#
# found:
#  http://memory-alpha.wikia.com/Xenophobia
#  http://stexpanded.wikia.com/Xenophobia
#
# found:
#  http://memory-alpha.wikia.com/Xindi
#  http://stexpanded.wikia.com/Xindi
#
# found:
#  http://memory-alpha.wikia.com/Xindi-Aquatic
#  http://stexpanded.wikia.com/Xindi-Aquatic
#
# found:
#  http://memory-alpha.wikia.com/Xon
#  http://stexpanded.wikia.com/Xon
#
# found:
#  http://memory-alpha.wikia.com/Yaderan
#  http://stexpanded.wikia.com/Yaderan
#
# found:
#  http://memory-alpha.wikia.com/Yeager_type
#  http://stexpanded.wikia.com/Yeager_class
#
# found:
#  http://memory-alpha.wikia.com/Yelgrun
#  http://stexpanded.wikia.com/Yelgrun
#
# found:
#  http://memory-alpha.wikia.com/Yellow_alert
#  http://stexpanded.wikia.com/Yellow_alert
#
# found:
#  http://memory-alpha.wikia.com/Yellowstone_class
#  http://stexpanded.wikia.com/Yellowstone_class
#
# found:
#  http://memory-alpha.wikia.com/Yeoman
#  http://stexpanded.wikia.com/Yeoman
#
# found:
#  http://memory-alpha.wikia.com/Yoyodyne_Propulsion_Systems
#  http://stexpanded.wikia.com/Yoyodyne_Division
#
# found:
#  http://memory-alpha.wikia.com/Yridian
#  http://stexpanded.wikia.com/Yridian
#
# found:
#  http://memory-alpha.wikia.com/Zabathu
#  http://stexpanded.wikia.com/Zabathu
#
# not found:
#  http://stexpanded.wikia.com/Zefram_Cochrane_High_School
#  http://memory-alpha.wikia.com/Zefram_Cochrane_High_School
# found instead:
#  http://memory-alpha.wikia.com/Cochrane
#
# found:
#  http://memory-alpha.wikia.com/Zero_gravity
#  http://stexpanded.wikia.com/Zero_gravity
#
# found:
#  http://memory-alpha.wikia.com/Zhian%27tara
#  http://stexpanded.wikia.com/Zhian%27tara
#
# found:
#  http://memory-alpha.wikia.com/Zoo
#  http://stexpanded.wikia.com/Zoo
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship
#  http://stexpanded.wikia.com/class/starship-sidebar
#
# not found:
#  http://stexpanded.wikia.com/class/character
#  http://memory-alpha.wikia.com/class/sidebar_individual
# found instead:
#  http://memory-alpha.wikia.com/class/class
#
# not found:
#  http://stexpanded.wikia.com/class/yearbox
#  http://memory-alpha.wikia.com/class/sidebar_year
# found instead:
#  http://memory-alpha.wikia.com/class/ste
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_starship_class
#  http://stexpanded.wikia.com/class/starship-class
#
# found:
#  http://memory-alpha.wikia.com/class/uss
#  http://stexpanded.wikia.com/class/uss
#
# found:
#  http://memory-alpha.wikia.com/class/ds9
#  http://stexpanded.wikia.com/class/ds9
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_planet
#  http://stexpanded.wikia.com/class/planet_info
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_military_conflict
#  http://stexpanded.wikia.com/class/battle_data
#
# found:
#  http://memory-alpha.wikia.com/class/voy
#  http://stexpanded.wikia.com/class/voy
#
# found:
#  http://memory-alpha.wikia.com/class/sidebar_species
#  http://stexpanded.wikia.com/class/sidebar_species
#
# found:
#  http://memory-alpha.wikia.com/class/tng
#  http://stexpanded.wikia.com/class/tng
#
# found:
#  http://memory-alpha.wikia.com/class/ent
#  http://stexpanded.wikia.com/class/ent
#
# found:
#  http://memory-alpha.wikia.com/class/film
#  http://stexpanded.wikia.com/class/film
#
# found:
#  http://memory-alpha.wikia.com/name
#  http://stexpanded.wikia.com/name
#
# found:
#  http://memory-alpha.wikia.com/species
#  http://stexpanded.wikia.com/species
#
# found:
#  http://memory-alpha.wikia.com/status
#  http://stexpanded.wikia.com/status
#
# found:
#  http://memory-alpha.wikia.com/rank
#  http://stexpanded.wikia.com/rank
#
# found:
#  http://memory-alpha.wikia.com/affiliation
#  http://stexpanded.wikia.com/affiliation
#
# not found:
#  http://stexpanded.wikia.com/defense
#  http://memory-alpha.wikia.com/defenses
# found instead:
#  http://memory-alpha.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/combatant
#  http://stexpanded.wikia.com/combatant
#
# found:
#  http://memory-alpha.wikia.com/type
#  http://stexpanded.wikia.com/type
#
# found:
#  http://memory-alpha.wikia.com/father
#  http://stexpanded.wikia.com/father
#
# found:
#  http://memory-alpha.wikia.com/gender
#  http://stexpanded.wikia.com/gender
#
# found:
#  http://memory-alpha.wikia.com/mother
#  http://stexpanded.wikia.com/mother
#
# found:
#  http://memory-alpha.wikia.com/born
#  http://stexpanded.wikia.com/born
#
# found:
#  http://memory-alpha.wikia.com/relatives
#  http://stexpanded.wikia.com/relatives
#
# found:
#  http://memory-alpha.wikia.com/died
#  http://stexpanded.wikia.com/died
#
# found:
#  http://memory-alpha.wikia.com/armament
#  http://stexpanded.wikia.com/armament
#
# found:
#  http://memory-alpha.wikia.com/spouse
#  http://stexpanded.wikia.com/spouse
#
# found:
#  http://memory-alpha.wikia.com/sibling
#  http://stexpanded.wikia.com/siblings
#
# found:
#  http://memory-alpha.wikia.com/children
#  http://stexpanded.wikia.com/children
#
# found:
#  http://memory-alpha.wikia.com/date
#  http://stexpanded.wikia.com/date
#
# found:
#  http://memory-alpha.wikia.com/location
#  http://stexpanded.wikia.com/location
#
# found:
#  http://memory-alpha.wikia.com/crew
#  http://stexpanded.wikia.com/crew
#
# found:
#  http://memory-alpha.wikia.com/result
#  http://stexpanded.wikia.com/result
#
# found:
#  http://memory-alpha.wikia.com/occupation
#  http://stexpanded.wikia.com/occupation
#
# found:
#  http://memory-alpha.wikia.com/strength
#  http://stexpanded.wikia.com/strength
#
# found:
#  http://memory-alpha.wikia.com/class
#  http://stexpanded.wikia.com/class
#
# found:
#  http://memory-alpha.wikia.com/planet
#  http://stexpanded.wikia.com/planet
#
# found:
#  http://memory-alpha.wikia.com/image
#  http://stexpanded.wikia.com/image
#
# found:
#  http://memory-alpha.wikia.com/military
#  http://stexpanded.wikia.com/military
#
# found:
#  http://memory-alpha.wikia.com/capital
#  http://stexpanded.wikia.com/capital
#
# found:
#  http://memory-alpha.wikia.com/majorSpecies
#  http://stexpanded.wikia.com/majorSpecies
#
# found:
#  http://memory-alpha.wikia.com/headOfState
#  http://stexpanded.wikia.com/headOfState
#
# found:
#  http://memory-alpha.wikia.com/season
#  http://stexpanded.wikia.com/season
#
# found:
#  http://memory-alpha.wikia.com/year
#  http://stexpanded.wikia.com/year
#
# found:
#  http://memory-alpha.wikia.com/registry
#  http://stexpanded.wikia.com/registry
#
# found:
#  http://memory-alpha.wikia.com/headOfGovernment
#  http://stexpanded.wikia.com/headOfGovernment
#
# found:
#  http://memory-alpha.wikia.com/actor
#  http://stexpanded.wikia.com/actor
#
# not found:
#  http://stexpanded.wikia.com/found
#  http://memory-alpha.wikia.com/founded
# found instead:
#  http://memory-alpha.wikia.com/from
#
# found:
#  http://memory-alpha.wikia.com/guest
#  http://stexpanded.wikia.com/guest
#
# found:
#  http://memory-alpha.wikia.com/artist
#  http://stexpanded.wikia.com/artist
#
# found:
#  http://memory-alpha.wikia.com/publisher
#  http://stexpanded.wikia.com/publisher
#
# found:
#  http://memory-alpha.wikia.com/beam
#  http://stexpanded.wikia.com/beam
